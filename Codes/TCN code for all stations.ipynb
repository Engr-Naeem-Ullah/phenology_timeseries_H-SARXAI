# %% [markdown]
# Cadiz stations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import psutil
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Input
import tensorflow as tf
from bayes_opt import BayesianOptimization
from scipy.fftpack import fft
import warnings

# Set seeds
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ============================================
# 1. Data Loading and Preprocessing
# ============================================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # df['month'] = df.index.month
    # df['weekofyear'] = df.index.isocalendar().week
    # df['year'] = df.index.isocalendar().year
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))])
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))])

    df.fillna(df.median(), inplace=True)
    return df, target_col

# ============================================
# 2. Feature Scaling
# ============================================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))  # 3D for CNN
    return X_scaled, y, scaler

# ============================================
# 3. Build TCN Model (Dilated CNN)
# ============================================
def build_tcn_model(input_shape, num_classes=4, num_filters=64, kernel_size=3, dropout_rate=0.2, dilation_rate=2):
    model = Sequential()
    
    # Add dilated convolutions
    model.add(Conv1D(filters=num_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, 
                     activation='relu', input_shape=input_shape))
    model.add(Dropout(dropout_rate))
    
    # Add more dilated convolutions if needed
    model.add(Conv1D(filters=num_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, activation='relu'))
    model.add(Dropout(dropout_rate))

    # Flatten and add Dense layers
    model.add(Flatten())
    model.add(Dense(num_filters // 2, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ============================================
# 4. Bayesian Optimization Objective
# ============================================
def objective_function(num_filters, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_tcn_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_filters=int(num_filters),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# ============================================
# 5. Optimize Hyperparameters
# ============================================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_filters': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_filters, dropout_rate, epochs, batch_size: objective_function(
            num_filters, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ============================================
# 6. Train & Evaluate Model
# ============================================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_tcn_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_filters=int(best_params['num_filters']),
        dropout_rate=float(best_params['dropout_rate'])
    )

    start_train = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start_train

    start_infer = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    inference_time = (time.time() - start_infer) / len(X_test)

    # Calculate total testing time
    testing_time = time.time() - start_infer

    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print("\n===== Evaluation =====")
    print(f"Accuracy: {acc:.4f}")
    print("Report:\n", classification_report(y_test, y_pred, digits=4))
    print("Confusion Matrix:\n", cm)

    model.save("temp_model.h5", include_optimizer=False)
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)
    os.remove("temp_model.h5")

    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    ram_usage = psutil.Process(os.getpid()).memory_info().rss / (1024 ** 2)

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f}s")
    print(f"Inference/sample: {inference_time:.6f}s")
    print(f"Testing Time: {testing_time:.2f}s")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Params: {total_params:,}")
    print(f"RAM Usage: {ram_usage:.2f} MB")

    return model, history

# ============================================
# 7. Main
# ============================================
def main():
    train_path =  r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cadiz_train.csv"
    test_path =  r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cadiz_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\n Optimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\n Best Params:", best_params)

    print("\n Training Final TCN Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
#  Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_fi... |
# -------------------------------------------------------------------------
# | 1         | 1.0       | 33.98     | 0.4803    | 86.6      | 89.47     |
# | 2         | 1.0       | 23.49     | 0.1624    | 52.9      | 115.2     |
# | 3         | 1.0       | 44.85     | 0.3832    | 51.03     | 125.1     |
# | 4         | 0.9692    | 55.96     | 0.1849    | 59.09     | 49.61     |
# | 5         | 1.0       | 30.6      | 0.3099    | 71.6      | 59.96     |
# | 6         | 1.0       | 31.85     | 0.4144    | 54.7      | 125.6     |
# | 7         | 1.0       | 16.22     | 0.1008    | 98.87     | 57.36     |
# | 8         | 1.0       | 24.08     | 0.3354    | 54.27     | 116.3     |
# | 9         | 1.0       | 62.74     | 0.2653    | 99.33     | 126.9     |
# | 10        | 1.0       | 21.2      | 0.3698    | 99.6      | 128.0     |
# | 11        | 1.0       | 16.02     | 0.4903    | 58.02     | 77.58     |
# | 12        | 1.0       | 16.84     | 0.2122    | 76.12     | 33.21     |
# | 13        | 1.0       | 63.77     | 0.3883    | 98.66     | 94.81     |
# | 14        | 1.0       | 63.51     | 0.1726    | 69.92     | 109.0     |
# | 15        | 1.0       | 32.35     | 0.1379    | 99.03     | 32.65     |
# | 16        | 1.0       | 42.5      | 0.1817    | 79.84     | 127.6     |
# | 17        | 1.0       | 16.41     | 0.1579    | 98.83     | 98.28     |
# | 18        | 1.0       | 17.1      | 0.3524    | 78.23     | 66.47     |
# | 19        | 1.0       | 42.31     | 0.4511    | 98.85     | 65.76     |
# | 20        | 1.0       | 39.79     | 0.4936    | 99.34     | 107.9     |
# =========================================================================
#
#  Best Params: {'batch_size': 33.977925704673396, 'dropout_rate': 0.4802857225639665, 'epochs': 86.59969709057026, 'num_filters': 89.47121448291551}
#
#  Training Final TCN Model...
# Epoch 1/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.3165 - loss: 1.3136 - val_accuracy: 0.3077 - val_loss: 1.1603
# Epoch 2/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3811 - loss: 1.1612 - val_accuracy: 0.3077 - val_loss: 1.0798
# Epoch 3/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3963 - loss: 1.0918 - val_accuracy: 0.5538 - val_loss: 0.9626
# Epoch 4/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.5288 - loss: 1.0169 - val_accuracy: 0.7231 - val_loss: 0.8490
# Epoch 5/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.6802 - loss: 0.8957 - val_accuracy: 0.8308 - val_loss: 0.6884
# Epoch 6/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7161 - loss: 0.7832 - val_accuracy: 0.8769 - val_loss: 0.5402
# Epoch 7/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7720 - loss: 0.6674 - val_accuracy: 0.8923 - val_loss: 0.4488
# Epoch 8/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7933 - loss: 0.5890 - val_accuracy: 0.9077 - val_loss: 0.3863
# Epoch 9/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8120 - loss: 0.5018 - val_accuracy: 0.8769 - val_loss: 0.3876
# Epoch 10/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.
86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9538 - loss: 0.1196 - val_accuracy: 1.0000 - val_loss: 0.0649
# Epoch 75/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9660 - loss: 0.1259 - val_accuracy: 1.0000 - val_loss: 0.0387
# Epoch 76/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9450 - loss: 0.1441 - val_accuracy: 1.0000 - val_loss: 0.0432
# Epoch 77/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9787 - loss: 0.0972 - val_accuracy: 1.0000 - val_loss: 0.0372
# Epoch 78/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9442 - loss: 0.1179 - val_accuracy: 1.0000 - val_loss: 0.0364
# Epoch 79/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9558 - loss: 0.1354 - val_accuracy: 1.0000 - val_loss: 0.0405
# Epoch 80/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9580 - loss: 0.1310 - val_accuracy: 0.9846 - val_loss: 0.0416
# Epoch 81/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9449 - loss: 0.1225 - val_accuracy: 0.9846 - val_loss: 0.0487
# Epoch 82/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9713 - loss: 0.0837 - val_accuracy: 1.0000 - val_loss: 0.0355
# Epoch 83/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9580 - loss: 0.1328 - val_accuracy: 1.0000 - val_loss: 0.0362
# Epoch 84/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9784 - loss: 0.0856 - val_accuracy: 1.0000 - val_loss: 0.0261
# Epoch 85/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9809 - loss: 0.1092 - val_accuracy: 1.0000 - val_loss: 0.0270
# Epoch 86/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9824 - loss: 0.0878 - val_accuracy: 1.0000 - val_loss: 0.0326
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation =====
# Accuracy: 0.9655
# Report:
#                precision    recall  f1-score   support
#
#            0     0.8000    0.7500    0.7742        16
#            1     0.9296    0.9565    0.9429        69
#            2     1.0000    0.9927    0.9963       137
#            3     1.0000    1.0000    1.0000        10
#
#     accuracy                         0.9655       232
#    macro avg     0.9324    0.9248    0.9283       232
# weighted avg     0.9653    0.9655    0.9653       232
#
# Confusion Matrix:
#  [[ 12   4   0   0]
#  [  3  66   0   0]
#  [  0   1 136   0]
#  [  0   0   0  10]]
#
# ===== Model Metrics =====
# Training Time: 22.84s
# Inference/sample: 0.002544s
# Testing Time: 0.59s
# Model Size: 0.26 MB
# Trainable Params: 59,676
# RAM Usage: 953.00 MB

# %% [markdown]
# Cordoba station

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import psutil
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Input
import tensorflow as tf
from bayes_opt import BayesianOptimization
from scipy.fftpack import fft
import warnings

# Set seeds
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ============================================
# 1. Data Loading and Preprocessing
# ============================================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # df['month'] = df.index.month
    # df['weekofyear'] = df.index.isocalendar().week
    # df['year'] = df.index.isocalendar().year
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))])
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))])

    df.fillna(df.median(), inplace=True)
    return df, target_col

# ============================================
# 2. Feature Scaling
# ============================================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))  # 3D for CNN
    return X_scaled, y, scaler

# ============================================
# 3. Build TCN Model (Dilated CNN)
# ============================================
def build_tcn_model(input_shape, num_classes=4, num_filters=64, kernel_size=3, dropout_rate=0.2, dilation_rate=2):
    model = Sequential()
    
    # Add dilated convolutions
    model.add(Conv1D(filters=num_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, 
                     activation='relu', input_shape=input_shape))
    model.add(Dropout(dropout_rate))
    
    # Add more dilated convolutions if needed
    model.add(Conv1D(filters=num_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, activation='relu'))
    model.add(Dropout(dropout_rate))

    # Flatten and add Dense layers
    model.add(Flatten())
    model.add(Dense(num_filters // 2, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ============================================
# 4. Bayesian Optimization Objective
# ============================================
def objective_function(num_filters, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_tcn_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_filters=int(num_filters),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# ============================================
# 5. Optimize Hyperparameters
# ============================================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_filters': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_filters, dropout_rate, epochs, batch_size: objective_function(
            num_filters, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ============================================
# 6. Train & Evaluate Model
# ============================================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_tcn_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_filters=int(best_params['num_filters']),
        dropout_rate=float(best_params['dropout_rate'])
    )

    start_train = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start_train

    start_infer = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    inference_time = (time.time() - start_infer) / len(X_test)

    # Calculate total testing time
    testing_time = time.time() - start_infer

    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print("\n===== Evaluation =====")
    print(f"Accuracy: {acc:.4f}")
    print("Report:\n", classification_report(y_test, y_pred, digits=4))
    print("Confusion Matrix:\n", cm)

    model.save("temp_model.h5", include_optimizer=False)
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)
    os.remove("temp_model.h5")

    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    ram_usage = psutil.Process(os.getpid()).memory_info().rss / (1024 ** 2)

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f}s")
    print(f"Inference/sample: {inference_time:.6f}s")
    print(f"Testing Time: {testing_time:.2f}s")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Params: {total_params:,}")
    print(f"RAM Usage: {ram_usage:.2f} MB")

    return model, history

# ============================================
# 7. Main
# ============================================
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_train.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\n Optimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\n Best Params:", best_params)

    print("\n Training Final TCN Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
#  Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_fi... |
# -------------------------------------------------------------------------
# | 1         | 1.0       | 33.98     | 0.4803    | 86.6      | 89.47     |
# | 2         | 0.9839    | 23.49     | 0.1624    | 52.9      | 115.2     |
# | 3         | 0.9839    | 44.85     | 0.3832    | 51.03     | 125.1     |
# | 4         | 0.9677    | 55.96     | 0.1849    | 59.09     | 49.61     |
# | 5         | 0.9839    | 30.6      | 0.3099    | 71.6      | 59.96     |
# | 6         | 1.0       | 19.66     | 0.4683    | 98.68     | 90.17     |
# | 7         | 0.9677    | 49.31     | 0.2359    | 100.0     | 117.8     |
# | 8         | 1.0       | 33.12     | 0.3515    | 85.97     | 89.07     |
# | 9         | 1.0       | 34.41     | 0.3111    | 99.28     | 68.82     |
# | 10        | 0.9839    | 18.2      | 0.4567    | 99.88     | 32.67     |
# | 11        | 0.9839    | 58.85     | 0.3279    | 99.81     | 73.71     |
# | 12        | 1.0       | 16.27     | 0.375     | 95.85     | 72.4      |
# | 13        | 1.0       | 31.19     | 0.1044    | 99.17     | 81.59     |
# | 14        | 1.0       | 16.05     | 0.2937    | 81.84     | 106.9     |
# | 15        | 1.0       | 16.09     | 0.1861    | 91.09     | 126.6     |
# | 16        | 1.0       | 16.14     | 0.2208    | 98.07     | 108.2     |
# | 17        | 0.8871    | 63.24     | 0.4801    | 99.09     | 32.68     |
# | 18        | 0.9194    | 60.89     | 0.2816    | 50.11     | 87.3      |
# | 19        | 0.9032    | 16.67     | 0.4528    | 50.47     | 34.09     |
# | 20        | 0.9839    | 19.95     | 0.4088    | 67.26     | 127.8     |
# =========================================================================
#
#  Best Params: {'batch_size': 33.977925704673396, 'dropout_rate': 0.4802857225639665, 'epochs': 86.59969709057026, 'num_filters': 89.47121448291551}
#
#  Training Final TCN Model...
# Epoch 1/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.3714 - loss: 1.3235 - val_accuracy: 0.5806 - val_loss: 1.1079
# Epoch 2/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5249 - loss: 1.0786 - val_accuracy: 0.5806 - val_loss: 0.9499
# Epoch 3/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5249 - loss: 1.0234 - val_accuracy: 0.5806 - val_loss: 0.8834
# Epoch 4/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5533 - loss: 0.9093 - val_accuracy: 0.6129 - val_loss: 0.7786
# Epoch 5/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6158 - loss: 0.8349 - val_accuracy: 0.7258 - val_loss: 0.6548
# Epoch 6/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7478 - loss: 0.7022 - val_accuracy: 0.8387 - val_loss: 0.5532
# Epoch 7/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8079 - loss: 0.5921 - val_accuracy: 0.8548 - val_loss: 0.4752
# Epoch 8/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8182 - loss: 0.5210 - val_accuracy: 0.8548 - val_loss: 0.4482
# Epoch 9/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8256 - loss: 0.4470 - val_accuracy: 0.8387 - val_loss: 0.4354
# Epoch 10/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8510 - loss: 0.4197 - val_accuracy: 0.8387 - val_loss: 0.4180
# Epoch 11/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8516 - loss: 0.4166 - val_accuracy: 0.8065 - val_loss: 0.4239
# Epoch 12/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8458 - loss: 0.4154 - val_accuracy: 0.8226 - val_loss: 0.4133
# Epoch 13/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8550 - loss: 0.3891 - val_accuracy: 0.8226 - val_loss: 0.3969
# Epoch 14/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8606 - loss: 0.3920 - val_accuracy: 0.8548 - val_loss: 0.3811
# Epoch 15/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8681 - loss: 0.3535 - val_accuracy: 0.8226 - val_loss: 0.4022
# Epoch 16/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8455 - loss: 0.3886 - val_accuracy: 0.8548 - val_loss: 0.3718
# Epoch 17/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8709 - loss: 0.3265 - val_accuracy: 0.8387 - val_loss: 0.3782
# Epoch 18/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8710 - loss: 0.3403 - val_accuracy: 0.8548 - val_loss: 0.3624
# Epoch 19/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8839 - loss: 0.3372 - val_accuracy: 0.8548 - val_loss: 0.3479
# Epoch 20/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8722 - loss: 0.3098 - val_accuracy: 0.8548 - val_loss: 0.3433
# Epoch 21/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8694 - loss: 0.3074 - val_accuracy: 0.8548 - val_loss: 0.3260
# Epoch 22/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8841 - loss: 0.2810 - val_accuracy: 0.8548 - val_loss: 0.3194
# Epoch 23/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8906 - loss: 0.2714 - val_accuracy: 0.8548 - val_loss: 0.2998
# Epoch 24/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8890 - loss: 0.2723 - val_accuracy: 0.8710 - val_loss: 0.2954
# Epoch 25/86
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation =====
# Accuracy: 0.8851
# Report:
#                precision    recall  f1-score   support
#
#            0     0.7143    0.2941    0.4167        17
#            1     0.7241    0.9333    0.8155        45
#            2     0.9897    0.9505    0.9697       101
#            3     0.9167    1.0000    0.9565        11
#
#     accuracy                         0.8851       174
#    macro avg     0.8362    0.7945    0.7896       174
# weighted avg     0.8895    0.8851    0.8750       174
#
# Confusion Matrix:
#  [[ 5 12  0  0]
#  [ 2 42  1  0]
#  [ 0  4 96  1]
#  [ 0  0  0 11]]
#
# ===== Model Metrics =====
# Training Time: 18.13s
# Inference/sample: 0.001959s
# Testing Time: 0.34s
# Model Size: 0.26 MB
# Trainable Params: 59,676
# RAM Usage: 1277.34 MB

# %% [markdown]
# Jaen Station

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import psutil
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Input
import tensorflow as tf
from bayes_opt import BayesianOptimization
from scipy.fftpack import fft
import warnings

# Set seeds
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ============================================
# 1. Data Loading and Preprocessing
# ============================================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # df['month'] = df.index.month
    # df['weekofyear'] = df.index.isocalendar().week
    # df['year'] = df.index.isocalendar().year
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))])
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))])

    df.fillna(df.median(), inplace=True)
    return df, target_col

# ============================================
# 2. Feature Scaling
# ============================================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))  # 3D for CNN
    return X_scaled, y, scaler

# ============================================
# 3. Build TCN Model (Dilated CNN)
# ============================================
def build_tcn_model(input_shape, num_classes=4, num_filters=64, kernel_size=3, dropout_rate=0.2, dilation_rate=2):
    model = Sequential()
    
    # Add dilated convolutions
    model.add(Conv1D(filters=num_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, 
                     activation='relu', input_shape=input_shape))
    model.add(Dropout(dropout_rate))
    
    # Add more dilated convolutions if needed
    model.add(Conv1D(filters=num_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, activation='relu'))
    model.add(Dropout(dropout_rate))

    # Flatten and add Dense layers
    model.add(Flatten())
    model.add(Dense(num_filters // 2, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ============================================
# 4. Bayesian Optimization Objective
# ============================================
def objective_function(num_filters, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_tcn_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_filters=int(num_filters),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# ============================================
# 5. Optimize Hyperparameters
# ============================================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_filters': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_filters, dropout_rate, epochs, batch_size: objective_function(
            num_filters, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ============================================
# 6. Train & Evaluate Model
# ============================================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_tcn_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_filters=int(best_params['num_filters']),
        dropout_rate=float(best_params['dropout_rate'])
    )

    start_train = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start_train

    start_infer = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    inference_time = (time.time() - start_infer) / len(X_test)

    # Calculate total testing time
    testing_time = time.time() - start_infer

    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print("\n===== Evaluation =====")
    print(f"Accuracy: {acc:.4f}")
    print("Report:\n", classification_report(y_test, y_pred, digits=4))
    print("Confusion Matrix:\n", cm)

    model.save("temp_model.h5", include_optimizer=False)
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)
    os.remove("temp_model.h5")

    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    ram_usage = psutil.Process(os.getpid()).memory_info().rss / (1024 ** 2)

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f}s")
    print(f"Inference/sample: {inference_time:.6f}s")
    print(f"Testing Time: {testing_time:.2f}s")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Params: {total_params:,}")
    print(f"RAM Usage: {ram_usage:.2f} MB")

    return model, history

# ============================================
# 7. Main
# ============================================
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\jaen_train.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\jaen_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\n Optimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\n Best Params:", best_params)

    print("\n Training Final TCN Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
#  Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_fi... |
# -------------------------------------------------------------------------
# | 1         | 1.0       | 33.98     | 0.4803    | 86.6      | 89.47     |
# | 2         | 1.0       | 23.49     | 0.1624    | 52.9      | 115.2     |
# | 3         | 0.96      | 44.85     | 0.3832    | 51.03     | 125.1     |
# | 4         | 0.96      | 55.96     | 0.1849    | 59.09     | 49.61     |
# | 5         | 1.0       | 30.6      | 0.3099    | 71.6      | 59.96     |
# | 6         | 1.0       | 22.97     | 0.3185    | 53.09     | 116.6     |
# | 7         | 1.0       | 22.24     | 0.4959    | 71.26     | 80.54     |
# | 8         | 1.0       | 19.19     | 0.136     | 92.37     | 66.74     |
# | 9         | 1.0       | 16.28     | 0.4313    | 75.57     | 111.3     |
# | 10        | 1.0       | 16.86     | 0.2711    | 88.25     | 36.35     |
# | 11        | 1.0       | 18.27     | 0.3674    | 99.38     | 128.0     |
# | 12        | 1.0       | 16.86     | 0.3206    | 99.54     | 96.5      |
# | 13        | 1.0       | 59.76     | 0.406     | 99.72     | 110.0     |
# | 14        | 1.0       | 61.77     | 0.4764    | 98.89     | 78.79     |
# | 15        | 1.0       | 39.47     | 0.1101    | 99.96     | 48.81     |
# | 16        | 1.0       | 16.16     | 0.3428    | 50.94     | 64.15     |
# | 17        | 1.0       | 16.03     | 0.273     | 62.75     | 33.16     |
# | 18        | 1.0       | 16.52     | 0.3108    | 50.56     | 94.76     |
# | 19        | 1.0       | 43.03     | 0.1098    | 99.13     | 127.8     |
# | 20        | 0.96      | 62.34     | 0.287     | 100.0     | 33.69     |
# =========================================================================
#
#  Best Params: {'batch_size': 33.977925704673396, 'dropout_rate': 0.4802857225639665, 'epochs': 86.59969709057026, 'num_filters': 89.47121448291551}
#
#  Training Final TCN Model...
# Epoch 1/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.3768 - loss: 1.3571 - val_accuracy: 0.6000 - val_loss: 1.1595
# Epoch 2/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5683 - loss: 1.0947 - val_accuracy: 0.6000 - val_loss: 1.0168
# Epoch 3/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5683 - loss: 1.0005 - val_accuracy: 0.6000 - val_loss: 1.0026
# Epoch 4/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5697 - loss: 0.9347 - val_accuracy: 0.6400 - val_loss: 0.9370
# Epoch 5/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.
86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9760 - loss: 0.0582 - val_accuracy: 1.0000 - val_loss: 0.0469
# Epoch 72/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9576 - loss: 0.0989 - val_accuracy: 1.0000 - val_loss: 0.0426
# Epoch 73/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9869 - loss: 0.0522 - val_accuracy: 1.0000 - val_loss: 0.0408
# Epoch 74/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9907 - loss: 0.0726 - val_accuracy: 1.0000 - val_loss: 0.0409
# Epoch 75/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9637 - loss: 0.0927 - val_accuracy: 1.0000 - val_loss: 0.0393
# Epoch 76/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9765 - loss: 0.0674 - val_accuracy: 1.0000 - val_loss: 0.0386
# Epoch 77/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9905 - loss: 0.0503 - val_accuracy: 1.0000 - val_loss: 0.0355
# Epoch 78/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9801 - loss: 0.0518 - val_accuracy: 1.0000 - val_loss: 0.0345
# Epoch 79/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9420 - loss: 0.1043 - val_accuracy: 1.0000 - val_loss: 0.0362
# Epoch 80/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9770 - loss: 0.0557 - val_accuracy: 1.0000 - val_loss: 0.0341
# Epoch 81/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9892 - loss: 0.0527 - val_accuracy: 1.0000 - val_loss: 0.0328
# Epoch 82/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9863 - loss: 0.0591 - val_accuracy: 1.0000 - val_loss: 0.0343
# Epoch 83/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9817 - loss: 0.0544 - val_accuracy: 1.0000 - val_loss: 0.0354
# Epoch 84/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9832 - loss: 0.0555 - val_accuracy: 1.0000 - val_loss: 0.0350
# Epoch 85/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9907 - loss: 0.0406 - val_accuracy: 1.0000 - val_loss: 0.0329
# Epoch 86/86
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9840 - loss: 0.0528 - val_accuracy: 1.0000 - val_loss: 0.0325
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A3A3D15080> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A3A3D15080> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation =====
# Accuracy: 0.6957
# Report:
#                precision    recall  f1-score   support
#
#            0     0.5294    0.6923    0.6000        13
#            1     0.8966    0.5200    0.6582        50
#            2     0.8692    0.7686    0.8158       121
#            3     0.0000    0.0000    0.0000         0
#
#     accuracy                         0.6957       184
#    macro avg     0.5738    0.4952    0.5185       184
# weighted avg     0.8526    0.6957    0.7577       184
#
# Confusion Matrix:
#  [[ 9  3  0  1]
#  [ 8 26 14  2]
#  [ 0  0 93 28]
#  [ 0  0  0  0]]
#
# ===== Model Metrics =====
# Training Time: 10.79s
# Inference/sample: 0.001549s
# Testing Time: 0.28s
# Model Size: 0.26 MB
# Trainable Params: 59,676
# RAM Usage: 1651.69 MB

# %% [markdown]
# Sevilla station

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import psutil
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Input
import tensorflow as tf
from bayes_opt import BayesianOptimization
from scipy.fftpack import fft
import warnings

# Set seeds
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ============================================
# 1. Data Loading and Preprocessing
# ============================================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # df['month'] = df.index.month
    # df['weekofyear'] = df.index.isocalendar().week
    # df['year'] = df.index.isocalendar().year
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))])
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))])

    df.fillna(df.median(), inplace=True)
    return df, target_col

# ============================================
# 2. Feature Scaling
# ============================================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], X_scaled.shape[1], 1))  # 3D for CNN
    return X_scaled, y, scaler

# ============================================
# 3. Build TCN Model (Dilated CNN)
# ============================================
def build_tcn_model(input_shape, num_classes=4, num_filters=64, kernel_size=3, dropout_rate=0.2, dilation_rate=2):
    model = Sequential()
    
    # Add dilated convolutions
    model.add(Conv1D(filters=num_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, 
                     activation='relu', input_shape=input_shape))
    model.add(Dropout(dropout_rate))
    
    # Add more dilated convolutions if needed
    model.add(Conv1D(filters=num_filters, kernel_size=kernel_size, dilation_rate=dilation_rate, activation='relu'))
    model.add(Dropout(dropout_rate))

    # Flatten and add Dense layers
    model.add(Flatten())
    model.add(Dense(num_filters // 2, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ============================================
# 4. Bayesian Optimization Objective
# ============================================
def objective_function(num_filters, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_tcn_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_filters=int(num_filters),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# ============================================
# 5. Optimize Hyperparameters
# ============================================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_filters': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_filters, dropout_rate, epochs, batch_size: objective_function(
            num_filters, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ============================================
# 6. Train & Evaluate Model
# ============================================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_tcn_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_filters=int(best_params['num_filters']),
        dropout_rate=float(best_params['dropout_rate'])
    )

    start_train = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start_train

    start_infer = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    inference_time = (time.time() - start_infer) / len(X_test)

    # Calculate total testing time
    testing_time = time.time() - start_infer

    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print("\n===== Evaluation =====")
    print(f"Accuracy: {acc:.4f}")
    print("Report:\n", classification_report(y_test, y_pred, digits=4))
    print("Confusion Matrix:\n", cm)

    model.save("temp_model.h5", include_optimizer=False)
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)
    os.remove("temp_model.h5")

    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    ram_usage = psutil.Process(os.getpid()).memory_info().rss / (1024 ** 2)

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f}s")
    print(f"Inference/sample: {inference_time:.6f}s")
    print(f"Testing Time: {testing_time:.2f}s")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Params: {total_params:,}")
    print(f"RAM Usage: {ram_usage:.2f} MB")

    return model, history

# ============================================
# 7. Main
# ============================================
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\sevilla_train.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\sevilla_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\n Optimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\n Best Params:", best_params)

    print("\n Training Final TCN Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
#  Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_fi... |
# -------------------------------------------------------------------------
# | 1         | 1.0       | 33.98     | 0.4803    | 86.6      | 89.47     |
# | 2         | 1.0       | 23.49     | 0.1624    | 52.9      | 115.2     |
# | 3         | 1.0       | 44.85     | 0.3832    | 51.03     | 125.1     |
# | 4         | 0.9857    | 55.96     | 0.1849    | 59.09     | 49.61     |
# | 5         | 1.0       | 30.6      | 0.3099    | 71.6      | 59.96     |
# | 6         | 1.0       | 31.85     | 0.4144    | 54.7      | 125.6     |
# | 7         | 1.0       | 16.22     | 0.1008    | 98.87     | 57.36     |
# | 8         | 1.0       | 24.08     | 0.3354    | 54.27     | 116.3     |
# | 9         | 1.0       | 62.74     | 0.2653    | 99.33     | 126.9     |
# | 10        | 1.0       | 21.2      | 0.3698    | 99.6      | 128.0     |
# | 11        | 1.0       | 16.02     | 0.4903    | 58.02     | 77.58     |
# | 12        | 1.0       | 16.84     | 0.2122    | 76.12     | 33.21     |
# | 13        | 1.0       | 63.77     | 0.3883    | 98.66     | 94.81     |
# | 14        | 1.0       | 63.51     | 0.1726    | 69.92     | 109.0     |
# | 15        | 1.0       | 32.35     | 0.1379    | 99.03     | 32.65     |
# | 16        | 1.0       | 42.5      | 0.1817    | 79.84     | 127.6     |
# | 17        | 1.0       | 16.41     | 0.1579    | 98.83     | 98.28     |
# | 18        | 1.0       | 17.1      | 0.3524    | 78.23     | 66.47     |
# | 19        | 1.0       | 42.31     | 0.4511    | 98.85     | 65.76     |
# | 20        | 1.0       | 39.79     | 0.4936    | 99.34     | 107.9     |
# =========================================================================
#
#  Best Params: {'batch_size': 33.977925704673396, 'dropout_rate': 0.4802857225639665, 'epochs': 86.59969709057026, 'num_filters': 89.47121448291551}
#
#  Training Final TCN Model...
# Epoch 1/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.4544 - loss: 1.2874 - val_accuracy: 0.5143 - val_loss: 1.0738
# Epoch 2/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.4725 - loss: 1.0970 - val_accuracy: 0.5143 - val_loss: 0.9696
# Epoch 3/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5118 - loss: 1.0004 - val_accuracy: 0.8000 - val_loss: 0.8588
# Epoch 4/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7037 - loss: 0.8879 - val_accuracy: 0.8000 - val_loss: 0.6749
# Epoch 5/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7715 - loss: 0.7430 - val_accuracy: 0.8571 - val_loss: 0.5303
# Epoch 6/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7975 - loss: 0.6144 - val_accuracy: 0.8714 - val_loss: 0.4223
# Epoch 7/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8074 - loss: 0.5148 - val_accuracy: 0.8571 - val_loss: 0.3672
# Epoch 8/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8093 - loss: 0.4751 - val_accuracy: 0.8857 - val_loss: 0.3266
# Epoch 9/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8377 - loss: 0.4285 - val_accuracy: 0.8857 - val_loss: 0.3106
# Epoch 10/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8069 - loss: 0.4517 - val_accuracy: 0.8857 - val_loss: 0.2852
# Epoch 11/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8380 - loss: 0.4189 - val_accuracy: 0.9000 - val_loss: 0.2695
# Epoch 12/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8348 - loss: 0.4073 - val_accuracy: 0.8857 - val_loss: 0.2532
# Epoch 13/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8602 - loss: 0.3677 - val_accuracy: 0.8857 - val_loss: 0.2487
# Epoch 14/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8317 - loss: 0.4171 - val_accuracy: 0.8857 - val_loss: 0.2583
# Epoch 15/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8339 - loss: 0.3875 - val_accuracy: 0.9143 - val_loss: 0.2428
# Epoch 16/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8501 - loss: 0.3624 - val_accuracy: 0.9000 - val_loss: 0.2410
# Epoch 17/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8810 - loss: 0.3661 - val_accuracy: 0.9143 - val_loss: 0.2322
# Epoch 18/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8659 - loss: 0.3262 - val_accuracy: 0.9286 - val_loss: 0.2191
# Epoch 19/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8868 - loss: 0.3149 - val_accuracy: 0.9143 - val_loss: 0.2098
# Epoch 20/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8876 - loss: 0.2890 - val_accuracy: 0.9286 - val_loss: 0.2028
# Epoch 21/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9118 - loss: 0.2545 - val_accuracy: 0.9286 - val_loss: 0.1930
# Epoch 22/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8839 - loss: 0.3012 - val_accuracy: 0.9286 - val_loss: 0.1812
# Epoch 23/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.
86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9242 - loss: 0.1732 - val_accuracy: 0.9714 - val_loss: 0.0678
# Epoch 56/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9769 - loss: 0.1101 - val_accuracy: 0.9857 - val_loss: 0.0535
# Epoch 57/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9725 - loss: 0.1000 - val_accuracy: 0.9714 - val_loss: 0.0543
# Epoch 58/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9660 - loss: 0.1028 - val_accuracy: 0.9857 - val_loss: 0.0482
# Epoch 59/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9533 - loss: 0.1277 - val_accuracy: 0.9857 - val_loss: 0.0563
# Epoch 60/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9433 - loss: 0.1331 - val_accuracy: 0.9857 - val_loss: 0.0571
# Epoch 61/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9790 - loss: 0.0842 - val_accuracy: 0.9857 - val_loss: 0.0500
# Epoch 62/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9486 - loss: 0.1099 - val_accuracy: 0.9857 - val_loss: 0.0490
# Epoch 63/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9581 - loss: 0.1261 - val_accuracy: 0.9857 - val_loss: 0.0364
# Epoch 64/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9611 - loss: 0.1045 - val_accuracy: 0.9857 - val_loss: 0.0323
# Epoch 65/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9720 - loss: 0.1046 - val_accuracy: 0.9857 - val_loss: 0.0310
# Epoch 66/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9648 - loss: 0.0984 - val_accuracy: 0.9857 - val_loss: 0.0306
# Epoch 67/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9739 - loss: 0.0799 - val_accuracy: 0.9857 - val_loss: 0.0391
# Epoch 68/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9685 - loss: 0.1020 - val_accuracy: 0.9857 - val_loss: 0.0289
# Epoch 69/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9733 - loss: 0.0735 - val_accuracy: 1.0000 - val_loss: 0.0265
# Epoch 70/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9758 - loss: 0.0849 - val_accuracy: 0.9857 - val_loss: 0.0250
# Epoch 71/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9682 - loss: 0.0957 - val_accuracy: 1.0000 - val_loss: 0.0225
# Epoch 72/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9612 - loss: 0.1066 - val_accuracy: 1.0000 - val_loss: 0.0233
# Epoch 73/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9705 - loss: 0.0853 - val_accuracy: 1.0000 - val_loss: 0.0246
# Epoch 74/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9795 - loss: 0.0694 - val_accuracy: 1.0000 - val_loss: 0.0197
# Epoch 75/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9618 - loss: 0.0903 - val_accuracy: 0.9857 - val_loss: 0.0233
# Epoch 76/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9809 - loss: 0.0603 - val_accuracy: 1.0000 - val_loss: 0.0186
# Epoch 77/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9658 - loss: 0.0749 - val_accuracy: 1.0000 - val_loss: 0.0156
# Epoch 78/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9751 - loss: 0.0672 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 79/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9851 - loss: 0.0510 - val_accuracy: 0.9857 - val_loss: 0.0226
# Epoch 80/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9885 - loss: 0.0564 - val_accuracy: 1.0000 - val_loss: 0.0194
# Epoch 81/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9751 - loss: 0.0648 - val_accuracy: 0.9857 - val_loss: 0.0216
# Epoch 82/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9738 - loss: 0.0826 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 83/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9734 - loss: 0.0482 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 84/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9644 - loss: 0.0707 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 85/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9849 - loss: 0.0437 - val_accuracy: 1.0000 - val_loss: 0.0123
# Epoch 86/86
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9893 - loss: 0.0359 - val_accuracy: 1.0000 - val_loss: 0.0065
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A3BD02E200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001A3BD02E200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation =====
# Accuracy: 0.9238
# Report:
#                precision    recall  f1-score   support
#
#            0     0.5000    0.3000    0.3750        10
#            1     0.9114    0.9474    0.9290        76
#            2     0.9840    0.9609    0.9723       128
#            3     0.6154    0.8889    0.7273         9
#
#     accuracy                         0.9238       223
#    macro avg     0.7527    0.7743    0.7509       223
# weighted avg     0.9227    0.9238    0.9209       223
#
# Confusion Matrix:
#  [[  3   7   0   0]
#  [  3  72   1   0]
#  [  0   0 123   5]
#  [  0   0   1   8]]
#
# ===== Model Metrics =====
# Training Time: 12.66s
# Inference/sample: 0.000942s
# Testing Time: 0.21s
# Model Size: 0.26 MB
# Trainable Params: 59,676
# RAM Usage: 1930.36 MB
