# %% [markdown]
# Final Code with all feature engineering techniques

# %% [markdown]
# BM + Lag + RWS + TBF + TLS + STL + Fourier

# %% [markdown]
# BM + Lag + RWS + TBF + EMA  + Rolling Correlation (RC) + Fourier

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    df['month'] = df.index.month                        # Useful for seasonal crop cycles
    df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # Smooth cyclical encoding for week-of-year (annual periodicity)
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    fft_values = fft(df[target_col].dropna().values)
    fft_real = np.real(fft_values)[:len(df[target_col])]
    fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.9355
# | 1         | 0.9355    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=1.0000
# | 2         | 1.0       | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.9516
# | 3         | 0.9516    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=1.0000
# | 4         | 1.0       | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=1.0000
# | 5         | 1.0       | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=71.06039001196841, dropout=0.42701296638324826, activation=relu, epochs=99.49460811199373, batch_size=18.130972718527694 => val_accuracy=1.0000
# | 6         | 1.0       | 0.9629    | 18.13     | 0.427     | 99.49     | 71.06     |
# Trying: units=76.14300960455571, dropout=0.30245415225722905, activation=relu, epochs=67.61524136815626, batch_size=21.842126924684578 => val_accuracy=1.0000
# | 7         | 1.0       | 0.1289    | 21.84     | 0.3025    | 67.62     | 76.14     |
# Trying: units=127.21732660431488, dropout=0.4933376879708927, activation=tanh, epochs=99.20900250728519, batch_size=57.28368987539639 => val_accuracy=1.0000
# | 8         | 1.0       | 1.748     | 57.28     | 0.4933    | 99.21     | 127.2     |
# Trying: units=126.97470491578986, dropout=0.2718699409013534, activation=relu, epochs=50.50210115877908, batch_size=48.99527192551361 => val_accuracy=0.9677
# | 9         | 0.9677    | 0.2615    | 49.0      | 0.2719    | 50.5      | 127.0     |
# Trying: units=36.50127636451891, dropout=0.22532073422446414, activation=relu, epochs=51.2142050106308, batch_size=16.00477708890147 => val_accuracy=0.9839
# | 10        | 0.9839    | 0.99      | 16.0      | 0.2253    | 51.21     | 36.5      |
# Trying: units=126.39289909693534, dropout=0.3234624880977848, activation=relu, epochs=98.5087931353597, batch_size=16.678278786995513 => val_accuracy=1.0000
# | 11        | 1.0       | 0.1994    | 16.68     | 0.3235    | 98.51     | 126.4     |
# Trying: units=100.02266521890265, dropout=0.4930284798416661, activation=tanh, epochs=99.95740760211447, batch_size=37.56494089959968 => val_accuracy=1.0000
# | 12        | 1.0       | 1.801     | 37.56     | 0.493     | 99.96     | 100.0     |
# Trying: units=33.93355495104366, dropout=0.154772436228266, activation=tanh, epochs=97.35515633207471, batch_size=17.4426045964175 => val_accuracy=0.9839
# | 13        | 0.9839    | 1.144     | 17.44     | 0.1548    | 97.36     | 33.93     |
# Trying: units=101.03269911177551, dropout=0.19629102454379993, activation=tanh, epochs=99.56158503627685, batch_size=16.007435618485715 => val_accuracy=1.0000
# | 14        | 1.0       | 1.053     | 16.01     | 0.1963    | 99.56     | 101.0     |
# Trying: units=59.73497225791671, dropout=0.15167398958280592, activation=tanh, epochs=76.24205259369084, batch_size=16.34711037307793 => val_accuracy=1.0000
# | 15        | 1.0       | 1.133     | 16.35     | 0.1517    | 76.24     | 59.73     |
# Trying: units=104.59255757874153, dropout=0.22943185027961507, activation=tanh, epochs=98.96961945555914, batch_size=63.38960372209996 => val_accuracy=1.0000
# | 16        | 1.0       | 1.242     | 63.39     | 0.2294    | 98.97     | 104.6     |
# Trying: units=126.23515861506021, dropout=0.3027723455731802, activation=relu, epochs=69.5051315339233, batch_size=16.30628368924077 => val_accuracy=1.0000
# | 17        | 1.0       | 0.9957    | 16.31     | 0.3028    | 69.51     | 126.2     |
# Trying: units=101.44108306197407, dropout=0.41472681151213797, activation=relu, epochs=52.182750897480936, batch_size=16.99300262939415 => val_accuracy=1.0000
# | 18        | 1.0       | 0.3921    | 16.99     | 0.4147    | 52.18     | 101.4     |
# Trying: units=69.37765921887136, dropout=0.3350695834858739, activation=tanh, epochs=50.19349467699993, batch_size=23.99482395543685 => val_accuracy=0.9839
# | 19        | 0.9839    | 1.753     | 23.99     | 0.3351    | 50.19     | 69.38     |
# Trying: units=125.38161235820145, dropout=0.3872219452009067, activation=relu, epochs=87.34086718633966, batch_size=36.59798400013662 => val_accuracy=1.0000
# | 20        | 1.0       | 0.7429    | 36.6      | 0.3872    | 87.34     | 125.4     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3496 - loss: 1.3322 - val_accuracy: 0.5806 - val_loss: 1.0049
# Epoch 2/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5366 - loss: 1.0129 - val_accuracy: 0.5806 - val_loss: 0.8501
# Epoch 3/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6086 - loss: 0.8779 - val_accuracy: 0.6935 - val_loss: 0.7182
# Epoch 4/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7304 - loss: 0.7772 - val_accuracy: 0.7903 - val_loss: 0.6032
# Epoch 5/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7732 - loss: 0.6345 - val_accuracy: 0.8871 - val_loss: 0.4935
# Epoch 6/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8449 - loss: 0.5851 - val_accuracy: 0.9194 - val_loss: 0.4080
# Epoch 7/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8870 - loss: 0.4537 - val_accuracy: 0.9355 - val_loss: 0.3382
# Epoch 8/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8671 - loss: 0.3726 - val_accuracy: 0.9194 - val_loss: 0.2889
# Epoch 9/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8971 - loss: 0.3211 - val_accuracy: 0.9032 - val_loss: 0.2626
# Epoch 10/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9193 - loss: 0.3112 - val_accuracy: 0.9355 - val_loss: 0.2218
# Epoch 11/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9530 - loss: 0.2272 - val_accuracy: 0.9032 - val_loss: 0.2301
# Epoch 12/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8887 - loss: 0.3025 - val_accuracy: 0.9355 - val_loss: 0.1923
# Epoch 13/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9251 - loss: 0.2259 - val_accuracy: 0.9516 - val_loss: 0.1774
# Epoch 14/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9559 - loss: 0.1815 - val_accuracy: 0.9355 - val_loss: 0.1676
# Epoch 15/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9561 - loss: 0.1884 - val_accuracy: 0.9516 - val_loss: 0.1592
# Epoch 16/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9145 - loss: 0.2105 - val_accuracy: 0.9194 - val_loss: 0.1583
# Epoch 17/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9444 - loss: 0.1983 - val_accuracy: 0.9355 - val_loss: 0.1405
# Epoch 18/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9512 - loss: 0.1745 - val_accuracy: 0.9677 - val_loss: 0.1391
# Epoch 19/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9585 - loss: 0.1421 - val_accuracy: 0.9677 - val_loss: 0.1255
# Epoch 20/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9656 - loss: 0.1357 - val_accuracy: 0.9516 - val_loss: 0.1284
# Epoch 21/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9656 - loss: 0.1310 - val_accuracy: 0.9516 - val_loss: 0.1228
# Epoch 22/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9511 - loss: 0.1515 - val_accuracy: 0.9516 - val_loss: 0.1081
# Epoch 23/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9489 - loss: 0.1425 - val_accuracy: 0.9677 - val_loss: 0.1105
# Epoch 24/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9633 - loss: 0.1182 - val_accuracy: 0.9516 - val_loss: 0.1048
# Epoch 25/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 0.1026 - val_accuracy: 0.9516 - val_loss: 0.1075
# Epoch 26/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9494 - loss: 0.1284 - val_accuracy: 0.9516 - val_loss: 0.0958
# Epoch 27/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9558 - loss: 0.1488 - val_accuracy: 0.9516 - val_loss: 0.0990
# Epoch 28/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9799 - loss: 0.0950 - val_accuracy: 0.9677 - val_loss: 0.0900
# Epoch 29/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9743 - loss: 0.0871 - val_accuracy: 0.9677 - val_loss: 0.0828
# Epoch 30/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9753 - loss: 0.0868 - val_accuracy: 0.9677 - val_loss: 0.0817
# Epoch 31/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9638 - loss: 0.1091 - val_accuracy: 0.9677 - val_loss: 0.0759
# Epoch 32/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9743 - loss: 0.0861 - val_accuracy: 0.9677 - val_loss: 0.0787
# Epoch 33/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9673 - loss: 0.0738 - val_accuracy: 0.9516 - val_loss: 0.0829
# Epoch 34/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9635 - loss: 0.0906 - val_accuracy: 0.9677 - val_loss: 0.0770
# Epoch 35/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9755 - loss: 0.0816 - val_accuracy: 0.9839 - val_loss: 0.0717
# Epoch 36/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9770 - loss: 0.0915 - val_accuracy: 0.9677 - val_loss: 0.0771
# Epoch 37/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9696 - loss: 0.0876 - val_accuracy: 0.9839 - val_loss: 0.0677
# Epoch 38/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0564 - val_accuracy: 0.9839 - val_loss: 0.0627
# Epoch 39/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9819 - loss: 0.0598 - val_accuracy: 0.9677 - val_loss: 0.0739
# Epoch 40/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9727 - loss: 0.0753 - val_accuracy: 1.0000 - val_loss: 0.0535
# Epoch 41/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9794 - loss: 0.0739 - val_accuracy: 0.9839 - val_loss: 0.0703
# Epoch 42/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9904 - loss: 0.0658 - val_accuracy: 0.9839 - val_loss: 0.0540
# Epoch 43/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0501 - val_accuracy: 1.0000 - val_loss: 0.0495
# Epoch 44/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9799 - loss: 0.0751 - val_accuracy: 0.9839 - val_loss: 0.0576
# Epoch 45/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9829 - loss: 0.0607 - val_accuracy: 0.9839 - val_loss: 0.0562
# Epoch 46/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9762 - loss: 0.0618 - val_accuracy: 0.9677 - val_loss: 0.0585
# Epoch 47/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0636 - val_accuracy: 0.9839 - val_loss: 0.0584
# Epoch 48/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9839 - loss: 0.0565 - val_accuracy: 0.9839 - val_loss: 0.0478
# Epoch 49/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9882 - loss: 0.0588 - val_accuracy: 1.0000 - val_loss: 0.0470
# Epoch 50/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9789 - loss: 0.0665 - val_accuracy: 0.9839 - val_loss: 0.0546
# Epoch 51/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9682 - loss: 0.0794 - val_accuracy: 0.9839 - val_loss: 0.0514
# Epoch 52/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9869 - loss: 0.0480 - val_accuracy: 0.9839 - val_loss: 0.0491
# Epoch 53/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9892 - loss: 0.0507 - val_accuracy: 1.0000 - val_loss: 0.0394
# Epoch 54/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9712 - loss: 0.0654 - val_accuracy: 0.9839 - val_loss: 0.0458
# Epoch 55/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9864 - loss: 0.0501 - val_accuracy: 0.9839 - val_loss: 0.0457
# Epoch 56/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9878 - loss: 0.0485 - val_accuracy: 1.0000 - val_loss: 0.0351
# Epoch 57/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9859 - loss: 0.0390 - val_accuracy: 1.0000 - val_loss: 0.0431
# Epoch 58/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0576 - val_accuracy: 0.9677 - val_loss: 0.0571
# Epoch 59/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9725 - loss: 0.0665 - val_accuracy: 0.9839 - val_loss: 0.0433
# Epoch 60/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9966 - loss: 0.0313 - val_accuracy: 0.9677 - val_loss: 0.0554
# Epoch 61/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9956 - loss: 0.0433 - val_accuracy: 0.9677 - val_loss: 0.0593
# Epoch 62/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9765 - loss: 0.0494 - val_accuracy: 1.0000 - val_loss: 0.0352
# Epoch 63/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9829 - loss: 0.0551 - val_accuracy: 1.0000 - val_loss: 0.0456
# Epoch 64/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9741 - loss: 0.0571 - val_accuracy: 0.9677 - val_loss: 0.0537
# Epoch 65/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0365 - val_accuracy: 0.9677 - val_loss: 0.0640
# Epoch 66/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0558 - val_accuracy: 1.0000 - val_loss: 0.0356
# Epoch 67/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9877 - loss: 0.0401 - val_accuracy: 0.9839 - val_loss: 0.0533
# Epoch 68/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9974 - loss: 0.0326 - val_accuracy: 0.9839 - val_loss: 0.0455
# Epoch 69/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9891 - loss: 0.0341 - val_accuracy: 0.9839 - val_loss: 0.0544
# Epoch 70/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9826 - loss: 0.0486 - val_accuracy: 0.9839 - val_loss: 0.0367
# Epoch 71/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9808 - loss: 0.0521 - val_accuracy: 0.9839 - val_loss: 0.0365
# Epoch 72/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9857 - loss: 0.0409 - val_accuracy: 0.9839 - val_loss: 0.0416
# Epoch 73/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.0450 - val_accuracy: 1.0000 - val_loss: 0.0368
# Epoch 74/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9937 - loss: 0.0333 - val_accuracy: 0.9839 - val_loss: 0.0375
# Epoch 75/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9868 - loss: 0.0477 - val_accuracy: 1.0000 - val_loss: 0.0280
# Epoch 76/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9891 - loss: 0.0385 - val_accuracy: 0.9839 - val_loss: 0.0283
# Epoch 77/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.0280 - val_accuracy: 1.0000 - val_loss: 0.0336
# Epoch 78/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9714 - loss: 0.0483 - val_accuracy: 1.0000 - val_loss: 0.0281
# Epoch 79/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9894 - loss: 0.0373 - val_accuracy: 0.9839 - val_loss: 0.0503
# Epoch 80/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9827 - loss: 0.0470 - val_accuracy: 1.0000 - val_loss: 0.0231
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.9138
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7143    0.2941    0.4167        17
#            1     0.7778    0.9333    0.8485        45
#            2     0.9902    1.0000    0.9951       101
#            3     1.0000    1.0000    1.0000        11
#
#     accuracy                         0.9138       174
#    macro avg     0.8706    0.8069    0.8151       174
# weighted avg     0.9089    0.9138    0.9010       174
#
#
# Confusion Matrix:
# [[  5  12   0   0]
#  [  2  42   1   0]
#  [  0   0 101   0]
#  [  0   0   0  11]]
# Total instances: 174
# Shape of test set: X_test=(174, 28), y_test=(174,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion matrix total: 174

# %% [markdown]
# BM + Lag + RWS + TBF + EMA  + Rolling Correlation (RC)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    df['month'] = df.index.month                        # Useful for seasonal crop cycles
    df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # Smooth cyclical encoding for week-of-year (annual periodicity)
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.9194
# | 1         | 0.9194    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=1.0000
# | 2         | 1.0       | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.9516
# | 3         | 0.9516    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.9839
# | 4         | 0.9839    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9839
# | 5         | 0.9839    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=84.75483544592163, dropout=0.1540665156619291, activation=relu, epochs=98.15575557945868, batch_size=17.238971533575373 => val_accuracy=1.0000
# | 6         | 1.0       | 0.1363    | 17.24     | 0.1541    | 98.16     | 84.75     |
# Trying: units=101.48738693066764, dropout=0.10739328000529058, activation=tanh, epochs=80.02528666528657, batch_size=18.362493503684107 => val_accuracy=1.0000
# | 7         | 1.0       | 1.632     | 18.36     | 0.1074    | 80.03     | 101.5     |
# Trying: units=127.47632717021833, dropout=0.3020553989213859, activation=tanh, epochs=99.27363388620901, batch_size=41.02136364212041 => val_accuracy=1.0000
# | 8         | 1.0       | 1.658     | 41.02     | 0.3021    | 99.27     | 127.5     |
# Trying: units=127.98580288369398, dropout=0.2108486047441157, activation=relu, epochs=55.7436850087901, batch_size=50.778284686427824 => val_accuracy=1.0000
# | 9         | 1.0       | 0.5004    | 50.78     | 0.2108    | 55.74     | 128.0     |
# Trying: units=127.45394253977202, dropout=0.4445536440274934, activation=tanh, epochs=50.74549660065429, batch_size=17.13376494864312 => val_accuracy=1.0000
# | 10        | 1.0       | 1.928     | 17.13     | 0.4446    | 50.75     | 127.5     |
# Trying: units=33.132980330843154, dropout=0.44379453631093824, activation=tanh, epochs=50.44546390905534, batch_size=19.456300234708873 => val_accuracy=0.9516
# | 11        | 0.9516    | 1.518     | 19.46     | 0.4438    | 50.45     | 33.13     |
# Trying: units=108.21177365528803, dropout=0.3308251362681637, activation=relu, epochs=85.59310966999095, batch_size=62.20429735220932 => val_accuracy=1.0000
# | 12        | 1.0       | 0.1007    | 62.2      | 0.3308    | 85.59     | 108.2     |
# Trying: units=99.07864396670485, dropout=0.21630115621931642, activation=tanh, epochs=50.65536863437313, batch_size=63.906993103453416 => val_accuracy=0.9677
# | 13        | 0.9677    | 1.373     | 63.91     | 0.2163    | 50.66     | 99.08     |
# Trying: units=127.96830554076595, dropout=0.2863988541824792, activation=relu, epochs=75.9409196976143, batch_size=32.00131403954819 => val_accuracy=1.0000
# | 14        | 1.0       | 0.3238    | 32.0      | 0.2864    | 75.94     | 128.0     |
# Trying: units=98.75609533773766, dropout=0.3575765867195332, activation=relu, epochs=99.60876536830374, batch_size=40.45587909209243 => val_accuracy=1.0000
# | 15        | 1.0       | 0.5982    | 40.46     | 0.3576    | 99.61     | 98.76     |
# Trying: units=124.78346814780416, dropout=0.49306302495348997, activation=tanh, epochs=99.91420992818885, batch_size=17.177836830931717 => val_accuracy=1.0000
# | 16        | 1.0       | 1.126     | 17.18     | 0.4931    | 99.91     | 124.8     |
# Trying: units=126.79935790179134, dropout=0.4279367903846715, activation=tanh, epochs=99.80547876118992, batch_size=63.93191954695592 => val_accuracy=0.9839
# | 17        | 0.9839    | 1.583     | 63.93     | 0.4279    | 99.81     | 126.8     |
# Trying: units=42.18647031172424, dropout=0.4942526361575236, activation=tanh, epochs=99.22251083736745, batch_size=16.18264744305158 => val_accuracy=0.9839
# | 18        | 0.9839    | 1.926     | 16.18     | 0.4943    | 99.22     | 42.19     |
# Trying: units=107.56222668124951, dropout=0.1951105944795658, activation=tanh, epochs=77.15351688041183, batch_size=42.464630259250704 => val_accuracy=0.9839
# | 19        | 0.9839    | 1.189     | 42.46     | 0.1951    | 77.15     | 107.6     |
# Trying: units=94.15758989464571, dropout=0.44207353364425395, activation=tanh, epochs=98.94478999998304, batch_size=62.67434880837768 => val_accuracy=0.9839
# | 20        | 0.9839    | 1.661     | 62.67     | 0.4421    | 98.94     | 94.16     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.2933 - loss: 1.3261 - val_accuracy: 0.5806 - val_loss: 1.0585
# Epoch 2/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5642 - loss: 1.0483 - val_accuracy: 0.5806 - val_loss: 0.9185
# Epoch 3/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5830 - loss: 0.9282 - val_accuracy: 0.6290 - val_loss: 0.7757
# Epoch 4/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7524 - loss: 0.7983 - val_accuracy: 0.7258 - val_loss: 0.6375
# Epoch 5/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7589 - loss: 0.6896 - val_accuracy: 0.7581 - val_loss: 0.5331
# Epoch 6/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8037 - loss: 0.5918 - val_accuracy: 0.8548 - val_loss: 0.4420
# Epoch 7/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8509 - loss: 0.5014 - val_accuracy: 0.8548 - val_loss: 0.3865
# Epoch 8/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9150 - loss: 0.4177 - val_accuracy: 0.9032 - val_loss: 0.3228
# Epoch 9/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8834 - loss: 0.3884 - val_accuracy: 0.8871 - val_loss: 0.2979
# Epoch 10/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9010 - loss: 0.3270 - val_accuracy: 0.9194 - val_loss: 0.2552
# Epoch 11/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9094 - loss: 0.2692 - val_accuracy: 0.9355 - val_loss: 0.2362
# Epoch 12/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8954 - loss: 0.2764 - val_accuracy: 0.9355 - val_loss: 0.2198
# Epoch 13/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9251 - loss: 0.2248 - val_accuracy: 0.9194 - val_loss: 0.2006
# Epoch 14/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9467 - loss: 0.2077 - val_accuracy: 0.9516 - val_loss: 0.1769
# Epoch 15/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9367 - loss: 0.2081 - val_accuracy: 0.9355 - val_loss: 0.1690
# Epoch 16/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9444 - loss: 0.1746 - val_accuracy: 0.9355 - val_loss: 0.1641
# Epoch 17/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9481 - loss: 0.1752 - val_accuracy: 0.9516 - val_loss: 0.1589
# Epoch 18/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9591 - loss: 0.1522 - val_accuracy: 0.9355 - val_loss: 0.1540
# Epoch 19/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9411 - loss: 0.1707 - val_accuracy: 0.9516 - val_loss: 0.1396
# Epoch 20/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9428 - loss: 0.1718 - val_accuracy: 0.9677 - val_loss: 0.1327
# Epoch 21/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9494 - loss: 0.1665 - val_accuracy: 0.9677 - val_loss: 0.1231
# Epoch 22/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9636 - loss: 0.1422 - val_accuracy: 0.9677 - val_loss: 0.1146
# Epoch 23/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9652 - loss: 0.1364 - val_accuracy: 0.9677 - val_loss: 0.1101
# Epoch 24/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9586 - loss: 0.1171 - val_accuracy: 0.9677 - val_loss: 0.1084
# Epoch 25/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9694 - loss: 0.1135 - val_accuracy: 0.9677 - val_loss: 0.1019
# Epoch 26/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9711 - loss: 0.1096 - val_accuracy: 0.9839 - val_loss: 0.0984
# Epoch 27/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9677 - loss: 0.1091 - val_accuracy: 0.9839 - val_loss: 0.0975
# Epoch 28/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9636 - loss: 0.1199 - val_accuracy: 0.9677 - val_loss: 0.0858
# Epoch 29/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9670 - loss: 0.1056 - val_accuracy: 0.9839 - val_loss: 0.0927
# Epoch 30/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9725 - loss: 0.1136 - val_accuracy: 0.9677 - val_loss: 0.0785
# Epoch 31/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9755 - loss: 0.0928 - val_accuracy: 0.9839 - val_loss: 0.0814
# Epoch 32/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9718 - loss: 0.1135 - val_accuracy: 0.9839 - val_loss: 0.0836
# Epoch 33/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9614 - loss: 0.0933 - val_accuracy: 0.9839 - val_loss: 0.0787
# Epoch 34/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9796 - loss: 0.0947 - val_accuracy: 0.9839 - val_loss: 0.0726
# Epoch 35/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9682 - loss: 0.0959 - val_accuracy: 0.9839 - val_loss: 0.0732
# Epoch 36/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9570 - loss: 0.1046 - val_accuracy: 0.9839 - val_loss: 0.0702
# Epoch 37/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9608 - loss: 0.0748 - val_accuracy: 1.0000 - val_loss: 0.0684
# Epoch 38/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9582 - loss: 0.1111 - val_accuracy: 1.0000 - val_loss: 0.0606
# Epoch 39/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9650 - loss: 0.0845 - val_accuracy: 1.0000 - val_loss: 0.0578
# Epoch 40/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9654 - loss: 0.1065 - val_accuracy: 1.0000 - val_loss: 0.0609
# Epoch 41/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9678 - loss: 0.0799 - val_accuracy: 1.0000 - val_loss: 0.0601
# Epoch 42/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9806 - loss: 0.0776 - val_accuracy: 1.0000 - val_loss: 0.0529
# Epoch 43/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9718 - loss: 0.0901 - val_accuracy: 0.9839 - val_loss: 0.0631
# Epoch 44/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9558 - loss: 0.0863 - val_accuracy: 1.0000 - val_loss: 0.0518
# Epoch 45/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9791 - loss: 0.0785 - val_accuracy: 1.0000 - val_loss: 0.0514
# Epoch 46/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9845 - loss: 0.0593 - val_accuracy: 1.0000 - val_loss: 0.0486
# Epoch 47/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9877 - loss: 0.0550 - val_accuracy: 1.0000 - val_loss: 0.0482
# Epoch 48/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9931 - loss: 0.0438 - val_accuracy: 1.0000 - val_loss: 0.0441
# Epoch 49/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9530 - loss: 0.0765 - val_accuracy: 1.0000 - val_loss: 0.0502
# Epoch 50/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9828 - loss: 0.0588 - val_accuracy: 1.0000 - val_loss: 0.0428
# Epoch 51/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9764 - loss: 0.0554 - val_accuracy: 1.0000 - val_loss: 0.0377
# Epoch 52/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9717 - loss: 0.0721 - val_accuracy: 1.0000 - val_loss: 0.0370
# Epoch 53/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9812 - loss: 0.0434 - val_accuracy: 1.0000 - val_loss: 0.0508
# Epoch 54/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9749 - loss: 0.0680 - val_accuracy: 1.0000 - val_loss: 0.0413
# Epoch 55/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9966 - loss: 0.0568 - val_accuracy: 1.0000 - val_loss: 0.0384
# Epoch 56/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9833 - loss: 0.0570 - val_accuracy: 1.0000 - val_loss: 0.0450
# Epoch 57/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9893 - loss: 0.0479 - val_accuracy: 1.0000 - val_loss: 0.0370
# Epoch 58/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9811 - loss: 0.0526 - val_accuracy: 1.0000 - val_loss: 0.0372
# Epoch 59/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9728 - loss: 0.0738 - val_accuracy: 1.0000 - val_loss: 0.0368
# Epoch 60/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9839 - loss: 0.0444 - val_accuracy: 1.0000 - val_loss: 0.0353
# Epoch 61/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9895 - loss: 0.0468 - val_accuracy: 1.0000 - val_loss: 0.0332
# Epoch 62/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9897 - loss: 0.0432 - val_accuracy: 1.0000 - val_loss: 0.0367
# Epoch 63/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9747 - loss: 0.0548 - val_accuracy: 1.0000 - val_loss: 0.0388
# Epoch 64/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9850 - loss: 0.0430 - val_accuracy: 1.0000 - val_loss: 0.0341
# Epoch 65/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9833 - loss: 0.0385 - val_accuracy: 1.0000 - val_loss: 0.0287
# Epoch 66/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9835 - loss: 0.0494 - val_accuracy: 1.0000 - val_loss: 0.0365
# Epoch 67/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9950 - loss: 0.0536 - val_accuracy: 1.0000 - val_loss: 0.0362
# Epoch 68/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9741 - loss: 0.0553 - val_accuracy: 1.0000 - val_loss: 0.0339
# Epoch 69/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9950 - loss: 0.0324 - val_accuracy: 1.0000 - val_loss: 0.0249
# Epoch 70/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9825 - loss: 0.0488 - val_accuracy: 1.0000 - val_loss: 0.0414
# Epoch 71/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9942 - loss: 0.0289 - val_accuracy: 1.0000 - val_loss: 0.0381
# Epoch 72/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9800 - loss: 0.0739 - val_accuracy: 1.0000 - val_loss: 0.0299
# Epoch 73/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9740 - loss: 0.0708 - val_accuracy: 1.0000 - val_loss: 0.0279
# Epoch 74/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9974 - loss: 0.0275 - val_accuracy: 1.0000 - val_loss: 0.0280
# Epoch 75/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9831 - loss: 0.0406 - val_accuracy: 1.0000 - val_loss: 0.0373
# Epoch 76/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.0396 - val_accuracy: 0.9839 - val_loss: 0.0463
# Epoch 77/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9775 - loss: 0.0405 - val_accuracy: 1.0000 - val_loss: 0.0284
# Epoch 78/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9939 - loss: 0.0379 - val_accuracy: 1.0000 - val_loss: 0.0290
# Epoch 79/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.0321 - val_accuracy: 1.0000 - val_loss: 0.0360
# Epoch 80/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9880 - loss: 0.0336 - val_accuracy: 1.0000 - val_loss: 0.0257
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.8966
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6667    0.1176    0.2000        17
#            1     0.7368    0.9333    0.8235        45
#            2     0.9806    1.0000    0.9902       101
#            3     1.0000    1.0000    1.0000        11
#
#     accuracy                         0.8966       174
#    macro avg     0.8460    0.7627    0.7534       174
# weighted avg     0.8881    0.8966    0.8705       174
#
#
# Confusion Matrix:
# [[  2  15   0   0]
#  [  1  42   2   0]
#  [  0   0 101   0]
#  [  0   0   0  11]]
# Total instances: 174
# Shape of test set: X_test=(174, 26), y_test=(174,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Confusion matrix total: 174

# %% [markdown]
# BM + Lag + RWS + TBF + EMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    df['month'] = df.index.month                        # Useful for seasonal crop cycles
    df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # Smooth cyclical encoding for week-of-year (annual periodicity)
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.9032
# | 1         | 0.9032    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=1.0000
# | 2         | 1.0       | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.9355
# | 3         | 0.9355    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=1.0000
# | 4         | 1.0       | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9839
# | 5         | 0.9839    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=78.31293097821562, dropout=0.4452145972977004, activation=relu, epochs=96.13467567214664, batch_size=20.98484677274213 => val_accuracy=1.0000
# | 6         | 1.0       | 0.7781    | 20.98     | 0.4452    | 96.13     | 78.31     |
# Trying: units=59.586264222326186, dropout=0.3415818125622894, activation=tanh, epochs=72.55129157458026, batch_size=31.442147899343865 => val_accuracy=0.9839
# | 7         | 0.9839    | 1.614     | 31.44     | 0.3416    | 72.55     | 59.59     |
# Trying: units=61.64544966843079, dropout=0.1564752859397432, activation=relu, epochs=67.0139133585285, batch_size=24.880904178544306 => val_accuracy=1.0000
# | 8         | 1.0       | 0.2519    | 24.88     | 0.1565    | 67.01     | 61.65     |
# Trying: units=65.55306189353806, dropout=0.13665207424076212, activation=relu, epochs=63.373694147670456, batch_size=33.81575092595814 => val_accuracy=0.9839
# | 9         | 0.9839    | 0.7737    | 33.82     | 0.1367    | 63.37     | 65.55     |
# Trying: units=89.0274332827876, dropout=0.30702773533987315, activation=tanh, epochs=86.00355539357072, batch_size=18.32951076421788 => val_accuracy=1.0000
# | 10        | 1.0       | 1.045     | 18.33     | 0.307     | 86.0      | 89.03     |
# Trying: units=88.75804439777562, dropout=0.39358404979153583, activation=relu, epochs=95.26396385340583, batch_size=26.886472916176643 => val_accuracy=1.0000
# | 11        | 1.0       | 0.8543    | 26.89     | 0.3936    | 95.26     | 88.76     |
# Trying: units=99.35997381180827, dropout=0.3211045984293549, activation=relu, epochs=95.77542818546743, batch_size=17.59248334945621 => val_accuracy=1.0000
# | 12        | 1.0       | 0.8702    | 17.59     | 0.3211    | 95.78     | 99.36     |
# Trying: units=99.91780876841851, dropout=0.43213517338238583, activation=tanh, epochs=88.3696469153075, batch_size=29.596656021257242 => val_accuracy=0.9839
# | 13        | 0.9839    | 1.781     | 29.6      | 0.4321    | 88.37     | 99.92     |
# Trying: units=88.39302774974178, dropout=0.3909874980187543, activation=tanh, epochs=97.69335930280332, batch_size=16.1519684182444 => val_accuracy=0.9839
# | 14        | 0.9839    | 1.811     | 16.15     | 0.391     | 97.69     | 88.39     |
# Trying: units=80.27039259299627, dropout=0.20865547252317207, activation=relu, epochs=87.22462332506271, batch_size=29.103324002672803 => val_accuracy=1.0000
# | 15        | 1.0       | 0.5373    | 29.1      | 0.2087    | 87.22     | 80.27     |
# Trying: units=77.29082472045789, dropout=0.12455058111067614, activation=relu, epochs=99.91151172558037, batch_size=33.851506357350786 => val_accuracy=0.9839
# | 16        | 0.9839    | 0.2758    | 33.85     | 0.1246    | 99.91     | 77.29     |
# Trying: units=74.11456987538782, dropout=0.23229493487371894, activation=tanh, epochs=85.94293349290396, batch_size=16.872510146887826 => val_accuracy=0.9839
# | 17        | 0.9839    | 1.388     | 16.87     | 0.2323    | 85.94     | 74.11     |
# Trying: units=90.48739946556142, dropout=0.17255176288542595, activation=relu, epochs=76.58832233949452, batch_size=24.819332890923384 => val_accuracy=1.0000
# | 18        | 1.0       | 0.4729    | 24.82     | 0.1726    | 76.59     | 90.49     |
# Trying: units=98.74524639658449, dropout=0.48868852011824815, activation=relu, epochs=66.9611933908277, batch_size=17.479200435496054 => val_accuracy=1.0000
# | 19        | 1.0       | 0.9419    | 17.48     | 0.4887    | 66.96     | 98.75     |
# Trying: units=103.53668912735992, dropout=0.49111704489513397, activation=relu, epochs=68.19977074933637, batch_size=29.806280930742986 => val_accuracy=0.9839
# | 20        | 0.9839    | 0.5227    | 29.81     | 0.4911    | 68.2      | 103.5     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4771 - loss: 1.2536 - val_accuracy: 0.5806 - val_loss: 0.9698
# Epoch 2/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5540 - loss: 1.0085 - val_accuracy: 0.5806 - val_loss: 0.8502
# Epoch 3/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5741 - loss: 0.9130 - val_accuracy: 0.6290 - val_loss: 0.7356
# Epoch 4/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7417 - loss: 0.8051 - val_accuracy: 0.8226 - val_loss: 0.6259
# Epoch 5/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7774 - loss: 0.6883 - val_accuracy: 0.8387 - val_loss: 0.5270
# Epoch 6/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8469 - loss: 0.5280 - val_accuracy: 0.8387 - val_loss: 0.4339
# Epoch 7/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8391 - loss: 0.4760 - val_accuracy: 0.8548 - val_loss: 0.3645
# Epoch 8/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8885 - loss: 0.3875 - val_accuracy: 0.8871 - val_loss: 0.3157
# Epoch 9/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8963 - loss: 0.3531 - val_accuracy: 0.8710 - val_loss: 0.2886
# Epoch 10/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8945 - loss: 0.3013 - val_accuracy: 0.8871 - val_loss: 0.2441
# Epoch 11/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9008 - loss: 0.2741 - val_accuracy: 0.8871 - val_loss: 0.2344
# Epoch 12/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9064 - loss: 0.2740 - val_accuracy: 0.8871 - val_loss: 0.2280
# Epoch 13/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9175 - loss: 0.2616 - val_accuracy: 0.8871 - val_loss: 0.2118
# Epoch 14/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9377 - loss: 0.2362 - val_accuracy: 0.9032 - val_loss: 0.2046
# Epoch 15/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9534 - loss: 0.1979 - val_accuracy: 0.9194 - val_loss: 0.1982
# Epoch 16/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9148 - loss: 0.2048 - val_accuracy: 0.9194 - val_loss: 0.1922
# Epoch 17/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9299 - loss: 0.2045 - val_accuracy: 0.9355 - val_loss: 0.1693
# Epoch 18/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9564 - loss: 0.1621 - val_accuracy: 0.9355 - val_loss: 0.1647
# Epoch 19/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9506 - loss: 0.1976 - val_accuracy: 0.9355 - val_loss: 0.1522
# Epoch 20/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9485 - loss: 0.1568 - val_accuracy: 0.9355 - val_loss: 0.1515
# Epoch 21/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9505 - loss: 0.1489 - val_accuracy: 0.9677 - val_loss: 0.1325
# Epoch 22/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9532 - loss: 0.1498 - val_accuracy: 0.9355 - val_loss: 0.1359
# Epoch 23/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9590 - loss: 0.1572 - val_accuracy: 0.9355 - val_loss: 0.1418
# Epoch 24/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9723 - loss: 0.1242 - val_accuracy: 0.9516 - val_loss: 0.1251
# Epoch 25/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9364 - loss: 0.1665 - val_accuracy: 0.9516 - val_loss: 0.1262
# Epoch 26/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9727 - loss: 0.1342 - val_accuracy: 0.9516 - val_loss: 0.1204
# Epoch 27/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9616 - loss: 0.1222 - val_accuracy: 0.9677 - val_loss: 0.1149
# Epoch 28/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9660 - loss: 0.1231 - val_accuracy: 0.9516 - val_loss: 0.1174
# Epoch 29/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9546 - loss: 0.1330 - val_accuracy: 0.9516 - val_loss: 0.1162
# Epoch 30/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9561 - loss: 0.1314 - val_accuracy: 0.9677 - val_loss: 0.1040
# Epoch 31/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9662 - loss: 0.1252 - val_accuracy: 0.9677 - val_loss: 0.1046
# Epoch 32/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9511 - loss: 0.1275 - val_accuracy: 0.9839 - val_loss: 0.0886
# Epoch 33/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9759 - loss: 0.0994 - val_accuracy: 0.9839 - val_loss: 0.0969
# Epoch 34/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9728 - loss: 0.0895 - val_accuracy: 1.0000 - val_loss: 0.0859
# Epoch 35/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9354 - loss: 0.1419 - val_accuracy: 1.0000 - val_loss: 0.0871
# Epoch 36/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9805 - loss: 0.0924 - val_accuracy: 0.9839 - val_loss: 0.0854
# Epoch 37/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9692 - loss: 0.0962 - val_accuracy: 1.0000 - val_loss: 0.0831
# Epoch 38/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9564 - loss: 0.1114 - val_accuracy: 0.9839 - val_loss: 0.0818
# Epoch 39/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9786 - loss: 0.0820 - val_accuracy: 0.9839 - val_loss: 0.0823
# Epoch 40/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9777 - loss: 0.0964 - val_accuracy: 0.9839 - val_loss: 0.0827
# Epoch 41/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0673 - val_accuracy: 0.9516 - val_loss: 0.0893
# Epoch 42/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9699 - loss: 0.0980 - val_accuracy: 1.0000 - val_loss: 0.0720
# Epoch 43/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9568 - loss: 0.0942 - val_accuracy: 1.0000 - val_loss: 0.0727
# Epoch 44/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9655 - loss: 0.0820 - val_accuracy: 1.0000 - val_loss: 0.0741
# Epoch 45/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9691 - loss: 0.0853 - val_accuracy: 1.0000 - val_loss: 0.0762
# Epoch 46/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9739 - loss: 0.0780 - val_accuracy: 0.9839 - val_loss: 0.0617
# Epoch 47/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9406 - loss: 0.0926 - val_accuracy: 1.0000 - val_loss: 0.0758
# Epoch 48/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9558 - loss: 0.0980 - val_accuracy: 1.0000 - val_loss: 0.0630
# Epoch 49/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9772 - loss: 0.0760 - val_accuracy: 1.0000 - val_loss: 0.0575
# Epoch 50/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9686 - loss: 0.0724 - val_accuracy: 1.0000 - val_loss: 0.0604
# Epoch 51/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9853 - loss: 0.0664 - val_accuracy: 1.0000 - val_loss: 0.0706
# Epoch 52/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9844 - loss: 0.0741 - val_accuracy: 1.0000 - val_loss: 0.0524
# Epoch 53/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9808 - loss: 0.0653 - val_accuracy: 1.0000 - val_loss: 0.0408
# Epoch 54/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9846 - loss: 0.0638 - val_accuracy: 1.0000 - val_loss: 0.0542
# Epoch 55/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9649 - loss: 0.0787 - val_accuracy: 1.0000 - val_loss: 0.0429
# Epoch 56/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0557 - val_accuracy: 1.0000 - val_loss: 0.0529
# Epoch 57/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9980 - loss: 0.0491 - val_accuracy: 1.0000 - val_loss: 0.0509
# Epoch 58/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9818 - loss: 0.0518 - val_accuracy: 0.9677 - val_loss: 0.0739
# Epoch 59/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9828 - loss: 0.0683 - val_accuracy: 0.9839 - val_loss: 0.0522
# Epoch 60/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9820 - loss: 0.0553 - val_accuracy: 1.0000 - val_loss: 0.0435
# Epoch 61/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9733 - loss: 0.0803 - val_accuracy: 1.0000 - val_loss: 0.0565
# Epoch 62/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9761 - loss: 0.0536 - val_accuracy: 1.0000 - val_loss: 0.0429
# Epoch 63/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9852 - loss: 0.0398 - val_accuracy: 1.0000 - val_loss: 0.0430
# Epoch 64/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9945 - loss: 0.0413 - val_accuracy: 1.0000 - val_loss: 0.0407
# Epoch 65/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9741 - loss: 0.0630 - val_accuracy: 1.0000 - val_loss: 0.0476
# Epoch 66/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9995 - loss: 0.0333 - val_accuracy: 1.0000 - val_loss: 0.0393
# Epoch 67/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9885 - loss: 0.0608 - val_accuracy: 1.0000 - val_loss: 0.0360
# Epoch 68/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9878 - loss: 0.0501 - val_accuracy: 0.9839 - val_loss: 0.0599
# Epoch 69/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9779 - loss: 0.0570 - val_accuracy: 1.0000 - val_loss: 0.0413
# Epoch 70/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9932 - loss: 0.0371 - val_accuracy: 1.0000 - val_loss: 0.0387
# Epoch 71/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9844 - loss: 0.0430 - val_accuracy: 1.0000 - val_loss: 0.0456
# Epoch 72/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9862 - loss: 0.0452 - val_accuracy: 1.0000 - val_loss: 0.0423
# Epoch 73/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9794 - loss: 0.0472 - val_accuracy: 1.0000 - val_loss: 0.0387
# Epoch 74/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9978 - loss: 0.0301 - val_accuracy: 1.0000 - val_loss: 0.0334
# Epoch 75/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9814 - loss: 0.0438 - val_accuracy: 1.0000 - val_loss: 0.0397
# Epoch 76/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9825 - loss: 0.0406 - val_accuracy: 1.0000 - val_loss: 0.0494
# Epoch 77/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9945 - loss: 0.0306 - val_accuracy: 1.0000 - val_loss: 0.0429
# Epoch 78/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9947 - loss: 0.0277 - val_accuracy: 0.9839 - val_loss: 0.0546
# Epoch 79/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9769 - loss: 0.0545 - val_accuracy: 1.0000 - val_loss: 0.0307
# Epoch 80/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9923 - loss: 0.0500 - val_accuracy: 1.0000 - val_loss: 0.0270
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.9023
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7500    0.1765    0.2857        17
#            1     0.7500    0.9333    0.8317        45
#            2     0.9806    1.0000    0.9902       101
#            3     1.0000    1.0000    1.0000        11
#
#     accuracy                         0.9023       174
#    macro avg     0.8701    0.7775    0.7769       174
# weighted avg     0.8996    0.9023    0.8810       174
#
#
# Confusion Matrix:
# [[  3  14   0   0]
#  [  1  42   2   0]
#  [  0   0 101   0]
#  [  0   0   0  11]]
# Total instances: 174
# Shape of test set: X_test=(174, 24), y_test=(174,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Confusion matrix total: 174

# %% [markdown]
# BM + Lag + RWS + TBF

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    df['month'] = df.index.month                        # Useful for seasonal crop cycles
    df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # Smooth cyclical encoding for week-of-year (annual periodicity)
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.9032
# | 1         | 0.9032    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=1.0000
# | 2         | 1.0       | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.9032
# | 3         | 0.9032    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.9839
# | 4         | 0.9839    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9839
# | 5         | 0.9839    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=127.92709570154624, dropout=0.36828752140575605, activation=relu, epochs=98.23930764750185, batch_size=38.31621867496922 => val_accuracy=1.0000
# | 6         | 1.0       | 0.36      | 38.32     | 0.3683    | 98.24     | 127.9     |
# Trying: units=126.80202179963152, dropout=0.3479026991890767, activation=tanh, epochs=97.57940073371194, batch_size=38.86047992573045 => val_accuracy=0.9677
# | 7         | 0.9677    | 1.359     | 38.86     | 0.3479    | 97.58     | 126.8     |
# Trying: units=127.98203613210715, dropout=0.34429480938451207, activation=relu, epochs=98.51397907804704, batch_size=35.64223456970725 => val_accuracy=0.9839
# | 8         | 0.9839    | 0.2692    | 35.64     | 0.3443    | 98.51     | 128.0     |
# Trying: units=96.65920998283795, dropout=0.34162227782583066, activation=relu, epochs=80.48766910276359, batch_size=17.25794505388066 => val_accuracy=0.9839
# | 9         | 0.9839    | 0.1063    | 17.26     | 0.3416    | 80.49     | 96.66     |
# Trying: units=99.3422662842249, dropout=0.22391674614020132, activation=tanh, epochs=76.5213389425342, batch_size=17.482268162302145 => val_accuracy=0.9677
# | 10        | 0.9677    | 1.433     | 17.48     | 0.2239    | 76.52     | 99.34     |
# Trying: units=98.3042903721516, dropout=0.13034536531391872, activation=tanh, epochs=82.44853623796595, batch_size=20.347484379191776 => val_accuracy=0.9677
# | 11        | 0.9677    | 1.464     | 20.35     | 0.1303    | 82.45     | 98.3      |
# Trying: units=101.4086045576042, dropout=0.41992691652276226, activation=tanh, epochs=82.47738280308599, batch_size=16.611019861730718 => val_accuracy=0.9839
# | 12        | 0.9839    | 1.991     | 16.61     | 0.4199    | 82.48     | 101.4     |
# Trying: units=104.96512178994166, dropout=0.3374929873563972, activation=relu, epochs=79.72217184139666, batch_size=19.54957854070358 => val_accuracy=1.0000
# | 13        | 1.0       | 0.7254    | 19.55     | 0.3375    | 79.72     | 105.0     |
# Trying: units=104.00198186290957, dropout=0.4815300297535098, activation=tanh, epochs=78.72983095097241, batch_size=16.076606929570602 => val_accuracy=0.9677
# | 14        | 0.9677    | 1.159     | 16.08     | 0.4815    | 78.73     | 104.0     |
# Trying: units=101.49763743027489, dropout=0.2631334916530722, activation=tanh, epochs=79.25748020666333, batch_size=21.521733460667754 => val_accuracy=0.9677
# | 15        | 0.9677    | 1.175     | 21.52     | 0.2631    | 79.26     | 101.5     |
# Trying: units=106.46687427339666, dropout=0.15666683997395864, activation=tanh, epochs=79.4531594181957, batch_size=21.138063406019466 => val_accuracy=0.9839
# | 16        | 0.9839    | 1.982     | 21.14     | 0.1567    | 79.45     | 106.5     |
# Trying: units=104.19180461649393, dropout=0.2764485968616106, activation=relu, epochs=83.72681522451313, batch_size=17.85254379749174 => val_accuracy=1.0000
# | 17        | 1.0       | 0.4559    | 17.85     | 0.2764    | 83.73     | 104.2     |
# Trying: units=105.65194848790875, dropout=0.3765181722283498, activation=relu, epochs=83.18155151106136, batch_size=21.950258457921635 => val_accuracy=1.0000
# | 18        | 1.0       | 0.03557   | 21.95     | 0.3765    | 83.18     | 105.7     |
# Trying: units=106.66692253614438, dropout=0.2929707259374643, activation=relu, epochs=85.88203874304875, batch_size=20.142624254785872 => val_accuracy=1.0000
# | 19        | 1.0       | 0.8977    | 20.14     | 0.293     | 85.88     | 106.7     |
# Trying: units=108.37252881081201, dropout=0.22422037448362264, activation=relu, epochs=82.15949989148574, batch_size=17.937490358224693 => val_accuracy=1.0000
# | 20        | 1.0       | 0.3316    | 17.94     | 0.2242    | 82.16     | 108.4     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0
80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9546 - loss: 0.1418 - val_accuracy: 0.9194 - val_loss: 0.1474
# Epoch 32/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9451 - loss: 0.1618 - val_accuracy: 0.9355 - val_loss: 0.1578
# Epoch 33/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9259 - loss: 0.1742 - val_accuracy: 0.9516 - val_loss: 0.1402
# Epoch 34/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9593 - loss: 0.1351 - val_accuracy: 0.9516 - val_loss: 0.1381
# Epoch 35/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9730 - loss: 0.1235 - val_accuracy: 0.9516 - val_loss: 0.1451
# Epoch 36/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9572 - loss: 0.1367 - val_accuracy: 0.9677 - val_loss: 0.1296
# Epoch 37/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9590 - loss: 0.1383 - val_accuracy: 0.9677 - val_loss: 0.1188
# Epoch 38/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9852 - loss: 0.1161 - val_accuracy: 0.9677 - val_loss: 0.1199
# Epoch 39/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9591 - loss: 0.1178 - val_accuracy: 0.9677 - val_loss: 0.1218
# Epoch 40/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9730 - loss: 0.1223 - val_accuracy: 0.9677 - val_loss: 0.1126
# Epoch 41/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9733 - loss: 0.1050 - val_accuracy: 0.9355 - val_loss: 0.1216
# Epoch 42/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9595 - loss: 0.1336 - val_accuracy: 0.9677 - val_loss: 0.1042
# Epoch 43/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9692 - loss: 0.1077 - val_accuracy: 0.9516 - val_loss: 0.1058
# Epoch 44/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9714 - loss: 0.1057 - val_accuracy: 0.9516 - val_loss: 0.1081
# Epoch 45/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9636 - loss: 0.1045 - val_accuracy: 0.9677 - val_loss: 0.0997
# Epoch 46/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9690 - loss: 0.0927 - val_accuracy: 0.9516 - val_loss: 0.1019
# Epoch 47/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9852 - loss: 0.0794 - val_accuracy: 0.9677 - val_loss: 0.1157
# Epoch 48/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9642 - loss: 0.1056 - val_accuracy: 0.9677 - val_loss: 0.0904
# Epoch 49/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9690 - loss: 0.0906 - val_accuracy: 0.9839 - val_loss: 0.0954
# Epoch 50/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9836 - loss: 0.0954 - val_accuracy: 0.9516 - val_loss: 0.0860
# Epoch 51/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9758 - loss: 0.0791 - val_accuracy: 0.9839 - val_loss: 0.0882
# Epoch 52/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9755 - loss: 0.0753 - val_accuracy: 0.9677 - val_loss: 0.0894
# Epoch 53/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9788 - loss: 0.0851 - val_accuracy: 0.9677 - val_loss: 0.0905
# Epoch 54/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9609 - loss: 0.0834 - val_accuracy: 0.9194 - val_loss: 0.1001
# Epoch 55/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9808 - loss: 0.0612 - val_accuracy: 0.9839 - val_loss: 0.0863
# Epoch 56/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9880 - loss: 0.0608 - val_accuracy: 1.0000 - val_loss: 0.0721
# Epoch 57/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9813 - loss: 0.0681 - val_accuracy: 0.9516 - val_loss: 0.0942
# Epoch 58/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9790 - loss: 0.0784 - val_accuracy: 0.9516 - val_loss: 0.0845
# Epoch 59/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9842 - loss: 0.0818 - val_accuracy: 0.9677 - val_loss: 0.0808
# Epoch 60/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9726 - loss: 0.0764 - val_accuracy: 0.9677 - val_loss: 0.0844
# Epoch 61/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9719 - loss: 0.0799 - val_accuracy: 0.9516 - val_loss: 0.0883
# Epoch 62/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9928 - loss: 0.0520 - val_accuracy: 0.9677 - val_loss: 0.0883
# Epoch 63/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9880 - loss: 0.0683 - val_accuracy: 0.9839 - val_loss: 0.0756
# Epoch 64/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9711 - loss: 0.0684 - val_accuracy: 0.9677 - val_loss: 0.0787
# Epoch 65/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9880 - loss: 0.0674 - val_accuracy: 0.9839 - val_loss: 0.0769
# Epoch 66/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9775 - loss: 0.0614 - val_accuracy: 0.9516 - val_loss: 0.0830
# Epoch 67/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9825 - loss: 0.0582 - val_accuracy: 0.9677 - val_loss: 0.0732
# Epoch 68/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9796 - loss: 0.0660 - val_accuracy: 0.9677 - val_loss: 0.0824
# Epoch 69/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9667 - loss: 0.0642 - val_accuracy: 0.9355 - val_loss: 0.0807
# Epoch 70/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9825 - loss: 0.0708 - val_accuracy: 0.9355 - val_loss: 0.0898
# Epoch 71/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9810 - loss: 0.0616 - val_accuracy: 0.9355 - val_loss: 0.0788
# Epoch 72/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9865 - loss: 0.0541 - val_accuracy: 0.9677 - val_loss: 0.0761
# Epoch 73/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9945 - loss: 0.0452 - val_accuracy: 0.9516 - val_loss: 0.0808
# Epoch 74/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9846 - loss: 0.0604 - val_accuracy: 0.9839 - val_loss: 0.0561
# Epoch 75/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9808 - loss: 0.0548 - val_accuracy: 0.9677 - val_loss: 0.0739
# Epoch 76/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9860 - loss: 0.0491 - val_accuracy: 0.9839 - val_loss: 0.0617
# Epoch 77/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9813 - loss: 0.0592 - val_accuracy: 0.9677 - val_loss: 0.0854
# Epoch 78/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9947 - loss: 0.0399 - val_accuracy: 1.0000 - val_loss: 0.0538
# Epoch 79/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9798 - loss: 0.0564 - val_accuracy: 0.9677 - val_loss: 0.0673
# Epoch 80/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9869 - loss: 0.0576 - val_accuracy: 0.9355 - val_loss: 0.0894
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.9138
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.7143    0.2941    0.4167        17
#            1     0.7778    0.9333    0.8485        45
#            2     0.9902    1.0000    0.9951       101
#            3     1.0000    1.0000    1.0000        11
#
#     accuracy                         0.9138       174
#    macro avg     0.8706    0.8069    0.8151       174
# weighted avg     0.9089    0.9138    0.9010       174
#
#
# Confusion Matrix:
# [[  5  12   0   0]
#  [  2  42   1   0]
#  [  0   0 101   0]
#  [  0   0   0  11]]
# Total instances: 174
# Shape of test set: X_test=(174, 22), y_test=(174,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Confusion matrix total: 174

# %% [markdown]
# BM + Lag + RWS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    # df['month'] = df.index.month                        # Useful for seasonal crop cycles
    # df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    # df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # # Smooth cyclical encoding for week-of-year (annual periodicity)
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.9032
# | 1         | 0.9032    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=0.9839
# | 2         | 0.9839    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.8871
# | 3         | 0.8871    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.9516
# | 4         | 0.9516    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9194
# | 5         | 0.9194    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=108.68209559500434, dropout=0.2662845236599394, activation=relu, epochs=86.41577552468674, batch_size=16.11782014930452 => val_accuracy=0.9839
# | 6         | 0.9839    | 0.5458    | 16.12     | 0.2663    | 86.42     | 108.7     |
# Trying: units=101.48738693066764, dropout=0.10739328000529058, activation=tanh, epochs=80.02528666528657, batch_size=18.362493503684107 => val_accuracy=0.9516
# | 7         | 0.9516    | 1.632     | 18.36     | 0.1074    | 80.03     | 101.5     |
# Trying: units=97.38920832902184, dropout=0.17839635045059832, activation=relu, epochs=80.50713892300283, batch_size=19.5916287720952 => val_accuracy=0.9839
# | 8         | 0.9839    | 0.6106    | 19.59     | 0.1784    | 80.51     | 97.39     |
# Trying: units=97.30790774630165, dropout=0.4852902568522147, activation=relu, epochs=76.4572977289706, batch_size=22.690997728044863 => val_accuracy=0.9839
# | 9         | 0.9839    | 0.1327    | 22.69     | 0.4853    | 76.46     | 97.31     |
# Trying: units=97.08913995169866, dropout=0.47348413655669985, activation=tanh, epochs=74.33144610149733, batch_size=17.331269725465585 => val_accuracy=0.9194
# | 10        | 0.9194    | 1.243     | 17.33     | 0.4735    | 74.33     | 97.09     |
# Trying: units=97.00192785600197, dropout=0.3222354270687776, activation=tanh, epochs=79.12388423045228, batch_size=24.91693117807229 => val_accuracy=0.9355
# | 11        | 0.9355    | 1.14      | 24.92     | 0.3222    | 79.12     | 97.0      |
# Trying: units=99.41241565421896, dropout=0.11108927480048081, activation=relu, epochs=77.24743449560361, batch_size=21.79034759074419 => val_accuracy=0.9839
# | 12        | 0.9839    | 0.3468    | 21.79     | 0.1111    | 77.25     | 99.41     |
# Trying: units=111.67665686064947, dropout=0.2790421016450001, activation=relu, epochs=88.11102218274455, batch_size=18.660861941521784 => val_accuracy=0.9677
# | 13        | 0.9677    | 0.6877    | 18.66     | 0.279     | 88.11     | 111.7     |
# Trying: units=109.4553469603098, dropout=0.1430965412433039, activation=relu, epochs=82.55005472289355, batch_size=17.361758816279178 => val_accuracy=0.9839
# | 14        | 0.9839    | 0.08876   | 17.36     | 0.1431    | 82.55     | 109.5     |
# Trying: units=106.9208562009166, dropout=0.2413994906776943, activation=relu, epochs=85.3346626331473, batch_size=21.611697175196767 => val_accuracy=0.9839
# | 15        | 0.9839    | 0.6196    | 21.61     | 0.2414    | 85.33     | 106.9     |
# Trying: units=109.73657403995699, dropout=0.4072704190683256, activation=tanh, epochs=81.30547586873521, batch_size=22.719369455861887 => val_accuracy=0.9516
# | 16        | 0.9516    | 1.07      | 22.72     | 0.4073    | 81.31     | 109.7     |
# Trying: units=102.63888394772047, dropout=0.23002646765426818, activation=relu, epochs=86.07634944131848, batch_size=19.49918859038441 => val_accuracy=0.9839
# | 17        | 0.9839    | 0.6511    | 19.5      | 0.23      | 86.08     | 102.6     |
# Trying: units=105.9288429083197, dropout=0.42420711439829184, activation=relu, epochs=89.26475972834723, batch_size=20.069023886808267 => val_accuracy=0.9677
# | 18        | 0.9677    | 0.4559    | 20.07     | 0.4242    | 89.26     | 105.9     |
# Trying: units=99.02121360570666, dropout=0.3311982727664037, activation=relu, epochs=83.9728862612009, batch_size=18.20119024223155 => val_accuracy=0.9839
# | 19        | 0.9839    | 0.3005    | 18.2      | 0.3312    | 83.97     | 99.02     |
# Trying: units=97.98403721415531, dropout=0.21400081898717788, activation=relu, epochs=89.57616116626615, batch_size=20.66399097766175 => val_accuracy=0.9839
# | 20        | 0.9839    | 0.9823    | 20.66     | 0.214     | 89.58     | 97.98     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4905 - loss: 1.2514 - val_accuracy: 0.5806 - val_loss: 0.9560
# Epoch 2/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5227 - loss: 1.0190 - val_accuracy: 0.5968 - val_loss: 0.8519
# Epoch 3/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5711 - loss: 0.9240 - val_accuracy: 0.6129 - val_loss: 0.7694
# Epoch 4/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6403 - loss: 0.8416 - val_accuracy: 0.6129 - val_loss: 0.6843
# Epoch 5/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7361 - loss: 0.7276 - val_accuracy: 0.8065 - val_loss: 0.6105
# Epoch 6/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7901 - loss: 0.6259 - val_accuracy: 0.8226 - val_loss: 0.5393
# Epoch 7/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7841 - loss: 0.5846 - val_accuracy: 0.8387 - val_loss: 0.4882
# Epoch 8/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8291 - loss: 0.5206 - val_accuracy: 0.8548 - val_loss: 0.4537
# Epoch 9/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7909 - loss: 0.5387 - val_accuracy: 0.8710 - val_loss: 0.4204
# Epoch 10/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8325 - loss: 0.4696 - val_accuracy: 0.8710 - val_loss: 0.3960
# Epoch 11/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8169 - loss: 0.4646 - val_accuracy: 0.8710 - val_loss: 0.3893
# Epoch 12/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.6364    0.4118    0.5000        17
#            1     0.8000    0.8889    0.8421        45
#            2     0.9902    1.0000    0.9951       101
#            3     1.0000    1.0000    1.0000        11
#
#     accuracy                         0.9138       174
#    macro avg     0.8566    0.8252    0.8343       174
# weighted avg     0.9071    0.9138    0.9075       174
#
#
# Confusion Matrix:
# [[  7  10   0   0]
#  [  4  40   1   0]
#  [  0   0 101   0]
#  [  0   0   0  11]]
# Total instances: 174
# Shape of test set: X_test=(174, 17), y_test=(174,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Confusion matrix total: 174

# %% [markdown]
# BM + Lag

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    # for window in [3, 6]:
    #     df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
    #     df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    # df['month'] = df.index.month                        # Useful for seasonal crop cycles
    # df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    # df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # # Smooth cyclical encoding for week-of-year (annual periodicity)
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.8548
# | 1         | 0.8548    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=0.9032
# | 2         | 0.9032    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.8871
# | 3         | 0.8871    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.9032
# | 4         | 0.9032    | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9032
# | 5         | 0.9032    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=77.27613105874512, dropout=0.21914375935608452, activation=relu, epochs=89.00240435200217, batch_size=22.19541985268231 => val_accuracy=0.9032
# | 6         | 0.9032    | 0.3854    | 22.2      | 0.2191    | 89.0      | 77.28     |
# Trying: units=76.14300960455571, dropout=0.30245415225722905, activation=relu, epochs=67.61524136815626, batch_size=21.842126924684578 => val_accuracy=0.9032
# | 7         | 0.9032    | 0.1289    | 21.84     | 0.3025    | 67.62     | 76.14     |
# Trying: units=39.142978571150756, dropout=0.3355105109193208, activation=relu, epochs=50.98337761543022, batch_size=17.007080507038268 => val_accuracy=0.8710
# | 8         | 0.871     | 0.009058  | 17.01     | 0.3355    | 50.98     | 39.14     |
# Trying: units=98.13321669477165, dropout=0.18434805026846465, activation=relu, epochs=64.22348460497564, batch_size=42.821859030734416 => val_accuracy=0.8871
# | 9         | 0.8871    | 0.2089    | 42.82     | 0.1843    | 64.22     | 98.13     |
# Trying: units=116.32699078775833, dropout=0.1480743873585873, activation=tanh, epochs=99.65146220502774, batch_size=16.934630400259394 => val_accuracy=0.9032
# | 10        | 0.9032    | 1.177     | 16.93     | 0.1481    | 99.65     | 116.3     |
# Trying: units=99.45678513898143, dropout=0.3883784179227173, activation=tanh, epochs=99.97869752455239, batch_size=38.004491511397774 => val_accuracy=0.9194
# | 11        | 0.9194    | 1.822     | 38.0      | 0.3884    | 99.98     | 99.46     |
# Trying: units=115.9784739004434, dropout=0.3525646680595804, activation=tanh, epochs=98.98356748302761, batch_size=47.15827367022645 => val_accuracy=0.9194
# | 12        | 0.9194    | 1.038     | 47.16     | 0.3526    | 98.98     | 116.0     |
# Trying: units=100.38306727642416, dropout=0.17002106216097568, activation=relu, epochs=99.12794240935025, batch_size=63.95917358931591 => val_accuracy=0.8871
# | 13        | 0.8871    | 0.05045   | 63.96     | 0.17      | 99.13     | 100.4     |
# Trying: units=126.83569009129445, dropout=0.44956645662858474, activation=tanh, epochs=86.84199701823654, batch_size=37.11735217966647 => val_accuracy=0.9194
# | 14        | 0.9194    | 1.594     | 37.12     | 0.4496    | 86.84     | 126.8     |
# Trying: units=127.86302075986191, dropout=0.39472126451583667, activation=relu, epochs=81.79389772567143, batch_size=57.71714763602821 => val_accuracy=0.9032
# | 15        | 0.9032    | 0.8324    | 57.72     | 0.3947    | 81.79     | 127.9     |
# Trying: units=127.66653154365602, dropout=0.4828936441505671, activation=tanh, epochs=66.28622561923393, batch_size=20.51796426206525 => val_accuracy=0.9194
# | 16        | 0.9194    | 1.92      | 20.52     | 0.4829    | 66.29     | 127.7     |
# Trying: units=126.4097623431789, dropout=0.35592261173943607, activation=tanh, epochs=50.11088773267898, batch_size=19.018980803880027 => val_accuracy=0.9194
# | 17        | 0.9194    | 1.307     | 19.02     | 0.3559    | 50.11     | 126.4     |
# Trying: units=127.71001686829842, dropout=0.17799918255635128, activation=relu, epochs=51.88720132580322, batch_size=39.52496746236702 => val_accuracy=0.9032
# | 18        | 0.9032    | 0.9492    | 39.52     | 0.178     | 51.89     | 127.7     |
# Trying: units=106.9535700296502, dropout=0.25683425081922523, activation=relu, epochs=51.39379292576452, batch_size=16.719740361775692 => val_accuracy=0.9194
# | 19        | 0.9194    | 0.4088    | 16.72     | 0.2568    | 51.39     | 107.0     |
# Trying: units=33.61495694122115, dropout=0.42991231751935244, activation=tanh, epochs=99.51018734438588, batch_size=16.379157665573018 => val_accuracy=0.8871
# | 20        | 0.8871    | 1.371     | 16.38     | 0.4299    | 99.51     | 33.61     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 1.8224763422758619, 'batch_size': 38.004491511397774, 'dropout_rate': 0.3883784179227173, 'epochs': 99.97869752455239, 'num_units': 99.45678513898143}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.4090 - loss: 1.2397 - val_accuracy: 0.5806 - val_loss: 0.9684
# Epoch 2/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5239 - loss: 1.0361 - val_accuracy: 0.5806 - val_loss: 0.9132
# Epoch 3/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5765 - loss: 0.9594 - val_accuracy: 0.5806 - val_loss: 0.8549
# Epoch 4/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6752 - loss: 0.8759 - val_accuracy: 0.6290 - val_loss: 0.7827
# Epoch 5/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6751 - loss: 0.8633 - val_accuracy: 0.6613 - val_loss: 0.7233
# Epoch 6/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7272 - loss: 0.7989 - val_accuracy: 0.7419 - val_loss: 0.6769
# Epoch 7/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7819 - loss: 0.7162 - val_accuracy: 0.7903 - val_loss: 0.6376
# Epoch 8/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7625 - loss: 0.7100 - val_accuracy: 0.8226 - val_loss: 0.6041
# Epoch 9/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7962 - loss: 0.6537 - val_accuracy: 0.8226 - val_loss: 0.5728
# Epoch 10/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8104 - loss: 0.6008 - val_accuracy: 0.8226 - val_loss: 0.5494
# Epoch 11/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7966 - loss: 0.6006 - val_accuracy: 0.8387 - val_loss: 0.5276
# Epoch 12/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8108 - loss: 0.5585 - val_accuracy: 0.8387 - val_loss: 0.5093
# Epoch 13/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8222 - loss: 0.5398 - val_accuracy: 0.8387 - val_loss: 0.4971
# Epoch 14/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8185 - loss: 0.5269 - val_accuracy: 0.8548 - val_loss: 0.4884
# Epoch 15/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8417 - loss: 0.5176 - val_accuracy: 0.8548 - val_loss: 0.4766
# Epoch 16/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8175 - loss: 0.5082 - val_accuracy: 0.8548 - val_loss: 0.4579
# Epoch 17/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8301 - loss: 0.4607 - val_accuracy: 0.8548 - val_loss: 0.4500
# Epoch 18/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8288 - loss: 0.4789 - val_accuracy: 0.8548 - val_loss: 0.4475
# Epoch 19/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8471 - loss: 0.4417 - val_accuracy: 0.8548 - val_loss: 0.4429
# Epoch 20/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8216 - loss: 0.4666 - val_accuracy: 0.8871 - val_loss: 0.4348
# Epoch 21/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8495 - loss: 0
99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9211 - loss: 0.2349 - val_accuracy: 0.9032 - val_loss: 0.2808
# Epoch 87/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9165 - loss: 0.2534 - val_accuracy: 0.9032 - val_loss: 0.2773
# Epoch 88/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9174 - loss: 0.2475 - val_accuracy: 0.9032 - val_loss: 0.2771
# Epoch 89/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9195 - loss: 0.2338 - val_accuracy: 0.9032 - val_loss: 0.2802
# Epoch 90/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9209 - loss: 0.2604 - val_accuracy: 0.9032 - val_loss: 0.2791
# Epoch 91/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9249 - loss: 0.2418 - val_accuracy: 0.9194 - val_loss: 0.2847
# Epoch 92/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8915 - loss: 0.2470 - val_accuracy: 0.9194 - val_loss: 0.2852
# Epoch 93/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9038 - loss: 0.2238 - val_accuracy: 0.9194 - val_loss: 0.2787
# Epoch 94/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9216 - loss: 0.2451 - val_accuracy: 0.9194 - val_loss: 0.2744
# Epoch 95/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9046 - loss: 0.2445 - val_accuracy: 0.9194 - val_loss: 0.2799
# Epoch 96/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9168 - loss: 0.2348 - val_accuracy: 0.9194 - val_loss: 0.2741
# Epoch 97/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9168 - loss: 0.2343 - val_accuracy: 0.9032 - val_loss: 0.2715
# Epoch 98/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8814 - loss: 0.2534 - val_accuracy: 0.9032 - val_loss: 0.2739
# Epoch 99/99
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9006 - loss: 0.2430 - val_accuracy: 0.9194 - val_loss: 0.2778
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.8161
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000        17
#            1     0.6176    0.9333    0.7434        45
#            2     0.9583    0.9109    0.9340       101
#            3     0.8000    0.7273    0.7619        11
#
#     accuracy                         0.8161       174
#    macro avg     0.5940    0.6429    0.6098       174
# weighted avg     0.7666    0.8161    0.7826       174
#
#
# Confusion Matrix:
# [[ 0 16  0  1]
#  [ 0 42  2  1]
#  [ 0  9 92  0]
#  [ 0  1  2  8]]
# Total instances: 174
# Shape of test set: X_test=(174, 13), y_test=(174,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Confusion matrix total: 174

# %% [markdown]
# BM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # # Lag features
    # for i in range(1, 4):
    #     df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    # for window in [3, 6]:
    #     df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
    #     df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    # df['month'] = df.index.month                        # Useful for seasonal crop cycles
    # df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    # df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # # Smooth cyclical encoding for week-of-year (annual periodicity)
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Cordoba_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.8226
# | 1         | 0.8226    | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=0.8871
# | 2         | 0.8871    | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.7742
# | 3         | 0.7742    | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.8710
# | 4         | 0.871     | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.8387
# | 5         | 0.8387    | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=110.85648110948767, dropout=0.4369540698534051, activation=relu, epochs=85.8453797559504, batch_size=22.780381753790053 => val_accuracy=0.8871
# | 6         | 0.8871    | 0.4291    | 22.78     | 0.437     | 85.85     | 110.9     |
# Trying: units=101.48738693066764, dropout=0.10739328000529058, activation=tanh, epochs=80.02528666528657, batch_size=18.362493503684107 => val_accuracy=0.8710
# | 7         | 0.871     | 1.632     | 18.36     | 0.1074    | 80.03     | 101.5     |
# Trying: units=96.378348957594, dropout=0.20201074883690695, activation=relu, epochs=84.73694730217763, batch_size=23.507261923303908 => val_accuracy=0.8548
# | 8         | 0.8548    | 0.1948    | 23.51     | 0.202     | 84.74     | 96.38     |
# Trying: units=94.52131737811617, dropout=0.2612095892669606, activation=relu, epochs=76.24573232375033, batch_size=19.06450146965195 => val_accuracy=0.8387
# | 9         | 0.8387    | 0.6249    | 19.06     | 0.2612    | 76.25     | 94.52     |
# Trying: units=106.18436632319975, dropout=0.30870242674103776, activation=tanh, epochs=84.60874889922916, batch_size=23.69740507788277 => val_accuracy=0.8710
# | 10        | 0.871     | 1.263     | 23.7      | 0.3087    | 84.61     | 106.2     |
# Trying: units=109.13532909538235, dropout=0.41234130002253144, activation=relu, epochs=90.55462665709476, batch_size=19.934276958990303 => val_accuracy=0.8871
# | 11        | 0.8871    | 0.4924    | 19.93     | 0.4123    | 90.55     | 109.1     |
# Trying: units=111.48359849813016, dropout=0.1733002062640877, activation=relu, epochs=92.08182806106498, batch_size=27.01094312402128 => val_accuracy=0.8871
# | 12        | 0.8871    | 0.9864    | 27.01     | 0.1733    | 92.08     | 111.5     |
# Trying: units=117.33889443587304, dropout=0.15389047375605658, activation=relu, epochs=91.58354484896687, batch_size=23.641817019520268 => val_accuracy=0.8871
# | 13        | 0.8871    | 0.3409    | 23.64     | 0.1539    | 91.58     | 117.3     |
# Trying: units=112.50941424483474, dropout=0.2875295823925863, activation=tanh, epochs=99.52855984894518, batch_size=19.75330335943947 => val_accuracy=0.8710
# | 14        | 0.871     | 1.975     | 19.75     | 0.2875    | 99.53     | 112.5     |
# Trying: units=117.99216945559068, dropout=0.4192888610131179, activation=relu, epochs=84.36865108756723, batch_size=28.011126415819867 => val_accuracy=0.8710
# | 15        | 0.871     | 0.1822    | 28.01     | 0.4193    | 84.37     | 118.0     |
# Trying: units=117.30342361152137, dropout=0.43072754962028925, activation=tanh, epochs=86.00085686394823, batch_size=17.724101217609874 => val_accuracy=0.8548
# | 16        | 0.8548    | 1.765     | 17.72     | 0.4307    | 86.0      | 117.3     |
# Trying: units=119.4513236284942, dropout=0.3910871718851261, activation=relu, epochs=98.06315598000603, batch_size=30.638084134277292 => val_accuracy=0.8710
# | 17        | 0.871     | 0.01639   | 30.64     | 0.3911    | 98.06     | 119.5     |
# Trying: units=105.76760808441396, dropout=0.4114888729525754, activation=relu, epochs=98.20945827780082, batch_size=27.571378854069962 => val_accuracy=0.8548
# | 18        | 0.8548    | 0.1372    | 27.57     | 0.4115    | 98.21     | 105.8     |
# Trying: units=112.91825357482622, dropout=0.14424800204225863, activation=relu, epochs=89.27359443636945, batch_size=33.74365445919971 => val_accuracy=0.8548
# | 19        | 0.8548    | 0.3973    | 33.74     | 0.1442    | 89.27     | 112.9     |
# Trying: units=123.71115076534385, dropout=0.45138430489492287, activation=tanh, epochs=97.81498337402662, batch_size=22.09717519798458 => val_accuracy=0.8548
# | 20        | 0.8548    | 1.783     | 22.1      | 0.4514    | 97.81     | 123.7     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3583 - loss: 1.3375 - val_accuracy: 0.5806 - val_loss: 1.1396
# Epoch 2/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4995 - loss: 1.1206 - val_accuracy: 0.5806 - val_loss: 1.0015
# Epoch 3/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5264 - loss: 1.0142 - val_accuracy: 0.5968 - val_loss: 0.8974
# Epoch 4/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5659 - loss: 0.9316 - val_accuracy: 0.6613 - val_loss: 0.7942
# Epoch 5/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6729 - loss: 0.8480 - val_accuracy: 0.6774 - val_loss: 0.7137
# Epoch 6/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6708 - loss: 0.8113 - val_accuracy: 0.6935 - val_loss: 0.6675
# Epoch 7/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7221 - loss: 0.7625 - val_accuracy: 0.7419 - val_loss: 0.6295
# Epoch 8/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7727 - loss: 0.6781 - val_accuracy: 0.7581 - val_loss: 0.6078
# Epoch 9/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7737 - loss: 0.6671 - val_accuracy: 0.7581 - val_loss: 0.5703
# Epoch 10/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7725 - loss: 0.6424 - val_accuracy: 0.7581 - val_loss: 0.5710
# Epoch 11/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7757 - loss: 0.6238 - val_accuracy: 0.7581 - val_loss: 0.5336
# Epoch 12/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8006 - loss: 0.5583 - val_accuracy: 0.7742 - val_loss: 0.5393
# Epoch 13/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7906 - loss: 0.5573 - val_accuracy: 0.7419 - val_loss: 0.5347
# Epoch 14/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8281 - loss: 0.5420 - val_accuracy: 0.7581 - val_loss: 0.5010
# Epoch 15/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8037 - loss: 0.5658 - val_accuracy: 0.7742 - val_loss: 0.4923
# Epoch 16/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8166 - loss: 0.5073 - val_accuracy: 0.8226 - val_loss: 0.4729
# Epoch 17/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8107 - loss: 0.5215 - val_accuracy: 0.8226 - val_loss: 0.4701
# Epoch 18/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8335 - loss: 0.5322 - val_accuracy: 0.8226 - val_loss: 0.4716
# Epoch 19/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8159 - loss: 0.4919 - val_accuracy: 0.8548 - val_loss: 0.4582
# Epoch 20/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8156 - loss: 0.4558 - val_accuracy: 0.8548 - val_loss: 0.4438
# Epoch 21/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8505 - loss: 0.4747 - val_accuracy: 0.8226 - val_loss: 0.4571
# Epoch 22/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8518 - loss: 0.3559 - val_accuracy: 0.8548 - val_loss: 0.3566
# Epoch 56/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8285 - loss: 0.3404 - val_accuracy: 0.8387 - val_loss: 0.3704
# Epoch 57/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8669 - loss: 0.3422 - val_accuracy: 0.8387 - val_loss: 0.3593
# Epoch 58/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8360 - loss: 0.3809 - val_accuracy: 0.8548 - val_loss: 0.3566
# Epoch 59/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8859 - loss: 0.3341 - val_accuracy: 0.8387 - val_loss: 0.3578
# Epoch 60/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8671 - loss: 0.3555 - val_accuracy: 0.8710 - val_loss: 0.3621
# Epoch 61/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8517 - loss: 0.3587 - val_accuracy: 0.8226 - val_loss: 0.3571
# Epoch 62/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8624 - loss: 0.3347 - val_accuracy: 0.8548 - val_loss: 0.3455
# Epoch 63/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8553 - loss: 0.3417 - val_accuracy: 0.8387 - val_loss: 0.3522
# Epoch 64/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8484 - loss: 0.3523 - val_accuracy: 0.8387 - val_loss: 0.3538
# Epoch 65/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8845 - loss: 0.3142 - val_accuracy: 0.8387 - val_loss: 0.3487
# Epoch 66/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8912 - loss: 0.3311 - val_accuracy: 0.8387 - val_loss: 0.3473
# Epoch 67/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8186 - loss: 0.3632 - val_accuracy: 0.8387 - val_loss: 0.3505
# Epoch 68/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8602 - loss: 0.3250 - val_accuracy: 0.8226 - val_loss: 0.3520
# Epoch 69/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8799 - loss: 0.3197 - val_accuracy: 0.8226 - val_loss: 0.3494
# Epoch 70/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8587 - loss: 0.3264 - val_accuracy: 0.8226 - val_loss: 0.3413
# Epoch 71/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8702 - loss: 0.3305 - val_accuracy: 0.8387 - val_loss: 0.3477
# Epoch 72/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8776 - loss: 0.3162 - val_accuracy: 0.8387 - val_loss: 0.3534
# Epoch 73/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8627 - loss: 0.3353 - val_accuracy: 0.8548 - val_loss: 0.3314
# Epoch 74/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8920 - loss: 0.3170 - val_accuracy: 0.8226 - val_loss: 0.3416
# Epoch 75/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8595 - loss: 0.3211 - val_accuracy: 0.8548 - val_loss: 0.3265
# Epoch 76/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9150 - loss: 0.2720 - val_accuracy: 0.8226 - val_loss: 0.3309
# Epoch 77/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8771 - loss: 0.3468 - val_accuracy: 0.8387 - val_loss: 0.3317
# Epoch 78/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8533 - loss: 0.3267 - val_accuracy: 0.8387 - val_loss: 0.3323
# Epoch 79/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8801 - loss: 0.3087 - val_accuracy: 0.8226 - val_loss: 0.3393
# Epoch 80/80
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8558 - loss: 0.3349 - val_accuracy: 0.8548 - val_loss: 0.3234
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.8448
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.2353    0.3810        17
#            1     0.7049    0.9556    0.8113        45
#            2     0.9579    0.9010    0.9286       101
#            3     0.6429    0.8182    0.7200        11
#
#     accuracy                         0.8448       174
#    macro avg     0.8264    0.7275    0.7102       174
# weighted avg     0.8767    0.8448    0.8316       174
#
#
# Confusion Matrix:
# [[ 4 12  0  1]
#  [ 0 43  2  0]
#  [ 0  6 91  4]
#  [ 0  0  2  9]]
# Total instances: 174
# Shape of test set: X_test=(174, 10), y_test=(174,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# Confusion matrix total: 174

# %% [markdown]
# BM + Lag + RWS + TBF + TLS

# %% [markdown]
# BM + Lag + RWS + TBF
