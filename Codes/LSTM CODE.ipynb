# %% [markdown]
# Horizon 1 LSTM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import psutil
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ============================================
# 1. Data Loading and Preprocessing
# ============================================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    df['month'] = df.index.month
    df['weekofyear'] = df.index.isocalendar().week
    df['year'] = df.index.isocalendar().year
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)
    df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()
    df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()
    df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    fft_values = fft(df[target_col].dropna().values)
    fft_real = np.real(fft_values)[:len(df[target_col])]
    fft_imag = np.imag(fft_values)[:len(df[target_col])]
    df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))])
    df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))])

    df.fillna(df.median(), inplace=True)
    return df, target_col

# ============================================
# 2. Feature Scaling
# ============================================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))  # LSTM expects 3D input
    return X_scaled, y, scaler

# ============================================
# 3. Build LSTM Model
# ============================================
def build_lstm_model(input_shape, num_classes=4, num_units=64, dropout_rate=0.2):
    model = Sequential()
    model.add(LSTM(num_units, input_shape=input_shape, return_sequences=False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ============================================
# 4. Bayesian Objective
# ============================================
def objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_units=int(num_units),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# ============================================
# 5. Optimize Hyperparameters
# ============================================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
            num_units, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )
    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ============================================
# 6. Train & Evaluate Model
# ============================================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate'])
    )

    # Training time
    start_train = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start_train

    # Inference time per sample
    start_infer = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    inference_time = (time.time() - start_infer) / len(X_test)

    # Testing time
    start_test = time.time()
    model.evaluate(X_test, y_test, verbose=0)  # Just to trigger testing phase
    testing_time = time.time() - start_test

    # Evaluation
    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print("\n===== Evaluation Results =====")
    print(f"Test Accuracy: {acc:.4f}")
    print("Classification Report:\n", classification_report(y_test, y_pred, digits=4))
    print("Confusion Matrix:\n", cm)

    # Save & calculate model size
    model.save("temp_model.h5", include_optimizer=False)
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)  # MB
    os.remove("temp_model.h5")

    # Trainable Parameters
    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])

    # RAM usage
    process = psutil.Process(os.getpid())
    ram_usage = process.memory_info().rss / (1024 ** 2)  # MB

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f} seconds")
    print(f"Inference Time per Sample: {inference_time:.6f} seconds")
    print(f"Testing Time: {testing_time:.2f} seconds")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Parameters: {total_params:,}")
    print(f"RAM Usage During Inference: {ram_usage:.2f} MB")

    return model, history

# ============================================
# 7. Main
# ============================================
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1_train.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\nOptimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest Params:", best_params)

    print("\nTraining Final Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
# Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------
# | 1         | 1.0       | 33.98     | 0.4803    | 86.6      | 89.47     |
# | 2         | 1.0       | 23.49     | 0.1624    | 52.9      | 115.2     |
# | 3         | 1.0       | 44.85     | 0.3832    | 51.03     | 125.1     |
# | 4         | 1.0       | 55.96     | 0.1849    | 59.09     | 49.61     |
# | 5         | 1.0       | 30.6      | 0.3099    | 71.6      | 59.96     |
# | 6         | 1.0       | 58.87     | 0.237     | 99.91     | 32.34     |
# | 7         | 1.0       | 63.83     | 0.1911    | 99.11     | 127.8     |
# | 8         | 1.0       | 17.24     | 0.4906    | 50.56     | 33.63     |
# | 9         | 1.0       | 16.41     | 0.4657    | 98.87     | 127.3     |
# | 10        | 1.0       | 18.2      | 0.4567    | 99.88     | 32.67     |
# | 11        | 1.0       | 63.94     | 0.4128    | 50.58     | 125.6     |
# | 12        | 0.9959    | 62.79     | 0.1521    | 55.2      | 32.03     |
# | 13        | 1.0       | 18.12     | 0.1482    | 99.07     | 126.2     |
# | 14        | 1.0       | 48.2      | 0.2424    | 60.91     | 63.33     |
# | 15        | 1.0       | 50.12     | 0.4386    | 78.94     | 53.15     |
# | 16        | 1.0       | 37.09     | 0.3597    | 94.36     | 43.37     |
# | 17        | 1.0       | 21.58     | 0.3057    | 76.63     | 37.34     |
# | 18        | 1.0       | 19.16     | 0.2526    | 92.46     | 57.48     |
# | 19        | 1.0       | 40.29     | 0.1606    | 95.7      | 68.59     |
# | 20        | 1.0       | 36.38     | 0.4202    | 74.45     | 113.3     |
# =========================================================================
#
# Best Params: {'batch_size': 33.977925704673396, 'dropout_rate': 0.4802857225639665, 'epochs': 86.59969709057026, 'num_units': 89.47121448291551}
#
# Training Final Model...
# Epoch 1/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.3754 - loss: 1.3209 - val_accuracy: 0.5000 - val_loss: 1.0957
# Epoch 2/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4844 - loss: 1.1079 - val_accuracy: 0.6463 - val_loss: 0.8640
# Epoch 3/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7136 - loss: 0.8411 - val_accuracy: 0.9065 - val_loss: 0.4998
# Epoch 4/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8497 - loss: 0.5226 - val_accuracy: 0.9309 - val_loss: 0.3135
# Epoch 5/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8556 - loss: 0.3747 - val_accuracy: 0.9431 - val_loss: 0.2441
# Epoch 6/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8879 - loss: 0.2966 - val_accuracy: 0.9309 - val_loss: 0.2013
# Epoch 7/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9106 - loss: 0.2580 - val_accuracy: 0.9512 - val_loss: 0.1727
# Epoch 8/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9101 - loss: 0.2447 - val_accuracy: 0.9593 - val_loss: 0.1517
# Epoch 9/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9057 - loss: 0.2151 - val_accuracy: 0.9634 - val_loss: 0.1455
# Epoch 10/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9257 - loss: 0.2005 - val_accuracy: 0.9715 - val_loss: 0.1192
# Epoch 11/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9294 - loss: 0.1861 - val_accuracy: 0.9797 - val_loss: 0.1092
# Epoch 12/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9202 - loss: 0.1732 - val_accuracy: 0.9756 - val_loss: 0.1021
# Epoch 13/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9290 - loss: 0.1625 - val_accuracy: 0.9715 - val_loss: 0.0931
# Epoch 14/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9378 - loss: 0.1661 - val_accuracy: 0.9715 - val_loss: 0.0820
# Epoch 15/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9432 - loss: 0.1419 - val_accuracy: 0.9756 - val_loss: 0.0784
# Epoch 16/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9607 - loss: 0.1272 - val_accuracy: 0.9715 - val_loss: 0.0751
# Epoch 17/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9601 - loss: 0.1236 - val_accuracy: 0.9797 - val_loss: 0.0654
# Epoch 18/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9580 - loss: 0.1285 - val_accuracy: 0.9797 - val_loss: 0.0608
# Epoch 19/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9540 - loss: 0.1163 - val_accuracy: 0.9756 - val_loss: 0.0582
# Epoch 20/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9563 - loss: 0.1233 - val_accuracy: 0.9837 - val_loss: 0.0563
# Epoch 21/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9682 - loss: 0.1022 - val_accuracy: 0.9919 - val_loss: 0.0499
# Epoch 22/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9568 - loss: 0.1153 - val_accuracy: 0.9919 - val_loss: 0.0498
# Epoch 23/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9635 - loss: 0.1008 - val_accuracy: 0.9959 - val_loss: 0.0433
# Epoch 24/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9557 - loss: 0.1057 - val_accuracy: 0.9959 - val_loss: 0.0457
# Epoch 25/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9579 - loss: 0.0917 - val_accuracy: 0.9959 - val_loss: 0.0360
# Epoch 26/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9692 - loss: 0.0825 - val_accuracy: 0.9919 - val_loss: 0.0459
# Epoch 27/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9569 - loss: 0.0901 - val_accuracy: 0.9959 - val_loss: 0.0369
# Epoch 28/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9754 - loss: 0.0810 - val_accuracy: 0.9959 - val_loss: 0.0309
# Epoch 29/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9756 - loss: 0.0790 - val_accuracy: 0.9959 - val_loss: 0.0313
# Epoch 30/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9729 - loss: 0.0866 - val_accuracy: 0.9959 - val_loss: 0.0331
# Epoch 31/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9753 - loss: 0.0832 - val_accuracy: 0.9959 - val_loss: 0.0331
# Epoch 32/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9750 - loss: 0.0775 - val_accuracy: 0.9959 - val_loss: 0.0288
# Epoch 33/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9796 - loss: 0.0788 - val_accuracy: 0.9919 - val_loss: 0.0308
# Epoch 34/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9648 - loss: 0.0808 - val_accuracy: 1.0000 - val_loss: 0.0246
# Epoch 35/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9805 - loss: 0.0626 - val_accuracy: 0.9919 - val_loss: 0.0311
# Epoch 36/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9689 - loss: 0.0700 - val_accuracy: 0.9959 - val_loss: 0.0273
# Epoch 37/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9741 - loss: 0.0596 - val_accuracy: 0.9959 - val_loss: 0.0217
# Epoch 38/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0631 - val_accuracy: 0.9959 - val_loss: 0.0259
# Epoch 39/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9811 - loss: 0.0488 - val_accuracy: 1.0000 - val_loss: 0.0171
# Epoch 40/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9829 - loss: 0.0576 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 41/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9782 - loss: 0.0673 - val_accuracy: 1.0000 - val_loss: 0.0214
# Epoch 42/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9766 - loss: 0.0615 - val_accuracy: 0.9959 - val_loss: 0.0242
# Epoch 43/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9692 - loss: 0.0755 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 44/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0498 - val_accuracy: 1.0000 - val_loss: 0.0208
# Epoch 45/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9868 - loss: 0.0520 - val_accuracy: 1.0000 - val_loss: 0.0167
# Epoch 46/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9822 - loss: 0.0490 - val_accuracy: 0.9959 - val_loss: 0.0165
# Epoch 47/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9867 - loss: 0.0402 - val_accuracy: 0.9797 - val_loss: 0.0369
# Epoch 48/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9720 - loss: 0.0548 - val_accuracy: 0.9959 - val_loss: 0.0190
# Epoch 49/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9827 - loss: 0.0418 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 50/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9853 - loss: 0.0433 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 51/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0446 - val_accuracy: 0.9959 - val_loss: 0.0133
# Epoch 52/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9804 - loss: 0.0513 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 53/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 54/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9875 - loss: 0.0483 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 55/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9887 - loss: 0.0372 - val_accuracy: 1.0000 - val_loss: 0.0163
# Epoch 56/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9862 - loss: 0.0409 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 57/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9875 - loss: 0.0503 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 58/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9914 - loss: 0.0270 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 59/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9843 - loss: 0.0517 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 60/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0444 - val_accuracy: 0.9837 - val_loss: 0.0256
# Epoch 61/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9886 - loss: 0.0420 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 62/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9891 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 63/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9856 - loss: 0.0402 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 64/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9849 - loss: 0.0399 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 65/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9864 - loss: 0.0443 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 66/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9828 - loss: 0.0395 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 67/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9882 - loss: 0.0324 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 68/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9892 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 69/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9944 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 70/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9873 - loss: 0.0293 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 71/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0330 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 72/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9888 - loss: 0.0317 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 73/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0386 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 74/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9937 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 75/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9873 - loss: 0.0313 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 76/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.0301 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 77/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.0282 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 78/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9857 - loss: 0.0300 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 79/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9906 - loss: 0.0301 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 80/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9972 - loss: 0.0185 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 81/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9888 - loss: 0.0347 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 82/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9883 - loss: 0.0274 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 83/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9868 - loss: 0.0291 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 84/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9894 - loss: 0.0348 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 85/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9941 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 86/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9886 - loss: 0.0360 - val_accuracy: 1.0000 - val_loss: 0.0042
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation Results =====
# Test Accuracy: 0.9680
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     1.0000    0.7143    0.8333        56
#            1     0.9370    0.9917    0.9636       240
#            2     0.9938    0.9856    0.9897       487
#            3     0.8056    0.9667    0.8788        30
#
#     accuracy                         0.9680       813
#    macro avg     0.9341    0.9146    0.9163       813
# weighted avg     0.9705    0.9680    0.9671       813
#
# Confusion Matrix:
#  [[ 40  16   0   0]
#  [  0 238   2   0]
#  [  0   0 480   7]
#  [  0   0   1  29]]
#
# ===== Model Metrics =====
# Training Time: 18.29 seconds
# Inference Time per Sample: 0.000632 seconds
# Testing Time: 0.11 seconds
# Model Size: 0.20 MB
# Trainable Parameters: 46,148
# RAM Usage During Inference: 978.09 MB

# %% [markdown]
# Horizon 2 LSTM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import psutil
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ============================================
# 1. Data Loading and Preprocessing
# ============================================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h2'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    df['month'] = df.index.month
    df['weekofyear'] = df.index.isocalendar().week
    df['year'] = df.index.isocalendar().year
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)
    df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()
    df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()
    df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    fft_values = fft(df[target_col].dropna().values)
    fft_real = np.real(fft_values)[:len(df[target_col])]
    fft_imag = np.imag(fft_values)[:len(df[target_col])]
    df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))])
    df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))])

    df.fillna(df.median(), inplace=True)
    return df, target_col

# ============================================
# 2. Feature Scaling
# ============================================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))  # LSTM expects 3D input
    return X_scaled, y, scaler

# ============================================
# 3. Build LSTM Model
# ============================================
def build_lstm_model(input_shape, num_classes=4, num_units=64, dropout_rate=0.2):
    model = Sequential()
    model.add(LSTM(num_units, input_shape=input_shape, return_sequences=False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ============================================
# 4. Bayesian Objective
# ============================================
def objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_units=int(num_units),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# ============================================
# 5. Optimize Hyperparameters
# ============================================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
            num_units, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )
    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ============================================
# 6. Train & Evaluate Model
# ============================================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate'])
    )

    # Training time
    start_train = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start_train

    # Inference time per sample
    start_infer = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    inference_time = (time.time() - start_infer) / len(X_test)

    # Testing time
    start_test = time.time()
    model.evaluate(X_test, y_test, verbose=0)  # Just to trigger testing phase
    testing_time = time.time() - start_test

    # Evaluation
    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print("\n===== Evaluation Results =====")
    print(f"Test Accuracy: {acc:.4f}")
    print("Classification Report:\n", classification_report(y_test, y_pred, digits=4))
    print("Confusion Matrix:\n", cm)

    # Save & calculate model size
    model.save("temp_model.h5", include_optimizer=False)
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)  # MB
    os.remove("temp_model.h5")

    # Trainable Parameters
    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])

    # RAM usage
    process = psutil.Process(os.getpid())
    ram_usage = process.memory_info().rss / (1024 ** 2)  # MB

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f} seconds")
    print(f"Inference Time per Sample: {inference_time:.6f} seconds")
    print(f"Testing Time: {testing_time:.2f} seconds")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Parameters: {total_params:,}")
    print(f"RAM Usage During Inference: {ram_usage:.2f} MB")

    return model, history

# ============================================
# 7. Main
# ============================================
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\Lasso_Selected_Features_H2\train_lasso_selected.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\Lasso_Selected_Features_H2\test_lasso_selected.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\nOptimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest Params:", best_params)

    print("\nTraining Final Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
# Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------
# | 1         | 1.0       | 33.98     | 0.4803    | 86.6      | 89.47     |
# | 2         | 1.0       | 23.49     | 0.1624    | 52.9      | 115.2     |
# | 3         | 1.0       | 44.85     | 0.3832    | 51.03     | 125.1     |
# | 4         | 1.0       | 55.96     | 0.1849    | 59.09     | 49.61     |
# | 5         | 1.0       | 30.6      | 0.3099    | 71.6      | 59.96     |
# | 6         | 1.0       | 58.87     | 0.237     | 99.91     | 32.34     |
# | 7         | 1.0       | 63.83     | 0.1911    | 99.11     | 127.8     |
# | 8         | 1.0       | 17.24     | 0.4906    | 50.56     | 33.63     |
# | 9         | 1.0       | 16.41     | 0.4657    | 98.87     | 127.3     |
# | 10        | 1.0       | 18.2      | 0.4567    | 99.88     | 32.67     |
# | 11        | 1.0       | 63.94     | 0.4128    | 50.58     | 125.6     |
# | 12        | 0.9959    | 62.79     | 0.1521    | 55.2      | 32.03     |
# | 13        | 1.0       | 18.12     | 0.1482    | 99.07     | 126.2     |
# | 14        | 1.0       | 48.2      | 0.2424    | 60.91     | 63.33     |
# | 15        | 1.0       | 50.12     | 0.4386    | 78.94     | 53.15     |
# | 16        | 1.0       | 37.09     | 0.3597    | 94.36     | 43.37     |
# | 17        | 1.0       | 21.58     | 0.3057    | 76.63     | 37.34     |
# | 18        | 1.0       | 19.16     | 0.2526    | 92.46     | 57.48     |
# | 19        | 1.0       | 40.29     | 0.1606    | 95.7      | 68.59     |
# | 20        | 1.0       | 36.38     | 0.4202    | 74.45     | 113.3     |
# =========================================================================
#
# Best Params: {'batch_size': 33.977925704673396, 'dropout_rate': 0.4802857225639665, 'epochs': 86.59969709057026, 'num_units': 89.47121448291551}
#
# Training Final Model...
# Epoch 1/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - accuracy: 0.4542 - loss: 1.2926 - val_accuracy: 0.4878 - val_loss: 1.0537
# Epoch 2/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5536 - loss: 1.0451 - val_accuracy: 0.7439 - val_loss: 0.8074
# Epoch 3/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6876 - loss: 0.8325 - val_accuracy: 0.8496 - val_loss: 0.5386
# Epoch 4/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8228 - loss: 0.5800 - val_accuracy: 0.8862 - val_loss: 0.3538
# Epoch 5/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8487 - loss: 0.4250 - val_accuracy: 0.9106 - val_loss: 0.2635
# Epoch 6/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8730 - loss: 0.3342 - val_accuracy: 0.9350 - val_loss: 0.2136
# Epoch 7/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8916 - loss: 0.3015 - val_accuracy: 0.9472 - val_loss: 0.1814
# Epoch 8/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9080 - loss: 0.2659 - val_accuracy: 0.9593 - val_loss: 0.1570
# Epoch 9/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9183 - loss: 0.2350 - val_accuracy: 0.9715 - val_loss: 0.1327
# Epoch 10/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9230 - loss: 0.2164 - val_accuracy: 0.9593 - val_loss: 0.1216
# Epoch 11/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9296 - loss: 0.1985 - val_accuracy: 0.9593 - val_loss: 0.1182
# Epoch 12/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9331 - loss: 0.2030 - val_accuracy: 0.9634 - val_loss: 0.1031
# Epoch 13/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9315 - loss: 0.2038 - val_accuracy: 0.9756 - val_loss: 0.0977
# Epoch 14/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9362 - loss: 0.1802 - val_accuracy: 0.9756 - val_loss: 0.0925
# Epoch 15/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9413 - loss: 0.1693 - val_accuracy: 0.9797 - val_loss: 0.0822
# Epoch 16/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9358 - loss: 0.1774 - val_accuracy: 0.9837 - val_loss: 0.0742
# Epoch 17/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9435 - loss: 0.1695 - val_accuracy: 0.9797 - val_loss: 0.0727
# Epoch 18/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9452 - loss: 0.1458 - val_accuracy: 0.9634 - val_loss: 0.0781
# Epoch 19/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9380 - loss: 0.1612 - val_accuracy: 0.9715 - val_loss: 0.0689
# Epoch 20/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9594 - loss: 0.1467 - val_accuracy: 0.9756 - val_loss: 0.0649
# Epoch 21/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9501 - loss: 0.1401 - val_accuracy: 0.9634 - val_loss: 0.0685
# Epoch 22/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9537 - loss: 0.1420 - val_accuracy: 0.9878 - val_loss: 0.0604
# Epoch 23/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9512 - loss: 0.1452 - val_accuracy: 0.9675 - val_loss: 0.0639
# Epoch 24/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9502 - loss: 0.1477 - val_accuracy: 0.9675 - val_loss: 0.0601
# Epoch 25/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9481 - loss: 0.1519 - val_accuracy: 0.9675 - val_loss: 0.0590
# Epoch 26/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9511 - loss: 0.1370 - val_accuracy: 0.9715 - val_loss: 0.0558
# Epoch 27/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9593 - loss: 0.1417 - val_accuracy: 0.9756 - val_loss: 0.0551
# Epoch 28/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9538 - loss: 0.1236 - val_accuracy: 0.9675 - val_loss: 0.0621
# Epoch 29/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9624 - loss: 0.1375 - val_accuracy: 0.9756 - val_loss: 0.0517
# Epoch 30/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9483 - loss: 0.1218 - val_accuracy: 0.9797 - val_loss: 0.0509
# Epoch 31/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9668 - loss: 0.1071 - val_accuracy: 0.9634 - val_loss: 0.0597
# Epoch 32/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9509 - loss: 0.1245 - val_accuracy: 0.9878 - val_loss: 0.0463
# Epoch 33/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9649 - loss: 0.1095 - val_accuracy: 0.9797 - val_loss: 0.0529
# Epoch 34/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9558 - loss: 0.1313 - val_accuracy: 0.9797 - val_loss: 0.0483
# Epoch 35/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9711 - loss: 0.1125 - val_accuracy: 0.9715 - val_loss: 0.0537
# Epoch 36/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9647 - loss: 0.1103 - val_accuracy: 0.9837 - val_loss: 0.0399
# Epoch 37/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9659 - loss: 0.1113 - val_accuracy: 0.9756 - val_loss: 0.0505
# Epoch 38/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9634 - loss: 0.1071 - val_accuracy: 0.9756 - val_loss: 0.0545
# Epoch 39/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9710 - loss: 0.1098 - val_accuracy: 0.9837 - val_loss: 0.0445
# Epoch 40/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9564 - loss: 0.1081 - val_accuracy: 0.9756 - val_loss: 0.0501
# Epoch 41/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9646 - loss: 0.1073 - val_accuracy: 0.9878 - val_loss: 0.0355
# Epoch 42/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9759 - loss: 0.0938 - val_accuracy: 0.9919 - val_loss: 0.0341
# Epoch 43/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9782 - loss: 0.0863 - val_accuracy: 0.9837 - val_loss: 0.0371
# Epoch 44/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9684 - loss: 0.0854 - val_accuracy: 0.9756 - val_loss: 0.0469
# Epoch 45/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9646 - loss: 0.1032 - val_accuracy: 0.9878 - val_loss: 0.0381
# Epoch 46/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9764 - loss: 0.0814 - val_accuracy: 0.9797 - val_loss: 0.0384
# Epoch 47/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9718 - loss: 0.0899 - val_accuracy: 0.9837 - val_loss: 0.0327
# Epoch 48/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9838 - loss: 0.0714 - val_accuracy: 0.9837 - val_loss: 0.0311
# Epoch 49/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9695 - loss: 0.0865 - val_accuracy: 0.9919 - val_loss: 0.0297
# Epoch 50/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9748 - loss: 0.0810 - val_accuracy: 0.9878 - val_loss: 0.0324
# Epoch 51/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9733 - loss: 0.0796 - val_accuracy: 0.9837 - val_loss: 0.0301
# Epoch 52/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9685 - loss: 0.0842 - val_accuracy: 0.9837 - val_loss: 0.0331
# Epoch 53/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9753 - loss: 0.0737 - val_accuracy: 0.9837 - val_loss: 0.0329
# Epoch 54/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9799 - loss: 0.0656 - val_accuracy: 0.9959 - val_loss: 0.0234
# Epoch 55/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9744 - loss: 0.0724 - val_accuracy: 0.9878 - val_loss: 0.0272
# Epoch 56/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9793 - loss: 0.0624 - val_accuracy: 0.9878 - val_loss: 0.0278
# Epoch 57/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9745 - loss: 0.0686 - val_accuracy: 0.9797 - val_loss: 0.0318
# Epoch 58/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9777 - loss: 0.0654 - val_accuracy: 1.0000 - val_loss: 0.0202
# Epoch 59/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9820 - loss: 0.0522 - val_accuracy: 0.9959 - val_loss: 0.0214
# Epoch 60/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9810 - loss: 0.0621 - val_accuracy: 0.9959 - val_loss: 0.0231
# Epoch 61/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9692 - loss: 0.0631 - val_accuracy: 0.9959 - val_loss: 0.0212
# Epoch 62/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9874 - loss: 0.0552 - val_accuracy: 0.9959 - val_loss: 0.0216
# Epoch 63/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9768 - loss: 0.0548 - val_accuracy: 0.9959 - val_loss: 0.0171
# Epoch 64/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9847 - loss: 0.0423 - val_accuracy: 0.9959 - val_loss: 0.0189
# Epoch 65/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9816 - loss: 0.0585 - val_accuracy: 0.9878 - val_loss: 0.0280
# Epoch 66/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9813 - loss: 0.0490 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 67/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9822 - loss: 0.0465 - val_accuracy: 1.0000 - val_loss: 0.0148
# Epoch 68/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9796 - loss: 0.0555 - val_accuracy: 1.0000 - val_loss: 0.0163
# Epoch 69/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9764 - loss: 0.0451 - val_accuracy: 0.9959 - val_loss: 0.0181
# Epoch 70/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9804 - loss: 0.0435 - val_accuracy: 0.9959 - val_loss: 0.0145
# Epoch 71/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9829 - loss: 0.0448 - val_accuracy: 1.0000 - val_loss: 0.0139
# Epoch 72/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9894 - loss: 0.0374 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 73/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9890 - loss: 0.0422 - val_accuracy: 0.9959 - val_loss: 0.0160
# Epoch 74/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9880 - loss: 0.0353 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 75/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9960 - loss: 0.0279 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 76/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9873 - loss: 0.0329 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 77/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9922 - loss: 0.0272 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 78/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9865 - loss: 0.0378 - val_accuracy: 0.9959 - val_loss: 0.0168
# Epoch 79/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9827 - loss: 0.0384 - val_accuracy: 0.9959 - val_loss: 0.0131
# Epoch 80/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9864 - loss: 0.0396 - val_accuracy: 0.9959 - val_loss: 0.0140
# Epoch 81/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9812 - loss: 0.0480 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 82/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9870 - loss: 0.0343 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 83/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9917 - loss: 0.0225 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 84/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0313 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 85/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9896 - loss: 0.0323 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 86/86
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9881 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 0.0069
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation Results =====
# Test Accuracy: 0.9533
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     1.0000    0.2619    0.4151        42
#            1     0.8721    0.9956    0.9298       226
#            2     0.9960    0.9902    0.9931       509
#            3     0.9211    0.9722    0.9459        36
#
#     accuracy                         0.9533       813
#    macro avg     0.9473    0.8050    0.8210       813
# weighted avg     0.9585    0.9533    0.9435       813
#
# Confusion Matrix:
#  [[ 11  31   0   0]
#  [  0 225   1   0]
#  [  0   2 504   3]
#  [  0   0   1  35]]
#
# ===== Model Metrics =====
# Training Time: 22.64 seconds
# Inference Time per Sample: 0.000780 seconds
# Testing Time: 0.12 seconds
# Model Size: 0.18 MB
# Trainable Parameters: 42,588
# RAM Usage During Inference: 1349.47 MB

# %% [markdown]
# Horizon 3 LSTM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import psutil
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ============================================
# 1. Data Loading and Preprocessing
# ============================================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h3'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()



    df.fillna(df.median(), inplace=True)
    return df, target_col

# ============================================
# 2. Feature Scaling
# ============================================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))  # LSTM expects 3D input
    return X_scaled, y, scaler

# ============================================
# 3. Build LSTM Model
# ============================================
def build_lstm_model(input_shape, num_classes=4, num_units=64, dropout_rate=0.2):
    model = Sequential()
    model.add(LSTM(num_units, input_shape=input_shape, return_sequences=False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ============================================
# 4. Bayesian Objective
# ============================================
def objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_units=int(num_units),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# ============================================
# 5. Optimize Hyperparameters
# ============================================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
            num_units, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )
    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ============================================
# 6. Train & Evaluate Model
# ============================================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate'])
    )

    # Training time
    start_train = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start_train

    # Inference time per sample
    start_infer = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    inference_time = (time.time() - start_infer) / len(X_test)

    # Testing time
    start_test = time.time()
    model.evaluate(X_test, y_test, verbose=0)  # Just to trigger testing phase
    testing_time = time.time() - start_test

    # Evaluation
    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print("\n===== Evaluation Results =====")
    print(f"Test Accuracy: {acc:.4f}")
    print("Classification Report:\n", classification_report(y_test, y_pred, digits=4))
    print("Confusion Matrix:\n", cm)

    # Save & calculate model size
    model.save("temp_model.h5", include_optimizer=False)
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)  # MB
    os.remove("temp_model.h5")

    # Trainable Parameters
    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])

    # RAM usage
    process = psutil.Process(os.getpid())
    ram_usage = process.memory_info().rss / (1024 ** 2)  # MB

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f} seconds")
    print(f"Inference Time per Sample: {inference_time:.6f} seconds")
    print(f"Testing Time: {testing_time:.2f} seconds")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Parameters: {total_params:,}")
    print(f"RAM Usage During Inference: {ram_usage:.2f} MB")

    return model, history

# ============================================
# 7. Main
# ============================================
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H3_train.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H3_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\nOptimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest Params:", best_params)

    print("\nTraining Final Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
# Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------
# | 1         | 0.9919    | 33.98     | 0.4803    | 86.6      | 89.47     |
# | 2         | 0.9959    | 23.49     | 0.1624    | 52.9      | 115.2     |
# | 3         | 0.9878    | 44.85     | 0.3832    | 51.03     | 125.1     |
# | 4         | 0.9878    | 55.96     | 0.1849    | 59.09     | 49.61     |
# | 5         | 0.9878    | 30.6      | 0.3099    | 71.6      | 59.96     |
# | 6         | 0.9959    | 22.97     | 0.3185    | 53.09     | 116.6     |
# | 7         | 0.9959    | 17.35     | 0.2868    | 66.53     | 109.0     |
# | 8         | 1.0       | 19.85     | 0.259     | 96.99     | 127.5     |
# | 9         | 0.9919    | 46.43     | 0.2861    | 99.9      | 126.2     |
# | 10        | 0.9959    | 16.08     | 0.4653    | 96.12     | 110.0     |
# | 11        | 1.0       | 16.06     | 0.2302    | 85.84     | 127.9     |
# | 12        | 0.9878    | 55.05     | 0.2309    | 99.48     | 33.32     |
# | 13        | 0.9959    | 17.14     | 0.3614    | 50.32     | 93.81     |
# | 14        | 0.9959    | 16.6      | 0.4329    | 97.94     | 126.3     |
# | 15        | 0.9959    | 24.79     | 0.1245    | 88.16     | 125.6     |
# | 16        | 1.0       | 26.43     | 0.1154    | 98.5      | 125.3     |
# | 17        | 1.0       | 16.86     | 0.3726    | 75.94     | 123.2     |
# | 18        | 1.0       | 16.15     | 0.1805    | 81.85     | 115.6     |
# | 19        | 0.9919    | 25.81     | 0.4066    | 74.39     | 114.8     |
# | 20        | 0.9959    | 19.95     | 0.4088    | 67.26     | 127.8     |
# =========================================================================
#
# Best Params: {'batch_size': 19.85335243268747, 'dropout_rate': 0.2590170634593081, 'epochs': 96.98808910760005, 'num_units': 127.5006823843842}
#
# Training Final Model...
# Epoch 1/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4204 - loss: 1.2198 - val_accuracy: 0.6382 - val_loss: 0.9152
# Epoch 2/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6091 - loss: 0.8877 - val_accuracy: 0.8089 - val_loss: 0.5797
# Epoch 3/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8237 - loss: 0.5341 - val_accuracy: 0.8333 - val_loss: 0.3886
# Epoch 4/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8642 - loss: 0.3710 - val_accuracy: 0.8618 - val_loss: 0.3314
# Epoch 5/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8782 - loss: 0.3363 - val_accuracy: 0.8821 - val_loss: 0.2850
# Epoch 6/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8848 - loss: 0.3006 - val_accuracy: 0.9024 - val_loss: 0.2527
# Epoch 7/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9066 - loss: 0.2663 - val_accuracy: 0.9106 - val_loss: 0.2263
# Epoch 8/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9060 - loss: 0.2411 - val_accuracy: 0.9187 - val_loss: 0.2056
# Epoch 9/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9259 - loss: 0.2225 - val_accuracy: 0.9187 - val_loss: 0.1952
# Epoch 10/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9219 - loss: 0.2073 - val_accuracy: 0.9268 - val_loss: 0.1694
# Epoch 11/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9306 - loss: 0.1965 - val_accuracy: 0.9350 - val_loss: 0.1506
# Epoch 12/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9385 - loss: 0.1727 - val_accuracy: 0.9350 - val_loss: 0.1436
# Epoch 13/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9327 - loss: 0.1662 - val_accuracy: 0.9431 - val_loss: 0.1307
# Epoch 14/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9419 - loss: 0.1664 - val_accuracy: 0.9472 - val_loss: 0.1204
# Epoch 15/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1578 - val_accuracy: 0.9593 - val_loss: 0.1151
# Epoch 16/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9452 - loss: 0.1388 - val_accuracy: 0.9553 - val_loss: 0.1005
# Epoch 17/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9529 - loss: 0.1302 - val_accuracy: 0.9593 - val_loss: 0.0974
# Epoch 18/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9465 - loss: 0.1327 - val_accuracy: 0.9715 - val_loss: 0.0963
# Epoch 19/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9642 - loss: 0.1231 - val_accuracy: 0.9797 - val_loss: 0.0858
# Epoch 20/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9661 - loss: 0.1148 - val_accuracy: 0.9715 - val_loss: 0.0792
# Epoch 21/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9565 - loss: 0.1244 - val_accuracy: 0.9837 - val_loss: 0.0752
# Epoch 22/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9583 - loss: 0.1075 - val_accuracy: 0.9715 - val_loss: 0.0718
# Epoch 23/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9676 - loss: 0.1041 - val_accuracy: 0.9837 - val_loss: 0.0689
# Epoch 24/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9647 - loss: 0.0970 - val_accuracy: 0.9715 - val_loss: 0.0637
# Epoch 25/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9664 - loss: 0.0936 - val_accuracy: 0.9797 - val_loss: 0.0596
# Epoch 26/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9753 - loss: 0.0840 - val_accuracy: 0.9837 - val_loss: 0.0561
# Epoch 27/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9738 - loss: 0.0895 - val_accuracy: 0.9919 - val_loss: 0.0592
# Epoch 28/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9700 - loss: 0.0934 - val_accuracy: 0.9797 - val_loss: 0.0532
# Epoch 29/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9654 - loss: 0.0847 - val_accuracy: 0.9837 - val_loss: 0.0524
# Epoch 30/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9830 - loss: 0.0728 - val_accuracy: 0.9878 - val_loss: 0.0490
# Epoch 31/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9735 - loss: 0.0823 - val_accuracy: 0.9919 - val_loss: 0.0458
# Epoch 32/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9694 - loss: 0.0784 - val_accuracy: 0.9919 - val_loss: 0.0453
# Epoch 33/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9792 - loss: 0.0750 - val_accuracy: 0.9919 - val_loss: 0.0459
# Epoch 34/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9786 - loss: 0.0719 - val_accuracy: 0.9878 - val_loss: 0.0443
# Epoch 35/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9811 - loss: 0.0672 - val_accuracy: 0.9959 - val_loss: 0.0400
# Epoch 36/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9770 - loss: 0.0666 - val_accuracy: 0.9959 - val_loss: 0.0394
# Epoch 37/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9783 - loss: 0.0669 - val_accuracy: 0.9878 - val_loss: 0.0390
# Epoch 38/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9772 - loss: 0.0702 - val_accuracy: 0.9919 - val_loss: 0.0444
# Epoch 39/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9846 - loss: 0.0644 - val_accuracy: 0.9919 - val_loss: 0.0364
# Epoch 40/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9858 - loss: 0.0596 - val_accuracy: 0.9878 - val_loss: 0.0366
# Epoch 41/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9748 - loss: 0.0666 - val_accuracy: 0.9959 - val_loss: 0.0329
# Epoch 42/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9840 - loss: 0.0484 - val_accuracy: 0.9919 - val_loss: 0.0317
# Epoch 43/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9799 - loss: 0.0574 - val_accuracy: 0.9959 - val_loss: 0.0302
# Epoch 44/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9857 - loss: 0.0583 - val_accuracy: 0.9919 - val_loss: 0.0321
# Epoch 45/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9819 - loss: 0.0526 - val_accuracy: 0.9919 - val_loss: 0.0324
# Epoch 46/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9851 - loss: 0.0501 - val_accuracy: 0.9919 - val_loss: 0.0300
# Epoch 47/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9854 - loss: 0.0535 - val_accuracy: 0.9878 - val_loss: 0.0314
# Epoch 48/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9823 - loss: 0.0502 - val_accuracy: 0.9959 - val_loss: 0.0274
# Epoch 49/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9830 - loss: 0.0442 - val_accuracy: 0.9959 - val_loss: 0.0250
# Epoch 50/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9862 - loss: 0.0493 - val_accuracy: 0.9959 - val_loss: 0.0253
# Epoch 51/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9856 - loss: 0.0372 - val_accuracy: 0.9959 - val_loss: 0.0273
# Epoch 52/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9820 - loss: 0.0441 - val_accuracy: 0.9919 - val_loss: 0.0259
# Epoch 53/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9772 - loss: 0.0488 - val_accuracy: 0.9959 - val_loss: 0.0227
# Epoch 54/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9854 - loss: 0.0443 - val_accuracy: 0.9959 - val_loss: 0.0238
# Epoch 55/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0356 - val_accuracy: 0.9959 - val_loss: 0.0220
# Epoch 56/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9884 - loss: 0.0355 - val_accuracy: 0.9959 - val_loss: 0.0266
# Epoch 57/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0386 - val_accuracy: 0.9919 - val_loss: 0.0248
# Epoch 58/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9845 - loss: 0.0437 - val_accuracy: 0.9959 - val_loss: 0.0216
# Epoch 59/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9850 - loss: 0.0299 - val_accuracy: 0.9959 - val_loss: 0.0195
# Epoch 60/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9887 - loss: 0.0360 - val_accuracy: 0.9959 - val_loss: 0.0199
# Epoch 61/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0323 - val_accuracy: 0.9919 - val_loss: 0.0216
# Epoch 62/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0368 - val_accuracy: 0.9919 - val_loss: 0.0188
# Epoch 63/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9916 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0192
# Epoch 64/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9901 - loss: 0.0378 - val_accuracy: 0.9919 - val_loss: 0.0171
# Epoch 65/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9913 - loss: 0.0240 - val_accuracy: 0.9959 - val_loss: 0.0154
# Epoch 66/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0259 - val_accuracy: 0.9959 - val_loss: 0.0127
# Epoch 67/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9903 - loss: 0.0281 - val_accuracy: 0.9959 - val_loss: 0.0158
# Epoch 68/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0286 - val_accuracy: 0.9959 - val_loss: 0.0255
# Epoch 69/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9893 - loss: 0.0325 - val_accuracy: 0.9959 - val_loss: 0.0198
# Epoch 70/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9910 - loss: 0.0339 - val_accuracy: 0.9959 - val_loss: 0.0125
# Epoch 71/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9889 - loss: 0.0251 - val_accuracy: 0.9959 - val_loss: 0.0113
# Epoch 72/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9930 - loss: 0.0262 - val_accuracy: 0.9919 - val_loss: 0.0255
# Epoch 73/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9941 - loss: 0.0223 - val_accuracy: 0.9919 - val_loss: 0.0124
# Epoch 74/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0274 - val_accuracy: 0.9959 - val_loss: 0.0117
# Epoch 75/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9937 - loss: 0.0203 - val_accuracy: 0.9959 - val_loss: 0.0189
# Epoch 76/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9946 - loss: 0.0166 - val_accuracy: 0.9919 - val_loss: 0.0167
# Epoch 77/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9962 - loss: 0.0150 - val_accuracy: 0.9919 - val_loss: 0.0142
# Epoch 78/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9938 - loss: 0.0186 - val_accuracy: 0.9959 - val_loss: 0.0127
# Epoch 79/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0227 - val_accuracy: 0.9959 - val_loss: 0.0100
# Epoch 80/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9955 - loss: 0.0185 - val_accuracy: 0.9919 - val_loss: 0.0220
# Epoch 81/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9935 - loss: 0.0202 - val_accuracy: 0.9959 - val_loss: 0.0144
# Epoch 82/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9961 - loss: 0.0147 - val_accuracy: 0.9959 - val_loss: 0.0149
# Epoch 83/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9963 - loss: 0.0221 - val_accuracy: 0.9959 - val_loss: 0.0126
# Epoch 84/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9968 - loss: 0.0169 - val_accuracy: 0.9959 - val_loss: 0.0160
# Epoch 85/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9974 - loss: 0.0148 - val_accuracy: 0.9959 - val_loss: 0.0078
# Epoch 86/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9936 - loss: 0.0158 - val_accuracy: 0.9959 - val_loss: 0.0109
# Epoch 87/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9927 - loss: 0.0173 - val_accuracy: 0.9919 - val_loss: 0.0209
# Epoch 88/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9968 - loss: 0.0136 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 89/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9961 - loss: 0.0116 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 90/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9954 - loss: 0.0178 - val_accuracy: 0.9959 - val_loss: 0.0172
# Epoch 91/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9940 - loss: 0.0185 - val_accuracy: 0.9919 - val_loss: 0.0098
# Epoch 92/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0176 - val_accuracy: 0.9959 - val_loss: 0.0108
# Epoch 93/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 94/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9958 - loss: 0.0088 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 95/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9959 - loss: 0.0099 - val_accuracy: 0.9878 - val_loss: 0.0212
# Epoch 96/96
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9906 - loss: 0.0268 - val_accuracy: 0.9959 - val_loss: 0.0089
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation Results =====
# Test Accuracy: 0.9766
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     1.0000    0.4815    0.6500        27
#            1     0.9378    0.9906    0.9635       213
#            2     0.9962    0.9943    0.9952       524
#            3     0.9423    1.0000    0.9703        49
#
#     accuracy                         0.9766       813
#    macro avg     0.9691    0.8666    0.8947       813
# weighted avg     0.9778    0.9766    0.9739       813
#
# Confusion Matrix:
#  [[ 13  14   0   0]
#  [  0 211   2   0]
#  [  0   0 521   3]
#  [  0   0   0  49]]
#
# ===== Model Metrics =====
# Training Time: 25.98 seconds
# Inference Time per Sample: 0.000652 seconds
# Testing Time: 0.20 seconds
# Model Size: 0.33 MB
# Trainable Parameters: 81,980
# RAM Usage During Inference: 1699.04 MB

# %% [markdown]
# Horizon 4 LSTM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
import os
import psutil
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ============================================
# 1. Data Loading and Preprocessing
# ============================================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h4'
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()



    df.fillna(df.median(), inplace=True)
    return df, target_col

# ============================================
# 2. Feature Scaling
# ============================================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = X_scaled.reshape((X_scaled.shape[0], 1, X_scaled.shape[1]))  # LSTM expects 3D input
    return X_scaled, y, scaler

# ============================================
# 3. Build LSTM Model
# ============================================
def build_lstm_model(input_shape, num_classes=4, num_units=64, dropout_rate=0.2):
    model = Sequential()
    model.add(LSTM(num_units, input_shape=input_shape, return_sequences=False))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ============================================
# 4. Bayesian Objective
# ============================================
def objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_units=int(num_units),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# ============================================
# 5. Optimize Hyperparameters
# ============================================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
            num_units, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )
    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ============================================
# 6. Train & Evaluate Model
# ============================================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_lstm_model(
        input_shape=(X_train.shape[1], X_train.shape[2]),
        num_classes=4,
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate'])
    )

    # Training time
    start_train = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start_train

    # Inference time per sample
    start_infer = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    inference_time = (time.time() - start_infer) / len(X_test)

    # Testing time
    start_test = time.time()
    model.evaluate(X_test, y_test, verbose=0)  # Just to trigger testing phase
    testing_time = time.time() - start_test

    # Evaluation
    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)

    print("\n===== Evaluation Results =====")
    print(f"Test Accuracy: {acc:.4f}")
    print("Classification Report:\n", classification_report(y_test, y_pred, digits=4))
    print("Confusion Matrix:\n", cm)

    # Save & calculate model size
    model.save("temp_model.h5", include_optimizer=False)
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)  # MB
    os.remove("temp_model.h5")

    # Trainable Parameters
    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])

    # RAM usage
    process = psutil.Process(os.getpid())
    ram_usage = process.memory_info().rss / (1024 ** 2)  # MB

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f} seconds")
    print(f"Inference Time per Sample: {inference_time:.6f} seconds")
    print(f"Testing Time: {testing_time:.2f} seconds")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Parameters: {total_params:,}")
    print(f"RAM Usage During Inference: {ram_usage:.2f} MB")

    return model, history

# ============================================
# 7. Main
# ============================================
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H4_train.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H4_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\nOptimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest Params:", best_params)

    print("\nTraining Final Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
# Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------
# | 1         | 0.9919    | 33.98     | 0.4803    | 86.6      | 89.47     |
# | 2         | 0.9919    | 23.49     | 0.1624    | 52.9      | 115.2     |
# | 3         | 0.9878    | 44.85     | 0.3832    | 51.03     | 125.1     |
# | 4         | 0.9837    | 55.96     | 0.1849    | 59.09     | 49.61     |
# | 5         | 0.9878    | 30.6      | 0.3099    | 71.6      | 59.96     |
# | 6         | 0.9919    | 22.97     | 0.3185    | 53.09     | 116.6     |
# | 7         | 0.9959    | 16.26     | 0.3996    | 90.52     | 118.5     |
# | 8         | 0.9959    | 28.92     | 0.1585    | 99.79     | 125.3     |
# | 9         | 0.9959    | 16.01     | 0.4354    | 98.89     | 104.6     |
# | 10        | 0.9959    | 17.0      | 0.2281    | 99.71     | 120.4     |
# | 11        | 0.9919    | 62.65     | 0.3616    | 99.98     | 127.8     |
# | 12        | 0.9959    | 27.26     | 0.359     | 99.47     | 112.6     |
# | 13        | 0.9959    | 16.01     | 0.4083    | 80.22     | 105.2     |
# | 14        | 0.9959    | 18.19     | 0.2867    | 91.15     | 108.4     |
# | 15        | 0.9919    | 18.3      | 0.1748    | 99.59     | 32.26     |
# | 16        | 0.9959    | 16.25     | 0.2012    | 98.81     | 79.49     |
# | 17        | 0.9959    | 16.02     | 0.3543    | 93.47     | 90.4      |
# | 18        | 1.0       | 17.06     | 0.1585    | 99.68     | 88.61     |
# | 19        | 0.9959    | 26.01     | 0.1584    | 99.48     | 93.44     |
# | 20        | 0.9878    | 62.34     | 0.287     | 100.0     | 33.69     |
# =========================================================================
#
# Best Params: {'batch_size': 17.062792368420432, 'dropout_rate': 0.1584660733322331, 'epochs': 99.67985510900867, 'num_units': 88.60770882234468}
#
# Training Final Model...
# Epoch 1/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.4528 - loss: 1.2668 - val_accuracy: 0.5976 - val_loss: 0.9419
# Epoch 2/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6066 - loss: 0.9408 - val_accuracy: 0.7805 - val_loss: 0.6580
# Epoch 3/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8046 - loss: 0.6350 - val_accuracy: 0.8211 - val_loss: 0.4362
# Epoch 4/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8328 - loss: 0.4476 - val_accuracy: 0.8618 - val_loss: 0.3384
# Epoch 5/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8625 - loss: 0.3680 - val_accuracy: 0.8780 - val_loss: 0.2878
# Epoch 6/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8913 - loss: 0.3088 - val_accuracy: 0.8862 - val_loss: 0.2493
# Epoch 7/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8904 - loss: 0.2916 - val_accuracy: 0.8943 - val_loss: 0.2169
# Epoch 8/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9092 - loss: 0.2456 - val_accuracy: 0.9146 - val_loss: 0.1998
# Epoch 9/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9158 - loss: 0.2325 - val_accuracy: 0.9228 - val_loss: 0.1737
# Epoch 10/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9196 - loss: 0.2112 - val_accuracy: 0.9350 - val_loss: 0.1594
# Epoch 11/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9314 - loss: 0.1963 - val_accuracy: 0.9553 - val_loss: 0.1452
# Epoch 12/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9352 - loss: 0.1772 - val_accuracy: 0.9634 - val_loss: 0.1326
# Epoch 13/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9500 - loss: 0.1603 - val_accuracy: 0.9797 - val_loss: 0.1227
# Epoch 14/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9594 - loss: 0.1510 - val_accuracy: 0.9837 - val_loss: 0.1120
# Epoch 15/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9619 - loss: 0.1437 - val_accuracy: 0.9837 - val_loss: 0.1045
# Epoch 16/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9671 - loss: 0.1358 - val_accuracy: 0.9837 - val_loss: 0.0998
# Epoch 17/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9685 - loss: 0.1237 - val_accuracy: 0.9878 - val_loss: 0.0933
# Epoch 18/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9690 - loss: 0.1253 - val_accuracy: 0.9837 - val_loss: 0.0889
# Epoch 19/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9670 - loss: 0.1176 - val_accuracy: 0.9837 - val_loss: 0.0842
# Epoch 20/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9725 - loss: 0.1077 - val_accuracy: 0.9837 - val_loss: 0.0814
# Epoch 21/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9742 - loss: 0.1021 - val_accuracy: 0.9837 - val_loss: 0.0761
# Epoch 22/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9755 - loss: 0.0984 - val_accuracy: 0.9837 - val_loss: 0.0750
# Epoch 23/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9735 - loss: 0.0923 - val_accuracy: 0.9837 - val_loss: 0.0718
# Epoch 24/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9743 - loss: 0.0912 - val_accuracy: 0.9837 - val_loss: 0.0679
# Epoch 25/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9778 - loss: 0.0864 - val_accuracy: 0.9837 - val_loss: 0.0657
# Epoch 26/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9779 - loss: 0.0859 - val_accuracy: 0.9837 - val_loss: 0.0631
# Epoch 27/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9734 - loss: 0.0817 - val_accuracy: 0.9878 - val_loss: 0.0585
# Epoch 28/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9805 - loss: 0.0793 - val_accuracy: 0.9837 - val_loss: 0.0574
# Epoch 29/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9769 - loss: 0.0775 - val_accuracy: 0.9878 - val_loss: 0.0541
# Epoch 30/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.0758 - val_accuracy: 0.9837 - val_loss: 0.0556
# Epoch 31/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9809 - loss: 0.0771 - val_accuracy: 0.9878 - val_loss: 0.0497
# Epoch 32/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9797 - loss: 0.0659 - val_accuracy: 0.9878 - val_loss: 0.0490
# Epoch 33/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9838 - loss: 0.0647 - val_accuracy: 0.9837 - val_loss: 0.0486
# Epoch 34/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9807 - loss: 0.0600 - val_accuracy: 0.9878 - val_loss: 0.0458
# Epoch 35/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9847 - loss: 0.0498 - val_accuracy: 0.9878 - val_loss: 0.0429
# Epoch 36/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9837 - loss: 0.0545 - val_accuracy: 0.9837 - val_loss: 0.0437
# Epoch 37/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0514 - val_accuracy: 0.9878 - val_loss: 0.0408
# Epoch 38/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9862 - loss: 0.0506 - val_accuracy: 0.9878 - val_loss: 0.0379
# Epoch 39/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9843 - loss: 0.0537 - val_accuracy: 0.9878 - val_loss: 0.0357
# Epoch 40/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9850 - loss: 0.0600 - val_accuracy: 0.9878 - val_loss: 0.0365
# Epoch 41/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0455 - val_accuracy: 0.9919 - val_loss: 0.0309
# Epoch 42/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9838 - loss: 0.0506 - val_accuracy: 0.9878 - val_loss: 0.0316
# Epoch 43/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9894 - loss: 0.0430 - val_accuracy: 0.9878 - val_loss: 0.0336
# Epoch 44/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9880 - loss: 0.0442 - val_accuracy: 0.9919 - val_loss: 0.0303
# Epoch 45/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9885 - loss: 0.0376 - val_accuracy: 0.9878 - val_loss: 0.0344
# Epoch 46/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9890 - loss: 0.0369 - val_accuracy: 0.9919 - val_loss: 0.0282
# Epoch 47/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0369 - val_accuracy: 0.9919 - val_loss: 0.0253
# Epoch 48/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9914 - loss: 0.0321 - val_accuracy: 0.9919 - val_loss: 0.0281
# Epoch 49/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9894 - loss: 0.0347 - val_accuracy: 0.9919 - val_loss: 0.0251
# Epoch 50/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9906 - loss: 0.0305 - val_accuracy: 0.9919 - val_loss: 0.0284
# Epoch 51/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9869 - loss: 0.0290 - val_accuracy: 0.9919 - val_loss: 0.0305
# Epoch 52/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9899 - loss: 0.0284 - val_accuracy: 0.9919 - val_loss: 0.0259
# Epoch 53/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9923 - loss: 0.0248 - val_accuracy: 0.9919 - val_loss: 0.0207
# Epoch 54/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9876 - loss: 0.0275 - val_accuracy: 0.9919 - val_loss: 0.0215
# Epoch 55/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9878 - loss: 0.0249 - val_accuracy: 0.9919 - val_loss: 0.0232
# Epoch 56/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9901 - loss: 0.0249 - val_accuracy: 0.9919 - val_loss: 0.0224
# Epoch 57/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.0274 - val_accuracy: 0.9919 - val_loss: 0.0204
# Epoch 58/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9927 - loss: 0.0205 - val_accuracy: 0.9919 - val_loss: 0.0197
# Epoch 59/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9952 - loss: 0.0206 - val_accuracy: 0.9919 - val_loss: 0.0184
# Epoch 60/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9951 - loss: 0.0193 - val_accuracy: 0.9919 - val_loss: 0.0159
# Epoch 61/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9952 - loss: 0.0203 - val_accuracy: 0.9919 - val_loss: 0.0159
# Epoch 62/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9989 - loss: 0.0172 - val_accuracy: 0.9919 - val_loss: 0.0244
# Epoch 63/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9963 - loss: 0.0192 - val_accuracy: 0.9919 - val_loss: 0.0231
# Epoch 64/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9948 - loss: 0.0163 - val_accuracy: 0.9959 - val_loss: 0.0121
# Epoch 65/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9943 - loss: 0.0171 - val_accuracy: 0.9919 - val_loss: 0.0184
# Epoch 66/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9954 - loss: 0.0181 - val_accuracy: 0.9878 - val_loss: 0.0311
# Epoch 67/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9963 - loss: 0.0160 - val_accuracy: 0.9919 - val_loss: 0.0187
# Epoch 68/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9957 - loss: 0.0159 - val_accuracy: 0.9919 - val_loss: 0.0195
# Epoch 69/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9950 - loss: 0.0128 - val_accuracy: 0.9919 - val_loss: 0.0190
# Epoch 70/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9968 - loss: 0.0139 - val_accuracy: 0.9919 - val_loss: 0.0255
# Epoch 71/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9958 - loss: 0.0167 - val_accuracy: 0.9919 - val_loss: 0.0187
# Epoch 72/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0119 - val_accuracy: 0.9919 - val_loss: 0.0155
# Epoch 73/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9962 - loss: 0.0119 - val_accuracy: 0.9959 - val_loss: 0.0133
# Epoch 74/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9989 - loss: 0.0127 - val_accuracy: 0.9959 - val_loss: 0.0138
# Epoch 75/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9979 - loss: 0.0105 - val_accuracy: 0.9919 - val_loss: 0.0242
# Epoch 76/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9944 - loss: 0.0173 - val_accuracy: 0.9959 - val_loss: 0.0098
# Epoch 77/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9953 - loss: 0.0112 - val_accuracy: 0.9919 - val_loss: 0.0266
# Epoch 78/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9972 - loss: 0.0117 - val_accuracy: 0.9959 - val_loss: 0.0187
# Epoch 79/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9990 - loss: 0.0079 - val_accuracy: 0.9919 - val_loss: 0.0223
# Epoch 80/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9972 - loss: 0.0096 - val_accuracy: 0.9959 - val_loss: 0.0154
# Epoch 81/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9994 - loss: 0.0078 - val_accuracy: 0.9959 - val_loss: 0.0156
# Epoch 82/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.0085 - val_accuracy: 0.9959 - val_loss: 0.0144
# Epoch 83/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.9959 - val_loss: 0.0132
# Epoch 84/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0056 - val_accuracy: 0.9959 - val_loss: 0.0186
# Epoch 85/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9974 - loss: 0.0083 - val_accuracy: 0.9919 - val_loss: 0.0207
# Epoch 86/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9946 - loss: 0.0134 - val_accuracy: 0.9959 - val_loss: 0.0146
# Epoch 87/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0062 - val_accuracy: 0.9919 - val_loss: 0.0221
# Epoch 88/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0071 - val_accuracy: 0.9919 - val_loss: 0.0176
# Epoch 89/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9989 - loss: 0.0072 - val_accuracy: 0.9919 - val_loss: 0.0220
# Epoch 90/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.9959 - val_loss: 0.0095
# Epoch 91/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.9959 - val_loss: 0.0107
# Epoch 92/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9939 - loss: 0.0110 - val_accuracy: 0.9959 - val_loss: 0.0188
# Epoch 93/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9968 - loss: 0.0079 - val_accuracy: 0.9959 - val_loss: 0.0172
# Epoch 94/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0046 - val_accuracy: 0.9959 - val_loss: 0.0161
# Epoch 95/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9959 - val_loss: 0.0128
# Epoch 96/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9971 - loss: 0.0083 - val_accuracy: 0.9959 - val_loss: 0.0126
# Epoch 97/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0040 - val_accuracy: 0.9959 - val_loss: 0.0181
# Epoch 98/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9994 - loss: 0.0061 - val_accuracy: 0.9959 - val_loss: 0.0170
# Epoch 99/99
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9990 - loss: 0.0042 - val_accuracy: 0.9959 - val_loss: 0.0203
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation Results =====
# Test Accuracy: 0.9582
# Classification Report:
#                precision    recall  f1-score   support
#
#            0     1.0000    0.3077    0.4706        13
#            1     0.9574    0.9045    0.9302       199
#            2     0.9871    0.9889    0.9880       541
#            3     0.7595    1.0000    0.8633        60
#
#     accuracy                         0.9582       813
#    macro avg     0.9260    0.8003    0.8130       813
# weighted avg     0.9632    0.9582    0.9564       813
#
# Confusion Matrix:
#  [[  4   8   0   1]
#  [  0 180   7  12]
#  [  0   0 535   6]
#  [  0   0   0  60]]
#
# ===== Model Metrics =====
# Training Time: 27.47 seconds
# Inference Time per Sample: 0.000597 seconds
# Testing Time: 0.12 seconds
# Model Size: 0.18 MB
# Trainable Parameters: 41,408
# RAM Usage During Inference: 2146.20 MB
