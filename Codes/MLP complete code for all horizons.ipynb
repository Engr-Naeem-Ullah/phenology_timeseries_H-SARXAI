# %% [markdown]
# Horizon 1

# %%
import pandas as pd
import numpy as np
import time
import os
import psutil
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models
from bayes_opt import BayesianOptimization
from scipy.fftpack import fft

np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# 1. Load and Preprocess Data
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath)
    df.columns = df.columns.str.replace('"', '').str.strip()
    if 'TIME' not in df.columns:
        raise KeyError("Column 'TIME' missing.")
    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'
    if target_col not in df.columns:
        target_col = 'target'
    if target_col not in df.columns:
        raise KeyError("Target column not found.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col].astype(int)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    df['month'] = df.index.month
    df['weekofyear'] = df.index.isocalendar().week
    df['year'] = df.index.isocalendar().year
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)
    df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()
    df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()
    df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    fft_values = fft(df[target_col].dropna().values)
    fft_real = np.real(fft_values)[:len(df[target_col])]
    fft_imag = np.imag(fft_values)[:len(df[target_col])]
    df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))])
    df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))])

    df.fillna(df.median(), inplace=True)
    return df, target_col

# 2. Feature Scaling
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled, y, scaler

# 3. MLP Model
def build_mlp_model(input_shape, num_classes=4, num_units=64, dropout_rate=0.2):
    model = models.Sequential()
    model.add(layers.Input(shape=(input_shape,)))
    model.add(layers.Dense(num_units, activation='relu'))
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(num_units // 2, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

# 4. Objective Function
def objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_mlp_model(
        input_shape=X_train.shape[1],
        num_classes=4,
        num_units=int(num_units),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# 5. Hyperparameter Optimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (30, 60),
        'batch_size': (16, 64)
    }
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
            num_units, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )
    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# 6. Train and Evaluate
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_mlp_model(
        input_shape=X_train.shape[1],
        num_classes=4,
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate'])
    )
    start = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start

    start = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    testing_time = time.time() - start
    inference_time = testing_time / len(X_test)

    print("\n===== Evaluation =====")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print(classification_report(y_test, y_pred, digits=4))
    print(confusion_matrix(y_test, y_pred))

    model.save("temp_model.h5")
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)
    os.remove("temp_model.h5")

    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    ram_usage = psutil.Process(os.getpid()).memory_info().rss / (1024 ** 2)

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f}s")
    print(f"Testing Time (total): {testing_time:.2f}s")
    print(f"Inference/sample: {inference_time:.6f}s")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Params: {total_params:,}")
    print(f"RAM Usage: {ram_usage:.2f} MB")

    return model, history

# 7. Main
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1_train.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\n Optimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\n Best Hyperparameters:", best_params)

    print("\n Training Final MLP Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
#  Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------
# | 1         | 1.0       | 33.98     | 0.4803    | 51.96     | 89.47     |
# | 2         | 1.0       | 23.49     | 0.1624    | 31.74     | 115.2     |
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 184
#     181     model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)
#     183 if __name__ == "__main__":
# --> 184     main()
#
# Cell In[1], line 177, in main()
#     174 X_test, y_test, _ = feature_scaling(df_test, target_col)
#     176 print("\n Optimizing Hyperparameters...")
# --> 177 best_params = optimize_hyperparameters(X_train, y_train)
#     178 print("\n Best Hyperparameters:", best_params)
#     180 print("\n Training Final MLP Model...")
#
# Cell In[1], line 117, in optimize_hyperparameters(X_train, y_train)
#     103 pbounds = {
#     104     'num_units': (32, 128),
#     105     'dropout_rate': (0.1, 0.5),
#     106     'epochs': (30, 60),
#     107     'batch_size': (16, 64)
#     108 }
#     109 optimizer = BayesianOptimization(
#     110     f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
#     111         num_units, dropout_rate, epochs, batch_size, X_train, y_train
#    (...)
#     115     verbose=2
#     116 )
# --> 117 optimizer.maximize(init_points=5, n_iter=15)
#     118 return optimizer.max['params']
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\bayes_opt\bayesian_optimization.py:338, in BayesianOptimization.maximize(self, init_points, n_iter)
#     336     x_probe = self.suggest()
#     337     iteration += 1
# --> 338 self.probe(x_probe, lazy=False)
#     340 if self._bounds_transformer and iteration > 0:
#     341     # The bounds transformer should only modify the bounds after
#     342     # the init_points points (only for the true iterations)
#     343     self.set_bounds(self._bounds_transformer.transform(self._space))
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\bayes_opt\bayesian_optimization.py:270, in BayesianOptimization.probe(self, params, lazy)
#     268     self._queue.append(params)
#     269 else:
# --> 270     self._space.probe(params)
#     271     self.dispatch(Events.OPTIMIZATION_STEP)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\bayes_opt\target_space.py:418, in TargetSpace.probe(self, params)
#     416     error_msg = "No target function has been provided."
#     417     raise ValueError(error_msg)
# --> 418 target = self.target_func(**dict_params)
#     420 if self._constraint is None:
#     421     self.register(x, target)
#
# Cell In[1], line 110, in optimize_hyperparameters.<locals>.<lambda>(num_units, dropout_rate, epochs, batch_size)
#     102 def optimize_hyperparameters(X_train, y_train):
#     103     pbounds = {
#     104         'num_units': (32, 128),
#     105         'dropout_rate': (0.1, 0.5),
#     106         'epochs': (30, 60),
#     107         'batch_size': (16, 64)
#     108     }
#     109     optimizer = BayesianOptimization(
# --> 110         f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
#     111             num_units, dropout_rate, epochs, batch_size, X_train, y_train
#     112         ),
#     113         pbounds=pbounds,
#     114         random_state=42,
#     115         verbose=2
#     116     )
#     117     optimizer.maximize(init_points=5, n_iter=15)
#     118     return optimizer.max['params']
#
# Cell In[1], line 92, in objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train)
#      85 def objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train):
#      86     model = build_mlp_model(
#      87         input_shape=X_train.shape[1],
#      88         num_classes=4,
#      89         num_units=int(num_units),
#      90         dropout_rate=dropout_rate
#      91     )
# ---> 92     history = model.fit(
#      93         X_train, y_train,
#      94         epochs=int(epochs),
#      95         batch_size=int(batch_size),
#      96         validation_split=0.2,
#      97         verbose=0
#      98     )
#      99     return np.max(history.history['val_accuracy'])
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     logs = self._pythonify_logs(logs)
#     322     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:121, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator(iterator)
#     119 """Runs a single training step given a Dataset iterator."""
#     120 data = next(iterator)
# --> 121 outputs = self.distribute_strategy.run(
#     122     one_step_on_data, args=(data,)
#     123 )
#     124 outputs = reduce_per_replica(
#     125     outputs,
#     126     self.distribute_strategy,
#     127     reduction="auto",
#     128 )
#     129 return outputs
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1673, in StrategyBase.run(***failed resolving arguments***)
#    1668 with self.scope():
#    1669   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670   # applied when the caller is also in Eager mode.
#    1671   fn = autograph.tf_convert(
#    1672       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3263, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3261   kwargs = {}
#    3262 with self._container_strategy().scope():
# -> 3263   return self._call_for_each_replica(fn, args, kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4061, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4059 def _call_for_each_replica(self, fn, args, kwargs):
#    4060   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061     return fn(*args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\func_graph.py:1059, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1056   return x
#    1058 _, original_func = tf_decorator.unwrap(python_func)
# -> 1059 func_outputs = python_func(*func_args, **func_kwargs)
#    1061 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1062 # TensorArrays and `None`s.
#    1063 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\eager\polymorphic_function\autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:108, in TensorFlowTrainer.make_train_function.<locals>.one_step_on_data(data)
#     105 @tf.autograph.experimental.do_not_convert
#     106 def one_step_on_data(data):
#     107     """Runs a single training step on a batch of data."""
# --> 108     return self.train_step(data)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:73, in TensorFlowTrainer.train_step(self, data)
#      70     gradients = tape.gradient(loss, trainable_weights)
#      72     # Update weights
# ---> 73     self.optimizer.apply_gradients(zip(gradients, trainable_weights))
#      74 else:
#      75     warnings.warn("The model does not have any trainable weights.")
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\optimizers\base_optimizer.py:291, in BaseOptimizer.apply_gradients(self, grads_and_vars)
#     289 def apply_gradients(self, grads_and_vars):
#     290     grads, trainable_variables = zip(*grads_and_vars)
# --> 291     self.apply(grads, trainable_variables)
#     292     # Return iterations for compat with tf.keras.
#     293     return self._iterations
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\optimizers\base_optimizer.py:356, in BaseOptimizer.apply(self, grads, trainable_variables)
#     353     grads = [g if g is None else g / scale for g in grads]
#     355 # Apply gradient updates.
# --> 356 self._backend_apply_gradients(grads, trainable_variables)
#     357 # Apply variable constraints after applying gradients.
#     358 for variable in trainable_variables:
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\optimizers\base_optimizer.py:419, in BaseOptimizer._backend_apply_gradients(self, grads, trainable_variables)
#     416     self._apply_weight_decay(trainable_variables)
#     418     # Run udpate step.
# --> 419     self._backend_update_step(
#     420         grads, trainable_variables, self.learning_rate
#     421     )
#     423 if self.use_ema:
#     424     self._update_model_variables_moving_average(
#     425         self._trainable_variables
#     426     )
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\optimizer.py:121, in TFOptimizer._backend_update_step(self, grads, trainable_variables, learning_rate)
#     119 grads_and_vars = list(zip(grads, trainable_variables))
#     120 grads_and_vars = self._all_reduce_sum_gradients(grads_and_vars)
# --> 121 tf.__internal__.distribute.interim.maybe_merge_call(
#     122     self._distributed_tf_update_step,
#     123     self._distribution_strategy,
#     124     grads_and_vars,
#     125     learning_rate,
#     126 )
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\optimizer.py:135, in TFOptimizer._distributed_tf_update_step(self, distribution, grads_and_vars, learning_rate)
#     132     return self.update_step(grad, var, learning_rate)
#     134 for grad, var in grads_and_vars:
# --> 135     distribution.extended.update(
#     136         var,
#     137         apply_grad_to_update_var,
#     138         args=(grad, learning_rate),
#     139         group=False,
#     140     )
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3007, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3005     return self._update(var, fn, args, kwargs, group)
#    3006 else:
# -> 3007   return self._replica_ctx_update(
#    3008       var, fn, args=args, kwargs=kwargs, group=group)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2886, in StrategyExtendedV2._replica_ctx_update(self, var, fn, args, kwargs, group)
#    2883 def merge_fn(_, *merged_args, **merged_kwargs):
#    2884   return self.update(var, fn, merged_args, merged_kwargs, group=group)
# -> 2886 return replica_context.merge_call(merge_fn, args=args, kwargs=kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3478, in ReplicaContextBase.merge_call(self, merge_fn, args, kwargs)
#    3474   kwargs = {}
#    3476 merge_fn = autograph.tf_convert(
#    3477     merge_fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 3478 return self._merge_call(merge_fn, args, kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3485, in ReplicaContextBase._merge_call(self, merge_fn, args, kwargs)
#    3482 _push_per_thread_mode(  # thread-local, so not needed with multiple threads
#    3483     _CrossReplicaThreadMode(self._strategy))  # pylint: disable=protected-access
#    3484 try:
# -> 3485   return merge_fn(self._strategy, *args, **kwargs)
#    3486 finally:
#    3487   _pop_per_thread_mode()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2884, in StrategyExtendedV2._replica_ctx_update.<locals>.merge_fn(_, *merged_args, **merged_kwargs)
#    2883 def merge_fn(_, *merged_args, **merged_kwargs):
# -> 2884   return self.update(var, fn, merged_args, merged_kwargs, group=group)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3005, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3002   fn = autograph.tf_convert(
#    3003       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3004   with self._container_strategy().scope():
# -> 3005     return self._update(var, fn, args, kwargs, group)
#    3006 else:
#    3007   return self._replica_ctx_update(
#    3008       var, fn, args=args, kwargs=kwargs, group=group)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4075, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4072 def _update(self, var, fn, args, kwargs, group):
#    4073   # The implementations of _update() and _update_non_slot() are identical
#    4074   # except _update() passes `var` as the first argument to `fn()`.
# -> 4075   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4081, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4077 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4078   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4079   # once that value is used for something.
#    4080   with UpdateContext(colocate_with):
# -> 4081     result = fn(*args, **kwargs)
#    4082     if should_group:
#    4083       return result
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\autograph\impl\api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\optimizer.py:132, in TFOptimizer._distributed_tf_update_step.<locals>.apply_grad_to_update_var(var, grad, learning_rate)
#     131 def apply_grad_to_update_var(var, grad, learning_rate):
# --> 132     return self.update_step(grad, var, learning_rate)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\optimizers\adam.py:130, in Adam.update_step(self, gradient, variable, learning_rate)
#     127 m = self._momentums[self._get_variable_index(variable)]
#     128 v = self._velocities[self._get_variable_index(variable)]
# --> 130 alpha = lr * ops.sqrt(1 - beta_2_power) / (1 - beta_1_power)
#     132 self.assign_add(
#     133     m, ops.multiply(ops.subtract(gradient, m), 1 - self.beta_1)
#     134 )
#     135 self.assign_add(
#     136     v,
#     137     ops.multiply(
#     138         ops.subtract(ops.square(gradient), v), 1 - self.beta_2
#     139     ),
#     140 )
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\override_binary_operator.py:113, in override_binary_operator_helper.<locals>.binary_op_wrapper(x, y)
#     108 try:
#     109   # force_same_dtype=False to preserve existing TF behavior
#     110   # TODO(b/178860388): Figure out why binary_op_wrapper and
#     111   #   r_binary_op_wrapper use different force_same_dtype values.
#     112   x, y = maybe_promote_tensors(x, y)
# --> 113   return func(x, y, name=name)
#     114 except (TypeError, ValueError) as e:
#     115   # Even if dispatching the op failed, the RHS may be a tensor aware
#     116   # object that can implement the operator with knowledge of itself
#    (...)
#     119   # original error from the LHS, because it may be more
#     120   # informative.
#     121   if hasattr(type(y), "__r%s__" % op_name):
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\tensor_math_operator_overrides.py:88, in _truediv_factory(x, y, name)
#      85 def _truediv_factory(x, y, name=None):
#      86   from tensorflow.python.ops import math_ops
# ---> 88   return math_ops.truediv(x, y, name=name)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\math_ops.py:1507, in truediv(x, y, name)
#    1476 @tf_export("math.truediv", "truediv")
#    1477 @dispatch.register_binary_elementwise_api
#    1478 @dispatch.add_dispatch_support
#    1479 def truediv(x, y, name=None):
#    1480   """Divides x / y elementwise (using Python 3 division operator semantics).
#    1481
#    1482   NOTE: Prefer using the Tensor operator or tf.divide which obey Python
#    (...)
#    1505     TypeError: If `x` and `y` have different dtypes.
#    1506   """
# -> 1507   return _truediv_python3(x, y, name)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\math_ops.py:1445, in _truediv_python3(x, y, name)
#    1443   x = cast(x, dtype)
#    1444   y = cast(y, dtype)
# -> 1445 return gen_math_ops.real_div(x, y, name=name)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\ops\gen_math_ops.py:9021, in real_div(x, y, name)
#    9019 # Add nodes to the TensorFlow graph.
#    9020 try:
# -> 9021   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9022       "RealDiv", x=x, y=y, name=name)
#    9023 except (TypeError, ValueError):
#    9024   _result = _dispatch.dispatch(
#    9025         real_div, (), dict(x=x, y=y, name=name)
#    9026       )
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\op_def_library.py:796, in _apply_op_helper(op_type_name, name, **keywords)
#     791 must_colocate_inputs = [val for arg, val in zip(op_def.input_arg, inputs)
#     792                         if arg.is_ref]
#     793 with _MaybeColocateWith(must_colocate_inputs):
#     794   # Add Op to graph
#     795   # pylint: disable=protected-access
# --> 796   op = g._create_op_internal(op_type_name, inputs, dtypes=None,
#     797                              name=scope, input_types=input_types,
#     798                              attrs=attr_protos, op_def=op_def)
#     800 # `outputs` is returned as a separate return value so that the output
#     801 # tensors can the `op` per se can be decoupled so that the
#     802 # `op_callbacks` can function properly. See framework/op_callbacks.py
#     803 # for more details.
#     804 outputs = op.outputs
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\ops.py:2701, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2698 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2699 # Session.run call cannot occur between creating and mutating the op.
#    2700 with self._mutation_lock():
# -> 2701   ret = Operation.from_node_def(
#    2702       node_def,
#    2703       self,
#    2704       inputs=inputs,
#    2705       output_types=dtypes,
#    2706       control_inputs=control_inputs,
#    2707       input_types=input_types,
#    2708       original_op=self._default_original_op,
#    2709       op_def=op_def,
#    2710   )
#    2711   self._create_op_helper(ret, compute_device=compute_device)
#    2712 return ret
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\ops.py:1196, in Operation.from_node_def(***failed resolving arguments***)
#    1193     control_input_ops.append(control_op)
#    1195 # Initialize c_op from node_def and other inputs
# -> 1196 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1197 self = Operation(c_op, SymbolicTensor)
#    1198 self._init(g)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\framework\ops.py:1053, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1049   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1050                                          serialized)
#    1052 try:
# -> 1053   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1054 except errors.InvalidArgumentError as e:
#    1055   # Convert to ValueError for backwards compatibility.
#    1056   raise ValueError(e.message)
#
# KeyboardInterrupt:

# %% [markdown]
# Horizon 2

# %%
import pandas as pd
import numpy as np
import time
import os
import psutil
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models
from bayes_opt import BayesianOptimization

np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# 1. Load and Preprocess Data
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath)
    df.columns = df.columns.str.replace('"', '').str.strip()
    if 'TIME' not in df.columns:
        raise KeyError("Column 'TIME' missing.")
    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h2'
    if target_col not in df.columns:
        target_col = 'target'
    if target_col not in df.columns:
        raise KeyError("Target column not found.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col].astype(int)
    df[target_col] = df[target_col] - 1  # ensure 0-indexed

    if df[target_col].min() < 0:
        raise ValueError("Invalid label: contains negative class.")

    df.fillna(df.median(), inplace=True)
    return df, target_col

# 2. Feature Scaling
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col].astype(int)
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled, y, scaler

# 3. MLP Model
def build_mlp_model(input_shape, num_classes=4, num_units=64, dropout_rate=0.2):
    model = models.Sequential()
    model.add(layers.Input(shape=(input_shape,)))
    model.add(layers.Dense(num_units, activation='relu'))
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(num_units // 2, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

# 4. Objective Function
def objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_mlp_model(
        input_shape=X_train.shape[1],
        num_classes=4,
        num_units=int(num_units),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# 5. Hyperparameter Optimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (30, 60),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
            num_units, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )
    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# 6. Train and Evaluate
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_mlp_model(
        input_shape=X_train.shape[1],
        num_classes=4,
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate'])
    )

    start_train = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start_train

    start_test = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    total_testing_time = time.time() - start_test
    inference_time = total_testing_time / len(X_test)

    print("\n===== Evaluation =====")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print(classification_report(y_test, y_pred, digits=4))
    print(confusion_matrix(y_test, y_pred))

    model.save("temp_model.h5")
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)
    os.remove("temp_model.h5")

    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    ram_usage = psutil.Process(os.getpid()).memory_info().rss / (1024 ** 2)

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f} seconds")
    print(f"Total Testing Time: {total_testing_time:.2f} seconds")
    print(f"Inference Time per Sample: {inference_time:.6f} seconds")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Params: {total_params:,}")
    print(f"RAM Usage: {ram_usage:.2f} MB")

    return model, history

# 7. Main
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\Lasso_Selected_Features_H2\train_lasso_selected.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\Lasso_Selected_Features_H2\test_lasso_selected.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\n Optimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\n Best Hyperparameters:", best_params)

    print("\n Training Final MLP Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
#  Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------
# | 1         | 0.9959    | 33.98     | 0.4803    | 51.96     | 89.47     |
# | 2         | 0.9959    | 23.49     | 0.1624    | 31.74     | 115.2     |
# | 3         | 0.9878    | 44.85     | 0.3832    | 30.62     | 125.1     |
# | 4         | 0.9837    | 55.96     | 0.1849    | 35.45     | 49.61     |
# | 5         | 0.9959    | 30.6      | 0.3099    | 42.96     | 59.96     |
# | 6         | 0.9959    | 22.21     | 0.3256    | 31.47     | 115.9     |
# | 7         | 1.0       | 17.3      | 0.4132    | 35.12     | 86.83     |
# | 8         | 0.9959    | 16.29     | 0.3761    | 56.62     | 69.8      |
# | 9         | 1.0       | 16.43     | 0.3942    | 59.5      | 113.4     |
# | 10        | 0.9959    | 18.2      | 0.4567    | 59.93     | 32.67     |
# | 11        | 1.0       | 16.19     | 0.354     | 30.41     | 69.48     |
# | 12        | 0.9959    | 18.2      | 0.1278    | 30.49     | 32.39     |
# | 13        | 0.9959    | 16.61     | 0.4199    | 49.49     | 101.4     |
# | 14        | 0.9959    | 23.85     | 0.1789    | 59.69     | 127.3     |
# | 15        | 0.9837    | 31.96     | 0.4452    | 30.61     | 81.02     |
# | 16        | 0.9959    | 16.17     | 0.2369    | 39.01     | 75.66     |
# | 17        | 1.0       | 16.35     | 0.3475    | 36.68     | 96.12     |
# | 18        | 0.9959    | 16.67     | 0.4804    | 32.27     | 55.36     |
# | 19        | 0.9959    | 27.39     | 0.133     | 58.5      | 109.2     |
# | 20        | 1.0       | 17.46     | 0.4207    | 49.3      | 118.7     |
# =========================================================================
#
#  Best Hyperparameters: {'batch_size': 17.297905108071824, 'dropout_rate': 0.41318530040431023, 'epochs': 35.116729137353275, 'num_units': 86.82668797162603}
#
#  Training Final MLP Model...
# Epoch 1/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4217 - loss: 1.2480 - val_accuracy: 0.7033 - val_loss: 0.8554
# Epoch 2/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6766 - loss: 0.8600 - val_accuracy: 0.8252 - val_loss: 0.5851
# Epoch 3/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7458 - loss: 0.6561 - val_accuracy: 0.8740 - val_loss: 0.4588
# Epoch 4/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7534 - loss: 0.5730 - val_accuracy: 0.9024 - val_loss: 0.3773
# Epoch 5/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8184 - loss: 0.4740 - val_accuracy: 0.9634 - val_loss: 0.3154
# Epoch 6/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8494 - loss: 0.4196 - val_accuracy: 0.9715 - val_loss: 0.2725
# Epoch 7/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8525 - loss: 0.3879 - val_accuracy: 0.9797 - val_loss: 0.2282
# Epoch 8/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8863 - loss: 0.3384 - val_accuracy: 0.9797 - val_loss: 0.2014
# Epoch 9/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9034 - loss: 0.3180 - val_accuracy: 0.9837 - val_loss: 0.1728
# Epoch 10/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9127 - loss: 0.2669 - val_accuracy: 0.9837 - val_loss: 0.1488
# Epoch 11/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9363 - loss: 0.2267 - val_accuracy: 0.9837 - val_loss: 0.1296
# Epoch 12/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9428 - loss: 0.2116 - val_accuracy: 0.9837 - val_loss: 0.1129
# Epoch 13/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9423 - loss: 0.2020 - val_accuracy: 0.9837 - val_loss: 0.1013
# Epoch 14/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9418 - loss: 0.1842 - val_accuracy: 0.9837 - val_loss: 0.0938
# Epoch 15/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9482 - loss: 0.1736 - val_accuracy: 0.9878 - val_loss: 0.0809
# Epoch 16/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9545 - loss: 0.1541 - val_accuracy: 0.9878 - val_loss: 0.0702
# Epoch 17/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9597 - loss: 0.1346 - val_accuracy: 0.9878 - val_loss: 0.0613
# Epoch 18/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9695 - loss: 0.1169 - val_accuracy: 0.9878 - val_loss: 0.0568
# Epoch 19/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9667 - loss: 0.1132 - val_accuracy: 0.9919 - val_loss: 0.0517
# Epoch 20/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9696 - loss: 0.0969 - val_accuracy: 0.9878 - val_loss: 0.0461
# Epoch 21/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9681 - loss: 0.1071 - val_accuracy: 0.9878 - val_loss: 0.0472
# Epoch 22/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9740 - loss: 0.0967 - val_accuracy: 0.9959 - val_loss: 0.0433
# Epoch 23/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9720 - loss: 0.0959 - val_accuracy: 0.9878 - val_loss: 0.0381
# Epoch 24/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9598 - loss: 0.1006 - val_accuracy: 0.9959 - val_loss: 0.0347
# Epoch 25/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9679 - loss: 0.0919 - val_accuracy: 0.9959 - val_loss: 0.0337
# Epoch 26/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9722 - loss: 0.0859 - val_accuracy: 0.9959 - val_loss: 0.0309
# Epoch 27/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9775 - loss: 0.0795 - val_accuracy: 0.9959 - val_loss: 0.0292
# Epoch 28/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9739 - loss: 0.0770 - val_accuracy: 0.9878 - val_loss: 0.0345
# Epoch 29/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9801 - loss: 0.0642 - val_accuracy: 0.9959 - val_loss: 0.0308
# Epoch 30/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9738 - loss: 0.0681 - val_accuracy: 1.0000 - val_loss: 0.0245
# Epoch 31/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9703 - loss: 0.0775 - val_accuracy: 0.9959 - val_loss: 0.0262
# Epoch 32/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9746 - loss: 0.0694 - val_accuracy: 0.9959 - val_loss: 0.0243
# Epoch 33/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9788 - loss: 0.0632 - val_accuracy: 0.9959 - val_loss: 0.0222
# Epoch 34/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9766 - loss: 0.0622 - val_accuracy: 0.9959 - val_loss: 0.0200
# Epoch 35/35
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9904 - loss: 0.0446 - val_accuracy: 0.9959 - val_loss: 0.0209
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation =====
# Accuracy: 0.9865
#               precision    recall  f1-score   support
#
#            0     0.9024    0.8810    0.8916        42
#            1     0.9778    0.9735    0.9756       226
#            2     0.9961    1.0000    0.9980       509
#            3     1.0000    1.0000    1.0000        36
#
#     accuracy                         0.9865       813
#    macro avg     0.9691    0.9636    0.9663       813
# weighted avg     0.9863    0.9865    0.9864       813
#
# [[ 37   5   0   0]
#  [  4 220   2   0]
#  [  0   0 509   0]
#  [  0   0   0  36]]
#
# ===== Model Metrics =====
# Training Time: 8.53 seconds
# Total Testing Time: 0.26 seconds
# Inference Time per Sample: 0.000324 seconds
# Model Size: 0.08 MB
# Trainable Params: 4,605
# RAM Usage: 940.93 MB

# %% [markdown]
# Horizon 3

# %%
import pandas as pd
import numpy as np
import time
import os
import psutil
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models
from bayes_opt import BayesianOptimization
from scipy.fftpack import fft

np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# 1. Load and Preprocess Data
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath)
    df.columns = df.columns.str.replace('"', '').str.strip()
    if 'TIME' not in df.columns:
        raise KeyError("Column 'TIME' missing.")
    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h3'
    if target_col not in df.columns:
        target_col = 'target'
    if target_col not in df.columns:
        raise KeyError("Target column not found.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col].astype(int)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()



    df.fillna(df.median(), inplace=True)
    return df, target_col

# 2. Feature Scaling
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled, y, scaler

# 3. MLP Model
def build_mlp_model(input_shape, num_classes=4, num_units=64, dropout_rate=0.2):
    model = models.Sequential()
    model.add(layers.Input(shape=(input_shape,)))
    model.add(layers.Dense(num_units, activation='relu'))
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(num_units // 2, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

# 4. Objective Function
def objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_mlp_model(
        input_shape=X_train.shape[1],
        num_classes=4,
        num_units=int(num_units),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# 5. Hyperparameter Optimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (30, 60),
        'batch_size': (16, 64)
    }
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
            num_units, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )
    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# 6. Train and Evaluate
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_mlp_model(
        input_shape=X_train.shape[1],
        num_classes=4,
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate'])
    )
    start = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start

    start = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    testing_time = time.time() - start
    inference_time = testing_time / len(X_test)

    print("\n===== Evaluation =====")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print(classification_report(y_test, y_pred, digits=4))
    print(confusion_matrix(y_test, y_pred))

    model.save("temp_model.h5")
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)
    os.remove("temp_model.h5")

    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    ram_usage = psutil.Process(os.getpid()).memory_info().rss / (1024 ** 2)

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f}s")
    print(f"Testing Time (total): {testing_time:.2f}s")
    print(f"Inference/sample: {inference_time:.6f}s")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Params: {total_params:,}")
    print(f"RAM Usage: {ram_usage:.2f} MB")

    return model, history

# 7. Main
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H3_train.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H3_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\n Optimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\n Best Hyperparameters:", best_params)

    print("\n Training Final MLP Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
#  Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------
# | 1         | 0.9837    | 33.98     | 0.4803    | 51.96     | 89.47     |
# | 2         | 0.9878    | 23.49     | 0.1624    | 31.74     | 115.2     |
# | 3         | 0.9837    | 44.85     | 0.3832    | 30.62     | 125.1     |
# | 4         | 0.9634    | 55.96     | 0.1849    | 35.45     | 49.61     |
# | 5         | 0.9797    | 30.6      | 0.3099    | 42.96     | 59.96     |
# | 6         | 0.9959    | 17.03     | 0.1144    | 59.75     | 126.0     |
# | 7         | 0.9878    | 40.62     | 0.3098    | 59.5      | 127.1     |
# | 8         | 0.9837    | 23.98     | 0.4888    | 32.56     | 116.6     |
# | 9         | 0.9959    | 19.27     | 0.441     | 57.97     | 122.2     |
# | 10        | 0.9919    | 24.99     | 0.1473    | 55.75     | 126.7     |
# | 11        | 0.9919    | 16.38     | 0.3724    | 30.13     | 105.8     |
# | 12        | 0.9756    | 29.51     | 0.4268    | 30.2      | 103.3     |
# | 13        | 0.9959    | 16.08     | 0.4672    | 51.53     | 127.9     |
# | 14        | 1.0       | 16.66     | 0.2821    | 48.66     | 114.4     |
# | 15        | 0.9959    | 17.14     | 0.2225    | 56.59     | 108.8     |
# | 16        | 0.9878    | 16.5      | 0.3157    | 44.5      | 104.7     |
# | 17        | 0.9878    | 24.43     | 0.3854    | 51.14     | 113.2     |
# | 18        | 0.9959    | 16.25     | 0.3707    | 44.43     | 120.6     |
# | 19        | 0.9878    | 63.07     | 0.1588    | 59.16     | 99.21     |
# | 20        | 0.9919    | 16.36     | 0.3329    | 54.15     | 116.7     |
# =========================================================================
#
#  Best Hyperparameters: {'batch_size': 16.662162480641946, 'dropout_rate': 0.2821350570464055, 'epochs': 48.66017841666772, 'num_units': 114.37783792293597}
#
#  Training Final MLP Model...
# Epoch 1/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4247 - loss: 1.1756 - val_accuracy: 0.7236 - val_loss: 0.7305
# Epoch 2/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7514 - loss: 0.7255 - val_accuracy: 0.8130 - val_loss: 0.4932
# Epoch 3/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8410 - loss: 0.4991 - val_accuracy: 0.8659 - val_loss: 0.3668
# Epoch 4/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8644 - loss: 0.4022 - val_accuracy: 0.8984 - val_loss: 0.3026
# Epoch 5/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8869 - loss: 0.3310 - val_accuracy: 0.9106 - val_loss: 0.2502
# Epoch 6/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8986 - loss: 0.3018 - val_accuracy: 0.9228 - val_loss: 0.2132
# Epoch 7/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9187 - loss: 0.2506 - val_accuracy: 0.9268 - val_loss: 0.1859
# Epoch 8/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9180 - loss: 0.2406 - val_accuracy: 0.9390 - val_loss: 0.1637
# Epoch 9/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9302 - loss: 0.2104 - val_accuracy: 0.9431 - val_loss: 0.1385
# Epoch 10/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9338 - loss: 0.1858 - val_accuracy: 0.9553 - val_loss: 0.1203
# Epoch 11/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9390 - loss: 0.1699 - val_accuracy: 0.9675 - val_loss: 0.1063
# Epoch 12/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9456 - loss: 0.1622 - val_accuracy: 0.9553 - val_loss: 0.1007
# Epoch 13/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9563 - loss: 0.1549 - val_accuracy: 0.9756 - val_loss: 0.0895
# Epoch 14/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9544 - loss: 0.1367 - val_accuracy: 0.9797 - val_loss: 0.0812
# Epoch 15/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9552 - loss: 0.1273 - val_accuracy: 0.9756 - val_loss: 0.0775
# Epoch 16/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9531 - loss: 0.1249 - val_accuracy: 0.9756 - val_loss: 0.0738
# Epoch 17/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9504 - loss: 0.1315 - val_accuracy: 0.9756 - val_loss: 0.0692
# Epoch 18/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9634 - loss: 0.0954 - val_accuracy: 0.9756 - val_loss: 0.0654
# Epoch 19/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9705 - loss: 0.0984 - val_accuracy: 0.9756 - val_loss: 0.0589
# Epoch 20/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9651 - loss: 0.1020 - val_accuracy: 0.9756 - val_loss: 0.0617
# Epoch 21/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9639 - loss: 0.1010 - val_accuracy: 0.9797 - val_loss: 0.0553
# Epoch 22/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9702 - loss: 0.0963 - val_accuracy: 0.9797 - val_loss: 0.0540
# Epoch 23/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9691 - loss: 0.0881 - val_accuracy: 0.9756 - val_loss: 0.0538
# Epoch 24/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9615 - loss: 0.0830 - val_accuracy: 0.9837 - val_loss: 0.0561
# Epoch 25/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9801 - loss: 0.0763 - val_accuracy: 0.9837 - val_loss: 0.0451
# Epoch 26/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9747 - loss: 0.0794 - val_accuracy: 0.9837 - val_loss: 0.0432
# Epoch 27/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9706 - loss: 0.0750 - val_accuracy: 0.9837 - val_loss: 0.0448
# Epoch 28/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9815 - loss: 0.0697 - val_accuracy: 0.9878 - val_loss: 0.0404
# Epoch 29/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9735 - loss: 0.0657 - val_accuracy: 0.9837 - val_loss: 0.0399
# Epoch 30/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9860 - loss: 0.0566 - val_accuracy: 0.9878 - val_loss: 0.0341
# Epoch 31/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9809 - loss: 0.0592 - val_accuracy: 0.9837 - val_loss: 0.0387
# Epoch 32/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9810 - loss: 0.0572 - val_accuracy: 0.9837 - val_loss: 0.0345
# Epoch 33/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9797 - loss: 0.0622 - val_accuracy: 0.9878 - val_loss: 0.0332
# Epoch 34/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9815 - loss: 0.0567 - val_accuracy: 0.9919 - val_loss: 0.0318
# Epoch 35/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9858 - loss: 0.0516 - val_accuracy: 0.9878 - val_loss: 0.0309
# Epoch 36/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9850 - loss: 0.0436 - val_accuracy: 0.9878 - val_loss: 0.0308
# Epoch 37/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9809 - loss: 0.0542 - val_accuracy: 0.9878 - val_loss: 0.0289
# Epoch 38/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9805 - loss: 0.0513 - val_accuracy: 0.9919 - val_loss: 0.0265
# Epoch 39/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9840 - loss: 0.0483 - val_accuracy: 0.9837 - val_loss: 0.0283
# Epoch 40/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9880 - loss: 0.0383 - val_accuracy: 0.9919 - val_loss: 0.0227
# Epoch 41/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9876 - loss: 0.0398 - val_accuracy: 0.9878 - val_loss: 0.0231
# Epoch 42/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.0418 - val_accuracy: 0.9919 - val_loss: 0.0223
# Epoch 43/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9794 - loss: 0.0444 - val_accuracy: 0.9878 - val_loss: 0.0265
# Epoch 44/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0419 - val_accuracy: 0.9878 - val_loss: 0.0228
# Epoch 45/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9903 - loss: 0.0360 - val_accuracy: 0.9878 - val_loss: 0.0217
# Epoch 46/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9897 - loss: 0.0362 - val_accuracy: 0.9878 - val_loss: 0.0254
# Epoch 47/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9908 - loss: 0.0338 - val_accuracy: 0.9878 - val_loss: 0.0224
# Epoch 48/48
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9878 - loss: 0.0341 - val_accuracy: 0.9919 - val_loss: 0.0199
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation =====
# Accuracy: 0.9619
#               precision    recall  f1-score   support
#
#            0     1.0000    0.3333    0.5000        27
#            1     0.9193    0.9624    0.9404       213
#            2     0.9943    0.9905    0.9924       524
#            3     0.8305    1.0000    0.9074        49
#
#     accuracy                         0.9619       813
#    macro avg     0.9360    0.8216    0.8350       813
# weighted avg     0.9649    0.9619    0.9573       813
#
# [[  9  18   0   0]
#  [  0 205   3   5]
#  [  0   0 519   5]
#  [  0   0   0  49]]
#
# ===== Model Metrics =====
# Training Time: 16.57s
# Testing Time (total): 0.21s
# Inference/sample: 0.000253s
# Model Size: 0.13 MB
# Trainable Params: 8,839
# RAM Usage: 1092.63 MB

# %% [markdown]
# Horizon 4

# %%
import pandas as pd
import numpy as np
import time
import os
import psutil
import warnings
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models
from bayes_opt import BayesianOptimization
from scipy.fftpack import fft

np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# 1. Load and Preprocess Data
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath)
    df.columns = df.columns.str.replace('"', '').str.strip()
    if 'TIME' not in df.columns:
        raise KeyError("Column 'TIME' missing.")
    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)
    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h4'
    if target_col not in df.columns:
        target_col = 'target'
    if target_col not in df.columns:
        raise KeyError("Target column not found.")

    df[target_col].interpolate(method='linear', inplace=True)
    df[target_col] = df[target_col].astype(int)
    df[target_col] = df[target_col] - 1

    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()



    df.fillna(df.median(), inplace=True)
    return df, target_col

# 2. Feature Scaling
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]
    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)
    return X_scaled, y, scaler

# 3. MLP Model
def build_mlp_model(input_shape, num_classes=4, num_units=64, dropout_rate=0.2):
    model = models.Sequential()
    model.add(layers.Input(shape=(input_shape,)))
    model.add(layers.Dense(num_units, activation='relu'))
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(num_units // 2, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))
    model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
    return model

# 4. Objective Function
def objective_function(num_units, dropout_rate, epochs, batch_size, X_train, y_train):
    model = build_mlp_model(
        input_shape=X_train.shape[1],
        num_classes=4,
        num_units=int(num_units),
        dropout_rate=dropout_rate
    )
    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )
    return np.max(history.history['val_accuracy'])

# 5. Hyperparameter Optimization
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'epochs': (30, 60),
        'batch_size': (16, 64)
    }
    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, epochs, batch_size: objective_function(
            num_units, dropout_rate, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )
    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# 6. Train and Evaluate
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    model = build_mlp_model(
        input_shape=X_train.shape[1],
        num_classes=4,
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate'])
    )
    start = time.time()
    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )
    training_time = time.time() - start

    start = time.time()
    y_pred = model.predict(X_test).argmax(axis=1)
    testing_time = time.time() - start
    inference_time = testing_time / len(X_test)

    print("\n===== Evaluation =====")
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
    print(classification_report(y_test, y_pred, digits=4))
    print(confusion_matrix(y_test, y_pred))

    model.save("temp_model.h5")
    model_size = os.path.getsize("temp_model.h5") / (1024 ** 2)
    os.remove("temp_model.h5")

    total_params = np.sum([np.prod(v.shape) for v in model.trainable_weights])
    ram_usage = psutil.Process(os.getpid()).memory_info().rss / (1024 ** 2)

    print("\n===== Model Metrics =====")
    print(f"Training Time: {training_time:.2f}s")
    print(f"Testing Time (total): {testing_time:.2f}s")
    print(f"Inference/sample: {inference_time:.6f}s")
    print(f"Model Size: {model_size:.2f} MB")
    print(f"Trainable Params: {total_params:,}")
    print(f"RAM Usage: {ram_usage:.2f} MB")

    return model, history

# 7. Main
def main():
    train_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H4_train.csv"
    test_path = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H4_test.csv"

    df_train, target_col = load_and_preprocess_data(train_path)
    X_train, y_train, _ = feature_scaling(df_train, target_col)

    df_test, _ = load_and_preprocess_data(test_path)
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    print("\n Optimizing Hyperparameters...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\n Best Hyperparameters:", best_params)

    print("\n Training Final MLP Model...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

if __name__ == "__main__":
    main()
# Out:
#  Optimizing Hyperparameters...
# |   iter    |  target   | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------
# | 1         | 0.9878    | 33.98     | 0.4803    | 51.96     | 89.47     |
# | 2         | 0.9878    | 23.49     | 0.1624    | 31.74     | 115.2     |
# | 3         | 0.9797    | 44.85     | 0.3832    | 30.62     | 125.1     |
# | 4         | 0.9797    | 55.96     | 0.1849    | 35.45     | 49.61     |
# | 5         | 0.9837    | 30.6      | 0.3099    | 42.96     | 59.96     |
# | 6         | 0.9878    | 23.48     | 0.2078    | 33.0      | 115.1     |
# | 7         | 0.9797    | 18.06     | 0.1411    | 33.09     | 95.96     |
# | 8         | 0.9919    | 18.44     | 0.1733    | 32.41     | 124.9     |
# | 9         | 0.9959    | 17.2      | 0.3094    | 44.18     | 127.8     |
# | 10        | 0.9919    | 21.2      | 0.3698    | 59.76     | 128.0     |
# | 11        | 0.9959    | 16.01     | 0.1641    | 57.06     | 112.5     |
# | 12        | 0.9837    | 63.41     | 0.3354    | 59.94     | 95.48     |
# | 13        | 0.9919    | 16.02     | 0.3563    | 59.3      | 99.86     |
# | 14        | 0.9837    | 17.43     | 0.4652    | 58.52     | 32.58     |
# | 15        | 0.9919    | 30.05     | 0.1684    | 59.7      | 112.3     |
# | 16        | 0.9959    | 16.58     | 0.2262    | 49.08     | 120.5     |
# | 17        | 0.9797    | 63.24     | 0.4801    | 59.45     | 32.68     |
# | 18        | 0.9797    | 16.42     | 0.4339    | 30.31     | 35.01     |
# | 19        | 0.9919    | 16.38     | 0.3227    | 59.07     | 117.7     |
# | 20        | 0.9878    | 25.82     | 0.3145    | 47.74     | 127.8     |
# =========================================================================
#
#  Best Hyperparameters: {'batch_size': 17.19510682682386, 'dropout_rate': 0.30939239497834525, 'epochs': 44.17680713368095, 'num_units': 127.78649869658051}
#
#  Training Final MLP Model...
# Epoch 1/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.4251 - loss: 1.1392 - val_accuracy: 0.7683 - val_loss: 0.7152
# Epoch 2/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7618 - loss: 0.7197 - val_accuracy: 0.8333 - val_loss: 0.4707
# Epoch 3/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8596 - loss: 0.4825 - val_accuracy: 0.8740 - val_loss: 0.3475
# Epoch 4/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8614 - loss: 0.3889 - val_accuracy: 0.8943 - val_loss: 0.2848
# Epoch 5/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8909 - loss: 0.3262 - val_accuracy: 0.9106 - val_loss: 0.2365
# Epoch 6/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9111 - loss: 0.2645 - val_accuracy: 0.9187 - val_loss: 0.2063
# Epoch 7/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9135 - loss: 0.2526 - val_accuracy: 0.9350 - val_loss: 0.1788
# Epoch 8/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9208 - loss: 0.2196 - val_accuracy: 0.9512 - val_loss: 0.1531
# Epoch 9/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9364 - loss: 0.2036 - val_accuracy: 0.9715 - val_loss: 0.1249
# Epoch 10/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9435 - loss: 0.1709 - val_accuracy: 0.9797 - val_loss: 0.1079
# Epoch 11/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9476 - loss: 0.1608 - val_accuracy: 0.9837 - val_loss: 0.1015
# Epoch 12/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9604 - loss: 0.1312 - val_accuracy: 0.9837 - val_loss: 0.0934
# Epoch 13/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9560 - loss: 0.1308 - val_accuracy: 0.9837 - val_loss: 0.0829
# Epoch 14/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9631 - loss: 0.1133 - val_accuracy: 0.9837 - val_loss: 0.0835
# Epoch 15/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9691 - loss: 0.1122 - val_accuracy: 0.9837 - val_loss: 0.0718
# Epoch 16/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9641 - loss: 0.1076 - val_accuracy: 0.9837 - val_loss: 0.0698
# Epoch 17/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9747 - loss: 0.0986 - val_accuracy: 0.9837 - val_loss: 0.0625
# Epoch 18/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9711 - loss: 0.0900 - val_accuracy: 0.9837 - val_loss: 0.0641
# Epoch 19/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9807 - loss: 0.0809 - val_accuracy: 0.9837 - val_loss: 0.0580
# Epoch 20/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9815 - loss: 0.0692 - val_accuracy: 0.9837 - val_loss: 0.0496
# Epoch 21/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9760 - loss: 0.0799 - val_accuracy: 0.9837 - val_loss: 0.0476
# Epoch 22/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9821 - loss: 0.0713 - val_accuracy: 0.9878 - val_loss: 0.0453
# Epoch 23/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9714 - loss: 0.0675 - val_accuracy: 0.9878 - val_loss: 0.0391
# Epoch 24/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9748 - loss: 0.0715 - val_accuracy: 0.9837 - val_loss: 0.0406
# Epoch 25/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9817 - loss: 0.0541 - val_accuracy: 0.9837 - val_loss: 0.0429
# Epoch 26/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9810 - loss: 0.0621 - val_accuracy: 0.9837 - val_loss: 0.0395
# Epoch 27/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9838 - loss: 0.0489 - val_accuracy: 0.9878 - val_loss: 0.0344
# Epoch 28/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9891 - loss: 0.0475 - val_accuracy: 0.9837 - val_loss: 0.0390
# Epoch 29/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9857 - loss: 0.0461 - val_accuracy: 0.9919 - val_loss: 0.0351
# Epoch 30/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9858 - loss: 0.0462 - val_accuracy: 0.9919 - val_loss: 0.0361
# Epoch 31/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0477 - val_accuracy: 0.9837 - val_loss: 0.0388
# Epoch 32/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9863 - loss: 0.0493 - val_accuracy: 0.9919 - val_loss: 0.0308
# Epoch 33/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9833 - loss: 0.0441 - val_accuracy: 0.9919 - val_loss: 0.0320
# Epoch 34/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9895 - loss: 0.0371 - val_accuracy: 0.9919 - val_loss: 0.0299
# Epoch 35/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9890 - loss: 0.0404 - val_accuracy: 0.9919 - val_loss: 0.0335
# Epoch 36/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9896 - loss: 0.0376 - val_accuracy: 0.9919 - val_loss: 0.0285
# Epoch 37/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9933 - loss: 0.0292 - val_accuracy: 0.9919 - val_loss: 0.0315
# Epoch 38/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.0247 - val_accuracy: 0.9919 - val_loss: 0.0265
# Epoch 39/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9910 - loss: 0.0304 - val_accuracy: 0.9919 - val_loss: 0.0268
# Epoch 40/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.0265 - val_accuracy: 0.9919 - val_loss: 0.0272
# Epoch 41/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.0350 - val_accuracy: 0.9919 - val_loss: 0.0256
# Epoch 42/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0241 - val_accuracy: 0.9919 - val_loss: 0.0286
# Epoch 43/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9955 - loss: 0.0211 - val_accuracy: 0.9919 - val_loss: 0.0306
# Epoch 44/44
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9925 - loss: 0.0216 - val_accuracy: 0.9919 - val_loss: 0.0230
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ===== Evaluation =====
# Accuracy: 0.9656
#               precision    recall  f1-score   support
#
#            0     1.0000    0.3077    0.4706        13
#            1     0.9538    0.9347    0.9442       199
#            2     0.9763    0.9889    0.9826       541
#            3     0.9091    1.0000    0.9524        60
#
#     accuracy                         0.9656       813
#    macro avg     0.9598    0.8078    0.8374       813
# weighted avg     0.9662    0.9656    0.9627       813
#
# [[  4   9   0   0]
#  [  0 186  13   0]
#  [  0   0 535   6]
#  [  0   0   0  60]]
#
# ===== Model Metrics =====
# Training Time: 13.32s
# Testing Time (total): 0.26s
# Inference/sample: 0.000324s
# Model Size: 0.15 MB
# Trainable Params: 10,606
# RAM Usage: 1302.79 MB
