# %% [markdown]
# Final Code with all feature engineering techniques

# %% [markdown]
# BM + Lag + RWS + TBF + TLS + STL + Fourier

# %% [markdown]
# BM + Lag + RWS + TBF + EMA  + Rolling Correlation (RC) + Fourier

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    df['month'] = df.index.month                        # Useful for seasonal crop cycles
    df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # Smooth cyclical encoding for week-of-year (annual periodicity)
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    fft_values = fft(df[target_col].dropna().values)
    fft_real = np.real(fft_values)[:len(df[target_col])]
    fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.9000
# | 1         | 0.9       | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=1.0000
# | 2         | 1.0       | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.9000
# | 3         | 0.9       | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.9800
# | 4         | 0.98      | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9800
# | 5         | 0.98      | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=127.50205081316213, dropout=0.24938568671708883, activation=relu, epochs=99.65853947991664, batch_size=33.45413194101553 => val_accuracy=1.0000
# | 6         | 1.0       | 0.3543    | 33.45     | 0.2494    | 99.66     | 127.5     |
# Trying: units=101.48738693066764, dropout=0.10739328000529058, activation=tanh, epochs=80.02528666528657, batch_size=18.362493503684107 => val_accuracy=1.0000
# | 7         | 1.0       | 1.632     | 18.36     | 0.1074    | 80.03     | 101.5     |
# Trying: units=127.80204937568448, dropout=0.40923252697581247, activation=relu, epochs=53.11968582622115, batch_size=63.589173376637454 => val_accuracy=0.9400
# | 8         | 0.94      | 0.4296    | 63.59     | 0.4092    | 53.12     | 127.8     |
# Trying: units=61.85581280114272, dropout=0.11851599214342468, activation=relu, epochs=99.52359466845371, batch_size=17.29199945345084 => val_accuracy=1.0000
# | 9         | 1.0       | 0.8693    | 17.29     | 0.1185    | 99.52     | 61.86     |
# Trying: units=32.494168083750594, dropout=0.2785416176061738, activation=tanh, epochs=65.90215410798685, batch_size=16.395947996328577 => val_accuracy=0.9600
# | 10        | 0.96      | 1.188     | 16.4      | 0.2785    | 65.9      | 32.49     |
# Trying: units=104.09628181577469, dropout=0.4421873248298369, activation=relu, epochs=99.4409721765904, batch_size=16.10876246546566 => val_accuracy=1.0000
# | 11        | 1.0       | 0.7912    | 16.11     | 0.4422    | 99.44     | 104.1     |
# Trying: units=126.10535568527536, dropout=0.1725064318260664, activation=relu, epochs=53.55782246672774, batch_size=16.98739358257813 => val_accuracy=1.0000
# | 12        | 1.0       | 0.4031    | 16.99     | 0.1725    | 53.56     | 126.1     |
# Trying: units=127.2807263194747, dropout=0.23355367163822094, activation=tanh, epochs=89.47100886302323, batch_size=16.019706502530205 => val_accuracy=1.0000
# | 13        | 1.0       | 1.175     | 16.02     | 0.2336    | 89.47     | 127.3     |
# Trying: units=97.12483013592991, dropout=0.42953527624773435, activation=relu, epochs=99.96389362480829, batch_size=45.03549644446736 => val_accuracy=1.0000
# | 14        | 1.0       | 0.01446   | 45.04     | 0.4295    | 99.96     | 97.12     |
# Trying: units=127.8144751983607, dropout=0.37685886097693133, activation=relu, epochs=99.41410524943103, batch_size=62.09186588764382 => val_accuracy=0.9800
# | 15        | 0.98      | 0.5473    | 62.09     | 0.3769    | 99.41     | 127.8     |
# Trying: units=80.82382180614893, dropout=0.48597078954070716, activation=tanh, epochs=99.40475393862002, batch_size=25.376392844618998 => val_accuracy=1.0000
# | 16        | 1.0       | 1.32      | 25.38     | 0.486     | 99.4      | 80.82     |
# Trying: units=117.61844945599486, dropout=0.12050429636639413, activation=relu, epochs=82.00525041727346, batch_size=33.20751775884239 => val_accuracy=1.0000
# | 17        | 1.0       | 0.2063    | 33.21     | 0.1205    | 82.01     | 117.6     |
# Trying: units=33.713801174316195, dropout=0.31015707070166054, activation=relu, epochs=97.62011441908317, batch_size=16.576008379332976 => val_accuracy=0.9800
# | 18        | 0.98      | 0.6621    | 16.58     | 0.3102    | 97.62     | 33.71     |
# Trying: units=106.9535700296502, dropout=0.25683425081922523, activation=relu, epochs=51.39379292576452, batch_size=16.719740361775692 => val_accuracy=1.0000
# | 19        | 1.0       | 0.4088    | 16.72     | 0.2568    | 51.39     | 107.0     |
# Trying: units=116.33465903256457, dropout=0.2854646826006877, activation=relu, epochs=70.32412354805362, batch_size=17.280807860097237 => val_accuracy=1.0000
# | 20        | 1.0       | 0.006805  | 17.28     | 0.2855    | 70.32     | 116.3     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.3974 - loss: 1.2168 - val_accuracy: 0.6000 - val_loss: 0.9935
# Epoch 2/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5782 - loss: 0.9801 - val_accuracy: 0.6200 - val_loss: 0.9240
# Epoch 3/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6091 - loss: 0.8843 - val_accuracy: 0.6600 - val_loss: 0.8293
# Epoch 4/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7016 - loss: 0.7844 - val_accuracy: 0.6600 - val_loss: 0.7202
# Epoch 5/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7392 - loss: 0.7132 - val_accuracy: 0.6800 - val_loss: 0.6300
# Epoch 6/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8020 - loss: 0.5774 - val_accuracy: 0.7800 - val_loss: 0.5469
# Epoch 7/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8443 - loss: 0.5230 - val_accuracy: 0.7800 - val_loss: 0.4746
# Epoch 8/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8074 - loss: 0.4755 - val_accuracy: 0.8400 - val_loss: 0.4048
# Epoch 9/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8607 - loss: 0.4345 - val_accuracy: 0.8800 - val_loss: 0.3546
# Epoch 10/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8844 - loss: 0.3437 - val_accuracy: 0.8800 - val_loss: 0.3121
# Epoch 11/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8703 - loss: 0.3349 - val_accuracy: 0.8800 - val_loss: 0.2763
# Epoch 12/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9196 - loss: 0.2852 - val_accuracy: 0.8800 - val_loss: 0.2574
# Epoch 13/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9024 - loss: 0.3234 - val_accuracy: 0.8800 - val_loss: 0.2401
# Epoch 14/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8746 - loss: 0.2556 - val_accuracy: 0.9400 - val_loss: 0.2269
# Epoch 15/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9208 - loss: 0.2524 - val_accuracy: 0.9400 - val_loss: 0.2132
# Epoch 16/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8972 - loss: 0.2744 - val_accuracy: 0.9400 - val_loss: 0.2064
# Epoch 17/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9110 - loss: 0.2375 - val_accuracy: 0.9200 - val_loss: 0.1930
# Epoch 18/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9097 - loss: 0.2299 - val_accuracy: 0.9400 - val_loss: 0.1726
# Epoch 19/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8984 - loss: 0.2451 - val_accuracy: 0.9400 - val_loss: 0.1685
# Epoch 20/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9096 - loss: 0.1982 - val_accuracy: 0.9400 - val_loss: 0.1642
# Epoch 21/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9206 - loss: 0.2109 - val_accuracy: 0.9600 - val_loss: 0.1549
# Epoch 22/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9515 - loss: 0.1671 - val_accuracy: 0.9600 - val_loss: 0.1500
# Epoch 23/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9649 - loss: 0.1631 - val_accuracy: 0.9400 - val_loss: 0.1423
# Epoch 24/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9236 - loss: 0.1715 - val_accuracy: 0.9800 - val_loss: 0.1267
# Epoch 25/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9339 - loss: 0.1796 - val_accuracy: 0.9600 - val_loss: 0.1307
# Epoch 26/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9411 - loss: 0.1803 - val_accuracy: 0.9800 - val_loss: 0.1220
# Epoch 27/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9394 - loss: 0.1909 - val_accuracy: 0.9800 - val_loss: 0.1234
# Epoch 28/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9414 - loss: 0.1559 - val_accuracy: 0.9600 - val_loss: 0.1221
# Epoch 29/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.
80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9566 - loss: 0.0851 - val_accuracy: 1.0000 - val_loss: 0.0383
# Epoch 64/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9682 - loss: 0.0924 - val_accuracy: 1.0000 - val_loss: 0.0398
# Epoch 65/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9894 - loss: 0.0523 - val_accuracy: 0.9800 - val_loss: 0.0445
# Epoch 66/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9904 - loss: 0.0592 - val_accuracy: 1.0000 - val_loss: 0.0428
# Epoch 67/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9928 - loss: 0.0558 - val_accuracy: 1.0000 - val_loss: 0.0353
# Epoch 68/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0513 - val_accuracy: 1.0000 - val_loss: 0.0419
# Epoch 69/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9724 - loss: 0.0756 - val_accuracy: 1.0000 - val_loss: 0.0392
# Epoch 70/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0513 - val_accuracy: 1.0000 - val_loss: 0.0372
# Epoch 71/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9795 - loss: 0.0484 - val_accuracy: 1.0000 - val_loss: 0.0325
# Epoch 72/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9799 - loss: 0.0650 - val_accuracy: 1.0000 - val_loss: 0.0285
# Epoch 73/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9976 - loss: 0.0378 - val_accuracy: 1.0000 - val_loss: 0.0305
# Epoch 74/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9902 - loss: 0.0550 - val_accuracy: 1.0000 - val_loss: 0.0355
# Epoch 75/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9678 - loss: 0.0483 - val_accuracy: 1.0000 - val_loss: 0.0272
# Epoch 76/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9888 - loss: 0.0535 - val_accuracy: 1.0000 - val_loss: 0.0262
# Epoch 77/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0306 - val_accuracy: 1.0000 - val_loss: 0.0252
# Epoch 78/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9828 - loss: 0.0464 - val_accuracy: 1.0000 - val_loss: 0.0293
# Epoch 79/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9856 - loss: 0.0423 - val_accuracy: 1.0000 - val_loss: 0.0228
# Epoch 80/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9780 - loss: 0.0536 - val_accuracy: 1.0000 - val_loss: 0.0264
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.9402
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.3846    0.5556        13
#            1     0.8545    0.9400    0.8952        50
#            2     0.9758    1.0000    0.9878       121
#
#     accuracy                         0.9402       184
#    macro avg     0.9435    0.7749    0.8128       184
# weighted avg     0.9446    0.9402    0.9321       184
#
#
# Confusion Matrix:
# [[  5   8   0]
#  [  0  47   3]
#  [  0   0 121]]
# Total instances: 184
# Shape of test set: X_test=(184, 28), y_test=(184,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion matrix total: 184

# %% [markdown]
# BM + Lag + RWS + TBF + EMA  + Rolling Correlation (RC)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    df['month'] = df.index.month                        # Useful for seasonal crop cycles
    df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # Smooth cyclical encoding for week-of-year (annual periodicity)
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.9200
# | 1         | 0.92      | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=1.0000
# | 2         | 1.0       | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.9200
# | 3         | 0.92      | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.9600
# | 4         | 0.96      | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9800
# | 5         | 0.98      | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=125.55512515158796, dropout=0.2889053843180861, activation=relu, epochs=51.46468525026853, batch_size=16.01584764445487 => val_accuracy=1.0000
# | 6         | 1.0       | 0.008803  | 16.02     | 0.2889    | 51.46     | 125.6     |
# Trying: units=101.48738693066764, dropout=0.10739328000529058, activation=tanh, epochs=80.02528666528657, batch_size=18.362493503684107 => val_accuracy=1.0000
# | 7         | 1.0       | 1.632     | 18.36     | 0.1074    | 80.03     | 101.5     |
# Trying: units=126.93405309555048, dropout=0.2653402996770312, activation=relu, epochs=99.33227714517628, batch_size=62.740949376093795 => val_accuracy=1.0000
# | 8         | 1.0       | 0.4288    | 62.74     | 0.2653    | 99.33     | 126.9     |
# Trying: units=127.98601137887972, dropout=0.3697505357310198, activation=relu, epochs=99.5988486730785, batch_size=21.19791159090859 => val_accuracy=1.0000
# | 9         | 1.0       | 0.2817    | 21.2      | 0.3698    | 99.6      | 128.0     |
# Trying: units=127.94230710276445, dropout=0.12312164225004461, activation=tanh, epochs=53.18327582304509, batch_size=60.806049142191334 => val_accuracy=0.9200
# | 10        | 0.92      | 1.32      | 60.81     | 0.1231    | 53.18     | 127.9     |
# Trying: units=98.77871205871818, dropout=0.41323479247090833, activation=tanh, epochs=99.8610167064273, batch_size=44.829763475186304 => val_accuracy=0.9800
# | 11        | 0.98      | 1.778     | 44.83     | 0.4132    | 99.86     | 98.78     |
# Trying: units=71.59894299662703, dropout=0.1661270888743997, activation=relu, epochs=98.16039534678156, batch_size=16.53657785146713 => val_accuracy=1.0000
# | 12        | 1.0       | 0.2087    | 16.54     | 0.1661    | 98.16     | 71.6      |
# Trying: units=33.93355495104366, dropout=0.154772436228266, activation=tanh, epochs=97.35515633207471, batch_size=17.4426045964175 => val_accuracy=0.9600
# | 13        | 0.96      | 1.144     | 17.44     | 0.1548    | 97.36     | 33.93     |
# Trying: units=101.03269911177551, dropout=0.19629102454379993, activation=tanh, epochs=99.56158503627685, batch_size=16.007435618485715 => val_accuracy=1.0000
# | 14        | 1.0       | 1.053     | 16.01     | 0.1963    | 99.56     | 101.0     |
# Trying: units=127.92281796622726, dropout=0.4737283042118545, activation=tanh, epochs=73.5116321249164, batch_size=17.683623133165796 => val_accuracy=1.0000
# | 15        | 1.0       | 1.05      | 17.68     | 0.4737    | 73.51     | 127.9     |
# Trying: units=101.17007816135491, dropout=0.17972552370721395, activation=relu, epochs=51.620627510090685, batch_size=16.04496592276123 => val_accuracy=1.0000
# | 16        | 1.0       | 0.08624   | 16.04     | 0.1797    | 51.62     | 101.2     |
# Trying: units=125.65438194952858, dropout=0.49525676807163854, activation=tanh, epochs=99.98196188045591, batch_size=40.438817340214605 => val_accuracy=0.9800
# | 17        | 0.98      | 1.249     | 40.44     | 0.4953    | 99.98     | 125.7     |
# Trying: units=33.53375780543386, dropout=0.4145369278754313, activation=relu, epochs=51.195679252378554, batch_size=16.164852383395356 => val_accuracy=0.9200
# | 18        | 0.92      | 0.614     | 16.16     | 0.4145    | 51.2      | 33.53     |
# Trying: units=113.04429946210747, dropout=0.1860147169135986, activation=relu, epochs=67.06123548111582, batch_size=16.298454164947103 => val_accuracy=1.0000
# | 19        | 1.0       | 0.9087    | 16.3      | 0.186     | 67.06     | 113.0     |
# Trying: units=120.548941427736, dropout=0.41004245062549594, activation=relu, epochs=86.69830323648928, batch_size=16.515276496134092 => val_accuracy=1.0000
# | 20        | 1.0       | 0.4075    | 16.52     | 0.41      | 86.7      | 120.5     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.3921 - loss: 1.3199 - val_accuracy: 0.6600 - val_loss: 1.1621
# Epoch 2/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5785 - loss: 1.0636 - val_accuracy: 0.6400 - val_loss: 0.9911
# Epoch 3/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5885 - loss: 0.9596 - val_accuracy: 0.6400 - val_loss: 0.8812
# Epoch 4/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6464 - loss: 0.8633 - val_accuracy: 0.6600 - val_loss: 0.7836
# Epoch 5/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7008 - loss: 0.7693 - val_accuracy: 0.6800 - val_loss: 0.6965
# Epoch 6/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7694 - loss: 0.6649 - val_accuracy: 0.7000 - val_loss: 0.6200
# Epoch 7/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7963 - loss: 0.5956 - val_accuracy: 0.8000 - val_loss: 0.5513
# Epoch 8/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8141 - loss: 0.5247 - val_accuracy: 0.8200 - val_loss: 0.4804
# Epoch 9/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8807 - loss: 0.4481 - val_accuracy: 0.8000 - val_loss: 0.4070
# Epoch 10/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8476 - loss: 0.4278 - val_accuracy: 0.8200 - val_loss: 0.3639
# Epoch 11/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8462 - loss: 0.4179 - val_accuracy: 0.8200 - val_loss: 0.3276
# Epoch 12/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8922 - loss: 0.3477 - val_accuracy: 0.8800 - val_loss: 0.2917
# Epoch 13/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8623 - loss: 0.3258 - val_accuracy: 0.9200 - val_loss: 0.2541
# Epoch 14/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8814 - loss: 0.3214 - val_accuracy: 0.9200 - val_loss: 0.2344
# Epoch 15/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9174 - loss: 0.2618 - val_accuracy: 0.9000 - val_loss: 0.2225
# Epoch 16/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9504 - loss: 0.1071 - val_accuracy: 0.9800 - val_loss: 0.0692
# Epoch 51/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9767 - loss: 0.0972 - val_accuracy: 0.9800 - val_loss: 0.0671
# Epoch 52/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9776 - loss: 0.0815 - val_accuracy: 0.9800 - val_loss: 0.0575
# Epoch 53/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9709 - loss: 0.0942 - val_accuracy: 0.9600 - val_loss: 0.0608
# Epoch 54/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9396 - loss: 0.0992 - val_accuracy: 0.9600 - val_loss: 0.0613
# Epoch 55/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9808 - loss: 0.0673 - val_accuracy: 0.9800 - val_loss: 0.0579
# Epoch 56/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9678 - loss: 0.0850 - val_accuracy: 0.9800 - val_loss: 0.0526
# Epoch 57/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9687 - loss: 0.0647 - val_accuracy: 0.9800 - val_loss: 0.0530
# Epoch 58/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9772 - loss: 0.0787 - val_accuracy: 0.9600 - val_loss: 0.0564
# Epoch 59/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9818 - loss: 0.0603 - val_accuracy: 0.9800 - val_loss: 0.0568
# Epoch 60/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9562 - loss: 0.0654 - val_accuracy: 0.9800 - val_loss: 0.0514
# Epoch 61/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9901 - loss: 0.0548 - val_accuracy: 1.0000 - val_loss: 0.0487
# Epoch 62/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9811 - loss: 0.0580 - val_accuracy: 0.9800 - val_loss: 0.0517
# Epoch 63/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9860 - loss: 0.0478 - val_accuracy: 0.9800 - val_loss: 0.0542
# Epoch 64/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9749 - loss: 0.0661 - val_accuracy: 1.0000 - val_loss: 0.0474
# Epoch 65/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9762 - loss: 0.0785 - val_accuracy: 1.0000 - val_loss: 0.0403
# Epoch 66/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9720 - loss: 0.0781 - val_accuracy: 1.0000 - val_loss: 0.0380
# Epoch 67/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9902 - loss: 0.0522 - val_accuracy: 1.0000 - val_loss: 0.0412
# Epoch 68/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9656 - loss: 0.0786 - val_accuracy: 1.0000 - val_loss: 0.0397
# Epoch 69/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9660 - loss: 0.0774 - val_accuracy: 1.0000 - val_loss: 0.0423
# Epoch 70/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9628 - loss: 0.0800 - val_accuracy: 1.0000 - val_loss: 0.0371
# Epoch 71/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9861 - loss: 0.0518 - val_accuracy: 1.0000 - val_loss: 0.0362
# Epoch 72/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9856 - loss: 0.0408 - val_accuracy: 1.0000 - val_loss: 0.0409
# Epoch 73/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9780 - loss: 0.0565 - val_accuracy: 1.0000 - val_loss: 0.0443
# Epoch 74/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9620 - loss: 0.0558 - val_accuracy: 1.0000 - val_loss: 0.0417
# Epoch 75/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9838 - loss: 0.0483 - val_accuracy: 1.0000 - val_loss: 0.0353
# Epoch 76/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9817 - loss: 0.0570 - val_accuracy: 1.0000 - val_loss: 0.0271
# Epoch 77/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9726 - loss: 0.0683 - val_accuracy: 1.0000 - val_loss: 0.0269
# Epoch 78/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9709 - loss: 0.0595 - val_accuracy: 1.0000 - val_loss: 0.0302
# Epoch 79/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9842 - loss: 0.0347 - val_accuracy: 1.0000 - val_loss: 0.0294
# Epoch 80/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9905 - loss: 0.0576 - val_accuracy: 1.0000 - val_loss: 0.0259
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.9511
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.3077    0.4706        13
#            1     0.8475    1.0000    0.9174        50
#            2     1.0000    1.0000    1.0000       121
#
#     accuracy                         0.9511       184
#    macro avg     0.9492    0.7692    0.7960       184
# weighted avg     0.9585    0.9511    0.9402       184
#
#
# Confusion Matrix:
# [[  4   9   0]
#  [  0  50   0]
#  [  0   0 121]]
# Total instances: 184
# Shape of test set: X_test=(184, 26), y_test=(184,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Confusion matrix total: 184

# %% [markdown]
# BM + Lag + RWS + TBF + EMA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    df['month'] = df.index.month                        # Useful for seasonal crop cycles
    df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # Smooth cyclical encoding for week-of-year (annual periodicity)
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.9400
# | 1         | 0.94      | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=1.0000
# | 2         | 1.0       | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.9200
# | 3         | 0.92      | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.9800
# | 4         | 0.98      | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9600
# | 5         | 0.96      | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=111.50842475711305, dropout=0.33748231318057387, activation=tanh, epochs=88.60158929861774, batch_size=19.220499166234177 => val_accuracy=1.0000
# | 6         | 1.0       | 1.359     | 19.22     | 0.3375    | 88.6      | 111.5     |
# Trying: units=112.91075726506544, dropout=0.19692902100545073, activation=relu, epochs=89.24241857777221, batch_size=18.218537198346922 => val_accuracy=1.0000
# | 7         | 1.0       | 0.8974    | 18.22     | 0.1969    | 89.24     | 112.9     |
# Trying: units=126.84519403259802, dropout=0.4133488571978109, activation=relu, epochs=61.35121117931309, batch_size=17.216542661695954 => val_accuracy=1.0000
# | 8         | 1.0       | 0.7005    | 17.22     | 0.4133    | 61.35     | 126.8     |
# Trying: units=126.89592927099972, dropout=0.18413087793318983, activation=relu, epochs=70.37320937118677, batch_size=51.10933391481193 => val_accuracy=0.9800
# | 9         | 0.98      | 0.5685    | 51.11     | 0.1841    | 70.37     | 126.9     |
# Trying: units=42.94983777051439, dropout=0.2138418744040687, activation=relu, epochs=99.52528250361465, batch_size=16.50904761516776 => val_accuracy=0.9800
# | 10        | 0.98      | 0.1112    | 16.51     | 0.2138    | 99.53     | 42.95     |
# Trying: units=86.5586032054723, dropout=0.2749830437620458, activation=relu, epochs=99.66413855954455, batch_size=20.58803115264184 => val_accuracy=1.0000
# | 11        | 1.0       | 0.8235    | 20.59     | 0.275     | 99.66     | 86.56     |
# Trying: units=101.979035530811, dropout=0.311896333914334, activation=relu, epochs=99.8723491185358, batch_size=55.02453237786088 => val_accuracy=1.0000
# | 12        | 1.0       | 0.06045   | 55.02     | 0.3119    | 99.87     | 102.0     |
# Trying: units=127.46062166226461, dropout=0.35579282218408936, activation=tanh, epochs=99.31346117900976, batch_size=37.03213361070964 => val_accuracy=1.0000
# | 13        | 1.0       | 1.771     | 37.03     | 0.3558    | 99.31     | 127.5     |
# Trying: units=127.78870730290647, dropout=0.34039121065149597, activation=tanh, epochs=96.14296459129139, batch_size=63.9595332551253 => val_accuracy=0.9600
# | 14        | 0.96      | 1.08      | 63.96     | 0.3404    | 96.14     | 127.8     |
# Trying: units=82.30453596411041, dropout=0.2106580852101126, activation=tanh, epochs=99.95773135276337, batch_size=44.54829349264467 => val_accuracy=0.9400
# | 15        | 0.94      | 1.129     | 44.55     | 0.2107    | 99.96     | 82.3      |
# Trying: units=126.88119853837526, dropout=0.3031341500634897, activation=relu, epochs=79.13279209664529, batch_size=27.619868623091897 => val_accuracy=1.0000
# | 16        | 1.0       | 0.3786    | 27.62     | 0.3031    | 79.13     | 126.9     |
# Trying: units=110.20626943072666, dropout=0.4224004752173588, activation=tanh, epochs=50.18440394625444, batch_size=28.326155448231695 => val_accuracy=0.9600
# | 17        | 0.96      | 1.81      | 28.33     | 0.4224    | 50.18     | 110.2     |
# Trying: units=110.40641091045909, dropout=0.2395283832405943, activation=relu, epochs=99.40033583443245, batch_size=36.65663450821915 => val_accuracy=1.0000
# | 18        | 1.0       | 0.3447    | 36.66     | 0.2395    | 99.4      | 110.4     |
# Trying: units=33.583583304371295, dropout=0.48002761705482844, activation=relu, epochs=61.243890775629254, batch_size=16.08068854619589 => val_accuracy=0.9400
# | 19        | 0.94      | 0.2713    | 16.08     | 0.48      | 61.24     | 33.58     |
# Trying: units=99.03661909425114, dropout=0.258696765425403, activation=relu, epochs=99.10694034740187, batch_size=17.131984177576207 => val_accuracy=1.0000
# | 20        | 1.0       | 0.2681    | 17.13     | 0.2587    | 99.11     | 99.04     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3591 - loss: 1.3741 - val_accuracy: 0.6000 - val_loss: 1.0530
# Epoch 2/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5646 - loss: 1.0447 - val_accuracy: 0.6400 - val_loss: 0.9082
# Epoch 3/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9920 - loss: 0.0453 - val_accuracy: 0.9800 - val_loss: 0.0471
# Epoch 73/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9753 - loss: 0.0633 - val_accuracy: 0.9800 - val_loss: 0.0456
# Epoch 74/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9952 - loss: 0.0362 - val_accuracy: 1.0000 - val_loss: 0.0442
# Epoch 75/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9830 - loss: 0.0522 - val_accuracy: 1.0000 - val_loss: 0.0420
# Epoch 76/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9854 - loss: 0.0607 - val_accuracy: 1.0000 - val_loss: 0.0387
# Epoch 77/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9904 - loss: 0.0481 - val_accuracy: 1.0000 - val_loss: 0.0343
# Epoch 78/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9744 - loss: 0.0567 - val_accuracy: 1.0000 - val_loss: 0.0324
# Epoch 79/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9805 - loss: 0.0676 - val_accuracy: 1.0000 - val_loss: 0.0329
# Epoch 80/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9893 - loss: 0.0508 - val_accuracy: 1.0000 - val_loss: 0.0325
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.8533
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.3077    0.4706        13
#            1     0.8500    0.6800    0.7556        50
#            2     0.8815    0.9835    0.9297       121
#            3     0.0000    0.0000    0.0000         0
#
#     accuracy                         0.8533       184
#    macro avg     0.6829    0.4928    0.5390       184
# weighted avg     0.8813    0.8533    0.8499       184
#
#
# Confusion Matrix:
# [[  4   6   0   3]
#  [  0  34  16   0]
#  [  0   0 119   2]
#  [  0   0   0   0]]
# Total instances: 184
# Shape of test set: X_test=(184, 24), y_test=(184,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion matrix total: 184

# %% [markdown]
# BM + Lag + RWS + TBF

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    df['month'] = df.index.month                        # Useful for seasonal crop cycles
    df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # Smooth cyclical encoding for week-of-year (annual periodicity)
    df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.9400
# | 1         | 0.94      | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=0.9600
# | 2         | 0.96      | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.8600
# | 3         | 0.86      | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.9600
# | 4         | 0.96      | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9600
# | 5         | 0.96      | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=86.1060725651995, dropout=0.169224779680282, activation=relu, epochs=80.81977623884296, batch_size=24.537790409642945 => val_accuracy=1.0000
# | 6         | 1.0       | 0.5101    | 24.54     | 0.1692    | 80.82     | 86.11     |
# Trying: units=87.38096568369156, dropout=0.10932778604201779, activation=tanh, epochs=81.72101822272187, batch_size=24.77877323288326 => val_accuracy=1.0000
# | 7         | 1.0       | 1.571     | 24.78     | 0.1093    | 81.72     | 87.38     |
# Trying: units=75.64536165445102, dropout=0.11232443930475276, activation=tanh, epochs=99.15892696639347, batch_size=27.819710717925027 => val_accuracy=0.9800
# | 8         | 0.98      | 1.492     | 27.82     | 0.1123    | 99.16     | 75.65     |
# Trying: units=88.29880492883947, dropout=0.14936649868120494, activation=tanh, epochs=87.4065826837691, batch_size=47.30666095941163 => val_accuracy=0.9600
# | 9         | 0.96      | 1.147     | 47.31     | 0.1494    | 87.41     | 88.3      |
# Trying: units=42.94983777051439, dropout=0.2138418744040687, activation=relu, epochs=99.52528250361465, batch_size=16.50904761516776 => val_accuracy=0.9800
# | 10        | 0.98      | 0.1112    | 16.51     | 0.2138    | 99.53     | 42.95     |
# Trying: units=33.88579365806304, dropout=0.41391048257399254, activation=tanh, epochs=99.84248997026015, batch_size=43.53008861036892 => val_accuracy=0.9400
# | 11        | 0.94      | 1.368     | 43.53     | 0.4139    | 99.84     | 33.89     |
# Trying: units=63.531162749649766, dropout=0.3936377035414219, activation=tanh, epochs=89.36851732065037, batch_size=16.036660131004794 => val_accuracy=0.9600
# | 12        | 0.96      | 1.068     | 16.04     | 0.3936    | 89.37     | 63.53     |
# Trying: units=91.02243391875419, dropout=0.163262007826517, activation=tanh, epochs=98.45420086442405, batch_size=17.683632009486708 => val_accuracy=1.0000
# | 13        | 1.0       | 1.182     | 17.68     | 0.1633    | 98.45     | 91.02     |
# Trying: units=126.04775530341834, dropout=0.3964097489677728, activation=relu, epochs=50.225156378464185, batch_size=59.610288660384995 => val_accuracy=0.9400
# | 14        | 0.94      | 0.2339    | 59.61     | 0.3964    | 50.23     | 126.0     |
# Trying: units=106.19766670893841, dropout=0.14033075065845668, activation=relu, epochs=99.76326421786948, batch_size=34.132160153894375 => val_accuracy=1.0000
# | 15        | 1.0       | 0.9085    | 34.13     | 0.1403    | 99.76     | 106.2     |
# Trying: units=126.64478561297737, dropout=0.3446480628799966, activation=relu, epochs=99.54706315490947, batch_size=33.33201570583354 => val_accuracy=1.0000
# | 16        | 1.0       | 0.9559    | 33.33     | 0.3446    | 99.55     | 126.6     |
# Trying: units=123.31224902264469, dropout=0.4613060465310631, activation=tanh, epochs=99.52957642115987, batch_size=52.98149395135615 => val_accuracy=0.9600
# | 17        | 0.96      | 1.93      | 52.98     | 0.4613    | 99.53     | 123.3     |
# Trying: units=124.95200629834625, dropout=0.3003360579451392, activation=relu, epochs=99.08731119879076, batch_size=16.593842310053127 => val_accuracy=1.0000
# | 18        | 1.0       | 0.8681    | 16.59     | 0.3003    | 99.09     | 125.0     |
# Trying: units=126.5438957167703, dropout=0.31983536162720766, activation=tanh, epochs=83.79675023945232, batch_size=25.81361309622944 => val_accuracy=1.0000
# | 19        | 1.0       | 1.907     | 25.81     | 0.3198    | 83.8      | 126.5     |
# Trying: units=127.73262013229674, dropout=0.3530232091925395, activation=relu, epochs=54.844315046083764, batch_size=17.677604622697427 => val_accuracy=1.0000
# | 20        | 1.0       | 0.5462    | 17.68     | 0.353     | 54.84     | 127.7     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.5100713392729201, 'batch_size': 24.537790409642945, 'dropout_rate': 0.169224779680282, 'epochs': 80.81977623884296, 'num_units': 86.1060725651995}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.2544 - loss: 1.3436 - val_accuracy: 0.6000 - val_loss: 1.1037
# Epoch 2/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5619 - loss: 1.0790 - val_accuracy: 0.6000 - val_loss: 0.9475
# Epoch 3/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5619 - loss: 0.9694 - val_accuracy: 0.6000 - val_loss: 0.8668
# Epoch 4/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5619 - loss: 0.8955 - val_accuracy: 0.6000 - val_loss: 0.7897
# Epoch 5/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5986 - loss: 0.7578 - val_accuracy: 0.6600 - val_loss: 0.7156
# Epoch 6/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7171 - loss: 0.6605 - val_accuracy: 0.7400 - val_loss: 0.6422
# Epoch 7/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7641 - loss: 0.5988 - val_accuracy: 0.8000 - val_loss: 0.5722
# Epoch 8/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8186 - loss: 0.5009 - val_accuracy: 0.8000 - val_loss: 0.5165
# Epoch 9/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8595 - loss: 0.4480 - val_accuracy: 0.8000 - val_loss: 0.4728
# Epoch 10/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8726 - loss: 0.3856 - val_accuracy: 0.8000 - val_loss: 0.4280
# Epoch 11/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8503 - loss: 0.3517 - val_accuracy: 0.8200 - val_loss: 0.3865
# Epoch 12/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8917 - loss: 0.3248 - val_accuracy: 0.8400 - val_loss: 0.3574
# Epoch 13/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8942 - loss: 0.2945 - val_accuracy: 0.8400 - val_loss: 0.3271
# Epoch 14/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8965 - loss: 0.2862 - val_accuracy: 0.8400 - val_loss: 0.3002
# Epoch 15/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9138 - loss: 0.2537 - val_accuracy: 0.8400 - val_loss: 0.2712
# Epoch 16/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9001 - loss: 0.2396 - val_accuracy: 0.8800 - val_loss: 0.2488
# Epoch 17/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9281 - loss: 0.2212 - val_accuracy: 0.8600 - val_loss: 0.2395
# Epoch 18/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9605 - loss: 0.0905 - val_accuracy: 1.0000 - val_loss: 0.0634
# Epoch 53/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9746 - loss: 0.0852 - val_accuracy: 1.0000 - val_loss: 0.0610
# Epoch 54/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9582 - loss: 0.0908 - val_accuracy: 1.0000 - val_loss: 0.0570
# Epoch 55/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9683 - loss: 0.0897 - val_accuracy: 1.0000 - val_loss: 0.0580
# Epoch 56/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9756 - loss: 0.0804 - val_accuracy: 1.0000 - val_loss: 0.0601
# Epoch 57/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9638 - loss: 0.1008 - val_accuracy: 1.0000 - val_loss: 0.0610
# Epoch 58/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9706 - loss: 0.0739 - val_accuracy: 1.0000 - val_loss: 0.0588
# Epoch 59/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9588 - loss: 0.0844 - val_accuracy: 1.0000 - val_loss: 0.0563
# Epoch 60/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9657 - loss: 0.0819 - val_accuracy: 1.0000 - val_loss: 0.0523
# Epoch 61/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9673 - loss: 0.0767 - val_accuracy: 1.0000 - val_loss: 0.0551
# Epoch 62/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9730 - loss: 0.0802 - val_accuracy: 1.0000 - val_loss: 0.0508
# Epoch 63/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9840 - loss: 0.0705 - val_accuracy: 1.0000 - val_loss: 0.0462
# Epoch 64/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9727 - loss: 0.0778 - val_accuracy: 1.0000 - val_loss: 0.0463
# Epoch 65/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9837 - loss: 0.0558 - val_accuracy: 1.0000 - val_loss: 0.0510
# Epoch 66/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9821 - loss: 0.0663 - val_accuracy: 1.0000 - val_loss: 0.0472
# Epoch 67/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9846 - loss: 0.0526 - val_accuracy: 1.0000 - val_loss: 0.0452
# Epoch 68/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9577 - loss: 0.0825 - val_accuracy: 1.0000 - val_loss: 0.0415
# Epoch 69/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9780 - loss: 0.0661 - val_accuracy: 1.0000 - val_loss: 0.0395
# Epoch 70/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9890 - loss: 0.0581 - val_accuracy: 1.0000 - val_loss: 0.0395
# Epoch 71/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9837 - loss: 0.0482 - val_accuracy: 1.0000 - val_loss: 0.0434
# Epoch 72/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9796 - loss: 0.0577 - val_accuracy: 1.0000 - val_loss: 0.0427
# Epoch 73/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9890 - loss: 0.0493 - val_accuracy: 1.0000 - val_loss: 0.0411
# Epoch 74/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9815 - loss: 0.0559 - val_accuracy: 1.0000 - val_loss: 0.0386
# Epoch 75/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9738 - loss: 0.0585 - val_accuracy: 1.0000 - val_loss: 0.0344
# Epoch 76/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9755 - loss: 0.0700 - val_accuracy: 1.0000 - val_loss: 0.0340
# Epoch 77/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9890 - loss: 0.0478 - val_accuracy: 1.0000 - val_loss: 0.0341
# Epoch 78/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9840 - loss: 0.0560 - val_accuracy: 1.0000 - val_loss: 0.0322
# Epoch 79/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 1.0000 - val_loss: 0.0301
# Epoch 80/80
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9890 - loss: 0.0448 - val_accuracy: 1.0000 - val_loss: 0.0320
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.9239
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.5385    0.7000        13
#            1     0.8750    0.8400    0.8571        50
#            2     0.9380    1.0000    0.9680       121
#
#     accuracy                         0.9239       184
#    macro avg     0.9377    0.7928    0.8417       184
# weighted avg     0.9253    0.9239    0.9189       184
#
#
# Confusion Matrix:
# [[  7   6   0]
#  [  0  42   8]
#  [  0   0 121]]
# Total instances: 184
# Shape of test set: X_test=(184, 22), y_test=(184,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Confusion matrix total: 184

# %% [markdown]
# BM + Lag + RWS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    for window in [3, 6]:
        df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
        df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    # df['month'] = df.index.month                        # Useful for seasonal crop cycles
    # df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    # df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # # Smooth cyclical encoding for week-of-year (annual periodicity)
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.8600
# | 1         | 0.86      | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=1.0000
# | 2         | 1.0       | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.8600
# | 3         | 0.86      | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.9400
# | 4         | 0.94      | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9600
# | 5         | 0.96      | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=127.63047589089311, dropout=0.4942664092098028, activation=tanh, epochs=99.02308175549153, batch_size=16.270397362306362 => val_accuracy=1.0000
# | 6         | 1.0       | 1.946     | 16.27     | 0.4943    | 99.02     | 127.6     |
# Trying: units=101.48738693066764, dropout=0.10739328000529058, activation=tanh, epochs=80.02528666528657, batch_size=18.362493503684107 => val_accuracy=0.9800
# | 7         | 0.98      | 1.632     | 18.36     | 0.1074    | 80.03     | 101.5     |
# Trying: units=87.90939168991163, dropout=0.1441332500676362, activation=relu, epochs=82.78300571995182, batch_size=20.65792783134797 => val_accuracy=1.0000
# | 8         | 1.0       | 0.1212    | 20.66     | 0.1441    | 82.78     | 87.91     |
# Trying: units=94.21119475820255, dropout=0.32729512763190965, activation=relu, epochs=76.24611101588499, batch_size=32.96726445105427 => val_accuracy=0.9600
# | 9         | 0.96      | 0.1288    | 32.97     | 0.3273    | 76.25     | 94.21     |
# Trying: units=97.42343911610281, dropout=0.29221314313802804, activation=relu, epochs=97.55747641207833, batch_size=16.973784510442428 => val_accuracy=1.0000
# | 10        | 1.0       | 0.1623    | 16.97     | 0.2922    | 97.56     | 97.42     |
# Trying: units=111.71776216565311, dropout=0.47220433426677155, activation=tanh, epochs=99.78311621997379, batch_size=32.32953314637717 => val_accuracy=0.9600
# | 11        | 0.96      | 1.367     | 32.33     | 0.4722    | 99.78     | 111.7     |
# Trying: units=81.75799125391876, dropout=0.495504104503777, activation=relu, epochs=99.69554053498379, batch_size=24.439916589916677 => val_accuracy=0.9800
# | 12        | 0.98      | 0.7346    | 24.44     | 0.4955    | 99.7      | 81.76     |
# Trying: units=93.87538109094879, dropout=0.1066039750815277, activation=relu, epochs=69.3914145012731, batch_size=16.308836202588346 => val_accuracy=1.0000
# | 13        | 1.0       | 0.2267    | 16.31     | 0.1066    | 69.39     | 93.88     |
# Trying: units=123.54809990610623, dropout=0.23270386262161497, activation=tanh, epochs=50.13275508556348, batch_size=63.09456731554556 => val_accuracy=0.8800
# | 14        | 0.88      | 1.215     | 63.09     | 0.2327    | 50.13     | 123.5     |
# Trying: units=32.08705049858234, dropout=0.4073192866055463, activation=relu, epochs=98.23283228456194, batch_size=16.2830679310495 => val_accuracy=0.9600
# | 15        | 0.96      | 0.9771    | 16.28     | 0.4073    | 98.23     | 32.09     |
# Trying: units=101.17007816135491, dropout=0.17972552370721395, activation=relu, epochs=51.620627510090685, batch_size=16.04496592276123 => val_accuracy=1.0000
# | 16        | 1.0       | 0.08624   | 16.04     | 0.1797    | 51.62     | 101.2     |
# Trying: units=124.06844502235265, dropout=0.34275968594238304, activation=relu, epochs=50.488826328444105, batch_size=19.440211901289448 => val_accuracy=1.0000
# | 17        | 1.0       | 0.5291    | 19.44     | 0.3428    | 50.49     | 124.1     |
# Trying: units=107.4600359920984, dropout=0.23167844667829698, activation=relu, epochs=53.264944830662145, batch_size=30.832038020741898 => val_accuracy=0.9800
# | 18        | 0.98      | 0.09616   | 30.83     | 0.2317    | 53.26     | 107.5     |
# Trying: units=127.8371805029733, dropout=0.31292785480860763, activation=tanh, epochs=65.89501584009953, batch_size=18.482800346995766 => val_accuracy=0.9600
# | 19        | 0.96      | 1.787     | 18.48     | 0.3129    | 65.9      | 127.8     |
# Trying: units=32.60554666090443, dropout=0.4593807438859089, activation=tanh, epochs=52.140792759845375, batch_size=16.686266529030373 => val_accuracy=0.9000
# | 20        | 0.9       | 1.574     | 16.69     | 0.4594    | 52.14     | 32.61     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.3119890406724053, 'batch_size': 18.788013384073572, 'dropout_rate': 0.4464704583099741, 'epochs': 80.05575058716045, 'num_units': 99.97496746842037}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - accuracy: 0.3215 - loss: 1.3972 - val_accuracy: 0.6200 - val_loss: 1.1484
# Epoch 2/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5520 - loss: 1.1364 - val_accuracy: 0.6200 - val_loss: 1.0199
# Epoch 3/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5965 - loss: 1.0329 - val_accuracy: 0.6200 - val_loss: 0.9474
# Epoch 4/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9600 - loss: 0.1135 - val_accuracy: 0.9800 - val_loss: 0.0508
# Epoch 71/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9610 - loss: 0.1296 - val_accuracy: 0.9800 - val_loss: 0.0549
# Epoch 72/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9732 - loss: 0.0925 - val_accuracy: 0.9800 - val_loss: 0.0512
# Epoch 73/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9741 - loss: 0.0821 - val_accuracy: 1.0000 - val_loss: 0.0439
# Epoch 74/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9701 - loss: 0.0953 - val_accuracy: 1.0000 - val_loss: 0.0430
# Epoch 75/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9780 - loss: 0.0787 - val_accuracy: 1.0000 - val_loss: 0.0425
# Epoch 76/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9670 - loss: 0.0858 - val_accuracy: 1.0000 - val_loss: 0.0425
# Epoch 77/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9731 - loss: 0.0806 - val_accuracy: 1.0000 - val_loss: 0.0446
# Epoch 78/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9744 - loss: 0.0809 - val_accuracy: 0.9800 - val_loss: 0.0480
# Epoch 79/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9870 - loss: 0.0791 - val_accuracy: 1.0000 - val_loss: 0.0392
# Epoch 80/80
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9865 - loss: 0.0800 - val_accuracy: 1.0000 - val_loss: 0.0384
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.8587
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.4615    0.6316        13
#            1     0.8947    0.6800    0.7727        50
#            2     0.9008    0.9752    0.9365       121
#            3     0.0000    0.0000    0.0000         0
#
#     accuracy                         0.8587       184
#    macro avg     0.6989    0.5292    0.5852       184
# weighted avg     0.9061    0.8587    0.8705       184
#
#
# Confusion Matrix:
# [[  6   4   0   3]
#  [  0  34  13   3]
#  [  0   0 118   3]
#  [  0   0   0   0]]
# Total instances: 184
# Shape of test set: X_test=(184, 17), y_test=(184,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Confusion matrix total: 184

# %% [markdown]
# BM + Lag

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # Lag features
    for i in range(1, 4):
        df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    # for window in [3, 6]:
    #     df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
    #     df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    # df['month'] = df.index.month                        # Useful for seasonal crop cycles
    # df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    # df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # # Smooth cyclical encoding for week-of-year (annual periodicity)
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.8200
# | 1         | 0.82      | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=0.9800
# | 2         | 0.98      | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.8000
# | 3         | 0.8       | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.8800
# | 4         | 0.88      | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9200
# | 5         | 0.92      | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=127.63047589089311, dropout=0.4942664092098028, activation=tanh, epochs=99.02308175549153, batch_size=16.270397362306362 => val_accuracy=0.9800
# | 6         | 0.98      | 1.946     | 16.27     | 0.4943    | 99.02     | 127.6     |
# Trying: units=101.48738693066764, dropout=0.10739328000529058, activation=tanh, epochs=80.02528666528657, batch_size=18.362493503684107 => val_accuracy=0.9400
# | 7         | 0.94      | 1.632     | 18.36     | 0.1074    | 80.03     | 101.5     |
# Trying: units=96.65809161458229, dropout=0.4553881619442737, activation=relu, epochs=81.06140404546366, batch_size=22.73421406169218 => val_accuracy=0.9400
# | 8         | 0.94      | 0.7991    | 22.73     | 0.4554    | 81.06     | 96.66     |
# Trying: units=95.01538471234544, dropout=0.2601068694011126, activation=relu, epochs=81.5442360633819, batch_size=16.15902440103703 => val_accuracy=1.0000
# | 9         | 1.0       | 0.8711    | 16.16     | 0.2601    | 81.54     | 95.02     |
# Trying: units=94.76930937656782, dropout=0.3365213897416046, activation=tanh, epochs=75.91981542827564, batch_size=16.21729342840554 => val_accuracy=0.9600
# | 10        | 0.96      | 1.742     | 16.22     | 0.3365    | 75.92     | 94.77     |
# Trying: units=94.96545492543594, dropout=0.35635838711656465, activation=relu, epochs=88.62365724833231, batch_size=16.37235248094739 => val_accuracy=0.9800
# | 11        | 0.98      | 0.8333    | 16.37     | 0.3564    | 88.62     | 94.97     |
# Trying: units=127.21854507411825, dropout=0.49428527505795206, activation=tanh, epochs=93.89377666740319, batch_size=24.077047141820586 => val_accuracy=0.9400
# | 12        | 0.94      | 1.691     | 24.08     | 0.4943    | 93.89     | 127.2     |
# Trying: units=84.40928085710786, dropout=0.18197736130207237, activation=tanh, epochs=86.59763192056964, batch_size=16.14299581394236 => val_accuracy=0.9600
# | 13        | 0.96      | 1.51      | 16.14     | 0.182     | 86.6      | 84.41     |
# Trying: units=119.23698124998414, dropout=0.4079909540196276, activation=tanh, epochs=99.26930567522462, batch_size=17.06789877463665 => val_accuracy=0.9800
# | 14        | 0.98      | 1.603     | 17.07     | 0.408     | 99.27     | 119.2     |
# Trying: units=108.99643739828039, dropout=0.4033775282393339, activation=tanh, epochs=99.45665756602861, batch_size=16.812602515008237 => val_accuracy=0.9600
# | 15        | 0.96      | 1.911     | 16.81     | 0.4034    | 99.46     | 109.0     |
# Trying: units=113.72396103053399, dropout=0.4643949211525982, activation=tanh, epochs=99.5413474598597, batch_size=26.743604085222294 => val_accuracy=0.9400
# | 16        | 0.94      | 1.183     | 26.74     | 0.4644    | 99.54     | 113.7     |
# Trying: units=87.49485428566845, dropout=0.44695487013645874, activation=relu, epochs=97.18294671599486, batch_size=16.505674528295522 => val_accuracy=0.9800
# | 17        | 0.98      | 0.9107    | 16.51     | 0.447     | 97.18     | 87.49     |
# Trying: units=93.15885925976535, dropout=0.269385748706397, activation=relu, epochs=99.35094248722132, batch_size=23.663072631149085 => val_accuracy=0.9200
# | 18        | 0.92      | 0.6457    | 23.66     | 0.2694    | 99.35     | 93.16     |
# Trying: units=77.01471799567926, dropout=0.351598804060841, activation=relu, epochs=96.31486919367481, batch_size=16.262621943631096 => val_accuracy=0.9600
# | 19        | 0.96      | 0.1584    | 16.26     | 0.3516    | 96.31     | 77.01     |
# Trying: units=117.42830446538764, dropout=0.4180560282374419, activation=tanh, epochs=90.77409582698073, batch_size=16.710886971343704 => val_accuracy=0.9800
# | 20        | 0.98      | 1.542     | 16.71     | 0.4181    | 90.77     | 117.4     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.8710904331365132, 'batch_size': 16.15902440103703, 'dropout_rate': 0.2601068694011126, 'epochs': 81.5442360633819, 'num_units': 95.01538471234544}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.3808 - loss: 1.2962 - val_accuracy: 0.6000 - val_loss: 1.0933
# Epoch 2/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5693 - loss: 1.0532 - val_accuracy: 0.6000 - val_loss: 0.9762
# Epoch 3/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6013 - loss: 0.9013 - val_accuracy: 0.6600 - val_loss: 0.8872
# Epoch 4/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7030 - loss: 0.8075 - val_accuracy: 0.6600 - val_loss: 0.7971
# Epoch 5/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7650 - loss: 0.7067 - val_accuracy: 0.7000 - val_loss: 0.7182
# Epoch 6/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7806 - loss: 0.6256 - val_accuracy: 0.7600 - val_loss: 0.6616
# Epoch 7/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8256 - loss: 0.5990 - val_accuracy: 0.7600 - val_loss: 0.6201
# Epoch 8/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8185 - loss: 0.5315 - val_accuracy: 0.7800 - val_loss: 0.5750
# Epoch 9/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8459 - loss: 0.4586 - val_accuracy: 0.7800 - val_loss: 0.5482
# Epoch 10/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8417 - loss: 0.4610 - val_accuracy: 0.7800 - val_loss: 0.5220
# Epoch 11/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8585 - loss: 0.4252 - val_accuracy: 0.8000 - val_loss: 0.4915
# Epoch 12/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8423 - loss: 0.4030 - val_accuracy: 0.8400 - val_loss: 0.4628
# Epoch 13/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8562 - loss: 0.4067 - val_accuracy: 0.8400 - val_loss: 0.4330
# Epoch 14/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8954 - loss: 0.3409 - val_accuracy: 0.8400 - val_loss: 0.4137
# Epoch 15/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9191 - loss: 0.1881 - val_accuracy: 0.9600 - val_loss: 0.1312
# Epoch 49/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9482 - loss: 0.1680 - val_accuracy: 0.9400 - val_loss: 0.1301
# Epoch 50/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9090 - loss: 0.1992 - val_accuracy: 0.9400 - val_loss: 0.1161
# Epoch 51/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9000 - loss: 0.1981 - val_accuracy: 0.9400 - val_loss: 0.1197
# Epoch 52/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9402 - loss: 0.1803 - val_accuracy: 0.9400 - val_loss: 0.1237
# Epoch 53/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9362 - loss: 0.1691 - val_accuracy: 0.9400 - val_loss: 0.1198
# Epoch 54/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9308 - loss: 0.1723 - val_accuracy: 0.9600 - val_loss: 0.1122
# Epoch 55/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9046 - loss: 0.2074 - val_accuracy: 0.9400 - val_loss: 0.1197
# Epoch 56/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9321 - loss: 0.1571 - val_accuracy: 0.9400 - val_loss: 0.1235
# Epoch 57/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9165 - loss: 0.1637 - val_accuracy: 0.9400 - val_loss: 0.1177
# Epoch 58/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9111 - loss: 0.1725 - val_accuracy: 0.9400 - val_loss: 0.1092
# Epoch 59/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9327 - loss: 0.1731 - val_accuracy: 0.9200 - val_loss: 0.1188
# Epoch 60/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9260 - loss: 0.1801 - val_accuracy: 0.9200 - val_loss: 0.1191
# Epoch 61/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9388 - loss: 0.1627 - val_accuracy: 0.9400 - val_loss: 0.1116
# Epoch 62/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9250 - loss: 0.1978 - val_accuracy: 0.9400 - val_loss: 0.1071
# Epoch 63/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9345 - loss: 0.1493 - val_accuracy: 0.9200 - val_loss: 0.1097
# Epoch 64/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9343 - loss: 0.1956 - val_accuracy: 0.9600 - val_loss: 0.1001
# Epoch 65/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9404 - loss: 0.1380 - val_accuracy: 0.9600 - val_loss: 0.1012
# Epoch 66/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9124 - loss: 0.1687 - val_accuracy: 0.9400 - val_loss: 0.1054
# Epoch 67/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9290 - loss: 0.1537 - val_accuracy: 0.9600 - val_loss: 0.1029
# Epoch 68/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9378 - loss: 0.1427 - val_accuracy: 0.9800 - val_loss: 0.0948
# Epoch 69/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9333 - loss: 0.1534 - val_accuracy: 0.9600 - val_loss: 0.0932
# Epoch 70/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9151 - loss: 0.1486 - val_accuracy: 0.9600 - val_loss: 0.0987
# Epoch 71/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8999 - loss: 0.1547 - val_accuracy: 0.9600 - val_loss: 0.0925
# Epoch 72/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9308 - loss: 0.1686 - val_accuracy: 0.9600 - val_loss: 0.0919
# Epoch 73/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9409 - loss: 0.1343 - val_accuracy: 0.9400 - val_loss: 0.0978
# Epoch 74/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9265 - loss: 0.1471 - val_accuracy: 0.9400 - val_loss: 0.0987
# Epoch 75/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9487 - loss: 0.1407 - val_accuracy: 0.9800 - val_loss: 0.0929
# Epoch 76/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9382 - loss: 0.1308 - val_accuracy: 0.9800 - val_loss: 0.0933
# Epoch 77/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1580 - val_accuracy: 1.0000 - val_loss: 0.0850
# Epoch 78/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9294 - loss: 0.1489 - val_accuracy: 0.9800 - val_loss: 0.0883
# Epoch 79/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9564 - loss: 0.1357 - val_accuracy: 0.9400 - val_loss: 0.0932
# Epoch 80/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9331 - loss: 0.1383 - val_accuracy: 0.9400 - val_loss: 0.0909
# Epoch 81/81
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9688 - loss: 0.1203 - val_accuracy: 0.9400 - val_loss: 0.0870
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.8207
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.3077    0.4706        13
#            1     0.8485    0.5600    0.6747        50
#            2     0.8623    0.9835    0.9189       121
#            3     0.0000    0.0000    0.0000         0
#
#     accuracy                         0.8207       184
#    macro avg     0.6777    0.4628    0.5161       184
# weighted avg     0.8683    0.8207    0.8209       184
#
#
# Confusion Matrix:
# [[  4   4   0   5]
#  [  0  28  19   3]
#  [  0   1 119   1]
#  [  0   0   0   0]]
# Total instances: 184
# Shape of test set: X_test=(184, 13), y_test=(184,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Confusion matrix total: 184

# %% [markdown]
# BM

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import tensorflow as tf
from bayes_opt import BayesianOptimization
from statsmodels.tsa.seasonal import STL
from scipy.fftpack import fft
import warnings

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
warnings.filterwarnings('ignore')

# ==============================
# 1. Data Loading and Preprocessing
# ==============================
def load_and_preprocess_data(filepath):
    df = pd.read_csv(filepath, delimiter=",", low_memory=False)
    df.columns = df.columns.str.replace('"', '').str.strip()

    if 'TIME' not in df.columns:
        raise KeyError("The column 'TIME' does not exist in the dataset.")

    df['TIME'] = pd.to_datetime(df['TIME'], errors='coerce')
    df.dropna(subset=['TIME'], inplace=True)
    df.set_index('TIME', inplace=True)

    df = df.apply(pd.to_numeric, errors='coerce')
    df.dropna(axis=1, how='all', inplace=True)

    target_col = 'fenologia_h1'  # Change target column to 'fenologia_h1' for classification
    if target_col not in df.columns:
        raise KeyError(f"The target column '{target_col}' does not exist.")

    df[target_col].interpolate(method='linear', inplace=True)

    # Subtract 1 from the target column to make it 0-indexed (0, 1, 2, 3)
    df[target_col] = df[target_col] - 1

    # # Lag features
    # for i in range(1, 4):
    #     df[f'{target_col}_lag{i}'] = df[target_col].shift(i)

    # Rolling statistics
    # for window in [3, 6]:
    #     df[f'{target_col}_roll_mean_{window}'] = df[target_col].rolling(window).mean()
    #     df[f'{target_col}_roll_std_{window}'] = df[target_col].rolling(window).std()

    # Time-based features for weekly data
    # df['month'] = df.index.month                        # Useful for seasonal crop cycles
    # df['weekofyear'] = df.index.isocalendar().week      # Week number in the year (1–52)
    # df['year'] = df.index.isocalendar().year            # Optional: if data spans multiple years

    # # Smooth cyclical encoding for week-of-year (annual periodicity)
    # df['sin_week'] = np.sin(2 * np.pi * df['weekofyear'] / 52)
    # df['cos_week'] = np.cos(2 * np.pi * df['weekofyear'] / 52)

    # Additional Feature 1: Exponential Moving Average (EMA)
    # df['EMA_3'] = df[target_col].ewm(span=3, adjust=False).mean()  # EMA with span 3
    # df['EMA_6'] = df[target_col].ewm(span=6, adjust=False).mean()  # EMA with span 6

    # Additional Feature 2: Rolling Correlation
    # We compute the correlation between the target and 'month' as an example
    # df['correlation_target_month'] = df[target_col].rolling(window=6).corr(df['month'])
    # df['correlation_target_week'] = df[target_col].rolling(window=6).corr(df['weekofyear'])

    # Additional Feature 3: Fourier Transform (FFT) Features
    # Apply FFT to the target variable and extract real and imaginary components
    # fft_values = fft(df[target_col].dropna().values)
    # fft_real = np.real(fft_values)[:len(df[target_col])]
    # fft_imag = np.imag(fft_values)[:len(df[target_col])]
    
    # df['fft_real'] = np.concatenate([fft_real, np.nan * np.ones(len(df) - len(fft_real))], axis=0)
    # df['fft_imag'] = np.concatenate([fft_imag, np.nan * np.ones(len(df) - len(fft_imag))], axis=0)

    # Fill missing values
    df.fillna(df.median(), inplace=True)

    return df, target_col

# ==============================
# 2. Feature Scaling
# ==============================
def feature_scaling(df, target_col):
    X = df.drop(columns=[target_col])
    y = df[target_col]

    scaler = MinMaxScaler()
    X_scaled = scaler.fit_transform(X)

    return X_scaled, y, scaler

# ==============================
# 3. MLP Model Definition (For Classification)
# ==============================
def build_mlp_model(input_dim, num_classes=4, num_units=64, dropout_rate=0.2, activation='relu'):
    model = Sequential()
    model.add(Dense(num_units, activation=activation, input_dim=input_dim))
    model.add(Dropout(dropout_rate))
    model.add(Dense(num_units // 2, activation=activation))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax for multi-class classification

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# ==============================
# 4. Objective Function for Bayesian Optimization
# ==============================
def objective_function(num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train):
    activation_fn = ['relu', 'tanh', 'sigmoid'][int(activation)] 

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(num_units),
        dropout_rate=dropout_rate,
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(epochs),
        batch_size=int(batch_size),
        validation_split=0.2,
        verbose=0
    )

    # Get the best validation accuracy (higher is better)
    val_accuracy = np.max(history.history['val_accuracy'])

    print(f"Trying: units={num_units}, dropout={dropout_rate}, activation={activation_fn}, epochs={epochs}, batch_size={batch_size} => val_accuracy={val_accuracy:.4f}")

    return val_accuracy  # Maximize validation accuracy

# ==============================
# 5. Bayesian Optimization Function
# ==============================
def optimize_hyperparameters(X_train, y_train):
    pbounds = {
        'num_units': (32, 128),
        'dropout_rate': (0.1, 0.5),
        'activation': (0, 2),
        'epochs': (50, 100),
        'batch_size': (16, 64)
    }

    optimizer = BayesianOptimization(
        f=lambda num_units, dropout_rate, activation, epochs, batch_size: objective_function(
            num_units, dropout_rate, activation, epochs, batch_size, X_train, y_train
        ),
        pbounds=pbounds,
        random_state=42,
        verbose=2
    )

    optimizer.maximize(init_points=5, n_iter=15)
    return optimizer.max['params']

# ==============================
# 6. Final Model Training and Evaluation
# ==============================
def train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params):
    activation_list = ['relu', 'tanh', 'sigmoid']
    activation_fn = activation_list[int(best_params['activation'])]

    model = build_mlp_model(
        input_dim=X_train.shape[1],
        num_classes=4,  # Number of classes in the classification task
        num_units=int(best_params['num_units']),
        dropout_rate=float(best_params['dropout_rate']),
        activation=activation_fn
    )

    history = model.fit(
        X_train, y_train,
        epochs=int(best_params['epochs']),
        batch_size=int(best_params['batch_size']),
        validation_split=0.2,
        verbose=1
    )

    y_pred = model.predict(X_test).argmax(axis=1)  # Get the class with highest probability

    # Ensure correct alignment of y_pred and y_test (same number of instances)
    if len(y_pred) != len(y_test):
        raise ValueError("Mismatch between the number of predictions and actual test samples.")

    # Evaluation Metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("\n======================= Test Results =======================")
    print(f"Test Accuracy: {accuracy:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred, digits=4))
    print("\nConfusion Matrix:")
    cm = confusion_matrix(y_test, y_pred)
    print(cm)
    print(f"Total instances: {cm.sum()}")  # Ensure we're counting the correct total instances

    # Plotting results
    plt.figure(figsize=(12, 6))
    plt.plot(y_test.index, y_test, label='True Values')
    plt.plot(y_test.index, y_pred, label='Predicted Values')
    plt.xlabel('Time')
    plt.ylabel('Target Value')
    plt.title('True vs Predicted Values')
    plt.legend()
    plt.grid(True)
    plt.show()

    return model, history

# ==============================
# 7. Main Function
# ==============================
def main():
    # Load and preprocess training data
    train_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_train.csv"
    df_train, target_col = load_and_preprocess_data(train_filepath)

    # Apply feature scaling to training data
    X_train, y_train, scaler = feature_scaling(df_train, target_col)

    # Hyperparameter optimization
    print("\nStarting Hyperparameter Optimization...")
    best_params = optimize_hyperparameters(X_train, y_train)
    print("\nBest hyperparameters found:", best_params)

    # Load and preprocess test data (no feature engineering, just scaling)
    test_filepath = r"E:\Abroad period research\Phenology datasets\PHENOLOGY_H1\Jaen_test.csv"
    df_test, _ = load_and_preprocess_data(test_filepath)

    # Apply feature scaling to test data
    X_test, y_test, _ = feature_scaling(df_test, target_col)

    # Train final model with optimized hyperparameters
    print("\nTraining Final Model with Optimized Hyperparameters...")
    model, history = train_and_evaluate_model(X_train, X_test, y_train, y_test, best_params)

    print(f"Shape of test set: X_test={X_test.shape}, y_test={y_test.shape}")
    print(f"Confusion matrix total: {confusion_matrix(y_test, model.predict(X_test).argmax(axis=1)).sum()}")

if __name__ == "__main__":
    main()
# Out:
# Starting Hyperparameter Optimization...
# |   iter    |  target   | activa... | batch_... | dropou... |  epochs   | num_units |
# -------------------------------------------------------------------------------------
# Trying: units=46.97778948247391, dropout=0.39279757672456206, activation=relu, epochs=79.93292420985183, batch_size=61.634286707675976 => val_accuracy=0.8000
# | 1         | 0.8       | 0.7491    | 61.63     | 0.3928    | 79.93     | 46.98     |
# Trying: units=99.97496746842037, dropout=0.4464704583099741, activation=relu, epochs=80.05575058716045, batch_size=18.788013384073572 => val_accuracy=0.9400
# | 2         | 0.94      | 0.312     | 18.79     | 0.4465    | 80.06     | 99.97     |
# Trying: units=49.45519685188166, dropout=0.4329770563201687, activation=relu, epochs=60.61695553391381, batch_size=62.55567290377573 => val_accuracy=0.8200
# | 3         | 0.82      | 0.04117   | 62.56     | 0.433     | 60.62     | 49.46     |
# Trying: units=59.95799745901202, dropout=0.3099025726528951, activation=relu, epochs=71.5972509321058, batch_size=30.60362766205781 => val_accuracy=0.8800
# | 4         | 0.88      | 0.3668    | 30.6      | 0.3099    | 71.6      | 59.96     |
# Trying: units=75.78271848483544, dropout=0.21685785941408728, activation=tanh, epochs=68.31809216468459, batch_size=22.695705311298006 => val_accuracy=0.9200
# | 5         | 0.92      | 1.224     | 22.7      | 0.2169    | 68.32     | 75.78     |
# Trying: units=125.55512515158796, dropout=0.2889053843180861, activation=relu, epochs=51.46468525026853, batch_size=16.01584764445487 => val_accuracy=0.9600
# | 6         | 0.96      | 0.008803  | 16.02     | 0.2889    | 51.46     | 125.6     |
# Trying: units=101.48738693066764, dropout=0.10739328000529058, activation=tanh, epochs=80.02528666528657, batch_size=18.362493503684107 => val_accuracy=0.9400
# | 7         | 0.94      | 1.632     | 18.36     | 0.1074    | 80.03     | 101.5     |
# Trying: units=127.80204937568448, dropout=0.40923252697581247, activation=relu, epochs=53.11968582622115, batch_size=63.589173376637454 => val_accuracy=0.8600
# | 8         | 0.86      | 0.4296    | 63.59     | 0.4092    | 53.12     | 127.8     |
# Trying: units=102.52949829579597, dropout=0.187062714793912, activation=tanh, epochs=50.43475352594457, batch_size=16.305468855248577 => val_accuracy=0.9200
# | 9         | 0.92      | 1.265     | 16.31     | 0.1871    | 50.43     | 102.5     |
# Trying: units=127.99325783774273, dropout=0.36741206859966913, activation=tanh, epochs=99.38096124738205, batch_size=18.2718783675487 => val_accuracy=0.9400
# | 10        | 0.94      | 1.98      | 18.27     | 0.3674    | 99.38     | 128.0     |
# Trying: units=127.50007771445657, dropout=0.36654625893329773, activation=tanh, epochs=67.51562979407649, batch_size=16.57123117041433 => val_accuracy=0.9400
# | 11        | 0.94      | 1.563     | 16.57     | 0.3665    | 67.52     | 127.5     |
# Trying: units=82.81306451729668, dropout=0.2774221166935714, activation=relu, epochs=98.18646598453839, batch_size=16.920238514096198 => val_accuracy=0.9600
# | 12        | 0.96      | 0.5549    | 16.92     | 0.2774    | 98.19     | 82.81     |
# Trying: units=98.64940452274092, dropout=0.22967011683708727, activation=relu, epochs=99.95485144412149, batch_size=37.42279215298274 => val_accuracy=0.9400
# | 13        | 0.94      | 0.8476    | 37.42     | 0.2297    | 99.95     | 98.65     |
# Trying: units=101.03269911177551, dropout=0.19629102454379993, activation=tanh, epochs=99.56158503627685, batch_size=16.007435618485715 => val_accuracy=0.9400
# | 14        | 0.94      | 1.053     | 16.01     | 0.1963    | 99.56     | 101.0     |
# Trying: units=127.8144751983607, dropout=0.37685886097693133, activation=relu, epochs=99.41410524943103, batch_size=62.09186588764382 => val_accuracy=0.9600
# | 15        | 0.96      | 0.5473    | 62.09     | 0.3769    | 99.41     | 127.8     |
# Trying: units=34.64886836434211, dropout=0.11015502492488856, activation=tanh, epochs=99.3016047584546, batch_size=16.27157436385266 => val_accuracy=0.9200
# | 16        | 0.92      | 1.995     | 16.27     | 0.1102    | 99.3      | 34.65     |
# Trying: units=125.65438194952858, dropout=0.49525676807163854, activation=tanh, epochs=99.98196188045591, batch_size=40.438817340214605 => val_accuracy=0.9200
# | 17        | 0.92      | 1.249     | 40.44     | 0.4953    | 99.98     | 125.7     |
# Trying: units=103.92138767281054, dropout=0.3960371641836783, activation=tanh, epochs=97.85731624501611, batch_size=63.298071851953694 => val_accuracy=0.9000
# | 18        | 0.9       | 1.511     | 63.3      | 0.396     | 97.86     | 103.9     |
# Trying: units=63.28621940734409, dropout=0.26925576321626465, activation=relu, epochs=98.6728057262873, batch_size=16.354944537633212 => val_accuracy=0.9600
# | 19        | 0.96      | 0.5785    | 16.35     | 0.2693    | 98.67     | 63.29     |
# Trying: units=32.60554666090443, dropout=0.4593807438859089, activation=tanh, epochs=52.140792759845375, batch_size=16.686266529030373 => val_accuracy=0.8400
# | 20        | 0.84      | 1.574     | 16.69     | 0.4594    | 52.14     | 32.61     |
# =====================================================================================
#
# Best hyperparameters found: {'activation': 0.008803218007572555, 'batch_size': 16.01584764445487, 'dropout_rate': 0.2889053843180861, 'epochs': 51.46468525026853, 'num_units': 125.55512515158796}
#
# Training Final Model with Optimized Hyperparameters...
# Epoch 1/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.4664 - loss: 1.2996 - val_accuracy: 0.6000 - val_loss: 1.0812
# Epoch 2/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6016 - loss: 1.0438 - val_accuracy: 0.6000 - val_loss: 0.9417
# Epoch 3/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6570 - loss: 0.8846 - val_accuracy: 0.6400 - val_loss: 0.8700
# Epoch 4/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7470 - loss: 0.7436 - val_accuracy: 0.6600 - val_loss: 0.7922
# Epoch 5/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7538 - loss: 0.6834 - val_accuracy: 0.6800 - val_loss: 0.7030
# Epoch 6/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7516 - loss: 0.5901 - val_accuracy: 0.7400 - val_loss: 0.6390
# Epoch 7/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8018 - loss: 0.5354 - val_accuracy: 0.7400 - val_loss: 0.5913
# Epoch 8/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8087 - loss: 0.5395 - val_accuracy: 0.7600 - val_loss: 0.5525
# Epoch 9/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8464 - loss: 0.4753 - val_accuracy: 0.7800 - val_loss: 0.5111
# Epoch 10/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8279 - loss: 0.4606 - val_accuracy: 0.8000 - val_loss: 0.4838
# Epoch 11/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8658 - loss: 0.4644 - val_accuracy: 0.8000 - val_loss: 0.4641
# Epoch 12/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8568 - loss: 0.4451 - val_accuracy: 0.8200 - val_loss: 0.4350
# Epoch 13/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8759 - loss: 0.4142 - val_accuracy: 0.8000 - val_loss: 0.4135
# Epoch 14/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8517 - loss: 0.4077 - val_accuracy: 0.8200 - val_loss: 0.4009
# Epoch 15/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8621 - loss: 0.3935 - val_accuracy: 0.8200 - val_loss: 0.3870
# Epoch 16/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8722 - loss: 0.3631 - val_accuracy: 0.8400 - val_loss: 0.3726
# Epoch 17/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8853 - loss: 0.3640 - val_accuracy: 0.8400 - val_loss: 0.3540
# Epoch 18/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8935 - loss: 0.3238 - val_accuracy: 0.8400 - val_loss: 0.3440
# Epoch 19/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8982 - loss: 0.3552 - val_accuracy: 0.8400 - val_loss: 0.3330
# Epoch 20/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9034 - loss: 0.3260 - val_accuracy: 0.8400 - val_loss: 0.3256
# Epoch 21/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8693 - loss: 0.3526 - val_accuracy: 0.8600 - val_loss: 0.2984
# Epoch 22/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8797 - loss: 0.3445 - val_accuracy: 0.8600 - val_loss: 0.2846
# Epoch 23/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9019 - loss: 0.3031 - val_accuracy: 0.8600 - val_loss: 0.2621
# Epoch 24/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8924 - loss: 0.3296 - val_accuracy: 0.8600 - val_loss: 0.2871
# Epoch 25/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8870 - loss: 0.2957 - val_accuracy: 0.8600 - val_loss: 0.2741
# Epoch 26/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8971 - loss: 0.2865 - val_accuracy: 0.8800 - val_loss: 0.2523
# Epoch 27/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9064 - loss: 0.2551 - val_accuracy: 0.8800 - val_loss: 0.2441
# Epoch 28/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9041 - loss: 0.3063 - val_accuracy: 0.9000 - val_loss: 0.2487
# Epoch 29/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8718 - loss: 0.3187 - val_accuracy: 0.9000 - val_loss: 0.2450
# Epoch 30/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9025 - loss: 0.2522 - val_accuracy: 0.9000 - val_loss: 0.2344
# Epoch 31/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9187 - loss: 0.2755 - val_accuracy: 0.9000 - val_loss: 0.2225
# Epoch 32/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9148 - loss: 0.2491 - val_accuracy: 0.9200 - val_loss: 0.2184
# Epoch 33/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9022 - loss: 0.2720 - val_accuracy: 0.9000 - val_loss: 0.2231
# Epoch 34/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9167 - loss: 0.2453 - val_accuracy: 0.9200 - val_loss: 0.2044
# Epoch 35/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8904 - loss: 0.3112 - val_accuracy: 0.9200 - val_loss: 0.2061
# Epoch 36/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8914 - loss: 0.2785 - val_accuracy: 0.9200 - val_loss: 0.2057
# Epoch 37/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8988 - loss: 0.2577 - val_accuracy: 0.9200 - val_loss: 0.2014
# Epoch 38/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9196 - loss: 0.2358 - val_accuracy: 0.9200 - val_loss: 0.2018
# Epoch 39/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9188 - loss: 0.2141 - val_accuracy: 0.9200 - val_loss: 0.1951
# Epoch 40/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9026 - loss: 0.2384 - val_accuracy: 0.9200 - val_loss: 0.1926
# Epoch 41/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8898 - loss: 0.2366 - val_accuracy: 0.9200 - val_loss: 0.1724
# Epoch 42/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9079 - loss: 0.2379 - val_accuracy: 0.9200 - val_loss: 0.1718
# Epoch 43/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9255 - loss: 0.2305 - val_accuracy: 0.9200 - val_loss: 0.1799
# Epoch 44/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9284 - loss: 0.2153 - val_accuracy: 0.9200 - val_loss: 0.1909
# Epoch 45/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9123 - loss: 0.2133 - val_accuracy: 0.9200 - val_loss: 0.1748
# Epoch 46/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9104 - loss: 0.1968 - val_accuracy: 0.9200 - val_loss: 0.1707
# Epoch 47/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9371 - loss: 0.1959 - val_accuracy: 0.9200 - val_loss: 0.1729
# Epoch 48/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9061 - loss: 0.2330 - val_accuracy: 0.9200 - val_loss: 0.1727
# Epoch 49/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9079 - loss: 0.1996 - val_accuracy: 0.9200 - val_loss: 0.1614
# Epoch 50/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9174 - loss: 0.1862 - val_accuracy: 0.9200 - val_loss: 0.1648
# Epoch 51/51
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8978 - loss: 0.2147 - val_accuracy: 0.9400 - val_loss: 0.1565
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# ======================= Test Results =======================
# Test Accuracy: 0.8696
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0     1.0000    0.2308    0.3750        13
#            1     0.8810    0.7400    0.8043        50
#            2     0.9023    0.9917    0.9449       121
#            3     0.0000    0.0000    0.0000         0
#
#     accuracy                         0.8696       184
#    macro avg     0.6958    0.4906    0.5311       184
# weighted avg     0.9034    0.8696    0.8664       184
#
#
# Confusion Matrix:
# [[  3   4   0   6]
#  [  0  37  13   0]
#  [  0   1 120   0]
#  [  0   0   0   0]]
# Total instances: 184
# Shape of test set: X_test=(184, 10), y_test=(184,)
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion matrix total: 184

# %% [markdown]
# BM + Lag + RWS + TBF + TLS

# %% [markdown]
# BM + Lag + RWS + TBF
